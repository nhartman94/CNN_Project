# %% [markdown]
# # Fully Connected Net
#
# For our least intelligent baseline, just *flatten* all of the layers and train a MLP classifier.
#
# Since the DataLoader has multiple inputs, I think we need to use the module API.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Loading the other modules I have in parent directories
import sys
PYTHONPATH="../"
sys.path.append(PYTHONPATH)
from dataProcessing import getDataLoaders
from models import FCNet, count_parameters
from train import check_accuracy, train
from plottingFcts import trainingMetrics, sigBkgEff, plotROC, plotConfusion

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
loader_train, loader_val, loader_test = getDataLoaders(batch_size=256)

# %% [markdown]
# In class, they said the network usually saturated with about 3 different hidden layers, so a default architecture I'm trying has hidden dimensions {150, 100, 50}, although these are hyperparams that I could (possibly) tune. I'm also using batchnorm and dropout!

# %%
myModel = FCNet() # h1_dim=300,h2_dim=200,h3_dim=100)

# %%
count_parameters(myModel)
# Out:
# 96653

# %% [markdown]
# #### Sanity check
# Before training, the validation accuracy should be about 33%

# %%
check_accuracy(loader_val, myModel)
# Out:
# cuda
# Got 9596 / 30000 correct (31.99)

# %% [markdown]
# ### Next step: Train the net!
#
# For simplicity, just use the adam optimizer!

# %%
optimizer = optim.Adam(myModel.parameters(), lr = 1e-5)

# %%
np.log(3)
# Out:
# 1.0986122886681098

# %%
history, myModel = train(loader_train, loader_val, myModel, optimizer, epochs=60, returnBest=True)
# Out:
# Epoch 1/60:
# Iteration 0, loss = 1.1314
# cuda
# Got 9643 / 30000 correct (32.14)
#
# Iteration 100, loss = 1.0581
# cuda
# Got 11921 / 30000 correct (39.74)
#
# Iteration 200, loss = 1.0756
# cuda
# Got 13513 / 30000 correct (45.04)
#
# Iteration 300, loss = 1.0314
# cuda
# Got 14820 / 30000 correct (49.40)
#
# Iteration 400, loss = 1.0073
# cuda
# Got 15849 / 30000 correct (52.83)
#
# Iteration 500, loss = 0.9848
# cuda
# Got 16427 / 30000 correct (54.76)
#
# Iteration 600, loss = 0.9517
# cuda
# Got 17036 / 30000 correct (56.79)
#
# Iteration 700, loss = 0.9697
# cuda
# Got 17318 / 30000 correct (57.73)
#
# cuda
# Got 103596 / 180000 correct (57.55)
# cuda
# Got 17211 / 30000 correct (57.37)
#
# Epoch 2/60:
# Iteration 0, loss = 0.9453
# cuda
# Got 17335 / 30000 correct (57.78)
#
# Iteration 100, loss = 0.9567
# cuda
# Got 17648 / 30000 correct (58.83)
#
# Iteration 200, loss = 0.9132
# cuda
# Got 17937 / 30000 correct (59.79)
#
# Iteration 300, loss = 0.8872
# cuda
# Got 18298 / 30000 correct (60.99)
#
# Iteration 400, loss = 0.8926
# cuda
# Got 18453 / 30000 correct (61.51)
#
# Iteration 500, loss = 0.8672
# cuda
# Got 18726 / 30000 correct (62.42)
#
# Iteration 600, loss = 0.8431
# cuda
# Got 18865 / 30000 correct (62.88)
#
# Iteration 700, loss = 0.7944
# cuda
# Got 19113 / 30000 correct (63.71)
#
# cuda
# Got 114190 / 180000 correct (63.44)
# cuda
# Got 19036 / 30000 correct (63.45)
#
# Epoch 3/60:
# Iteration 0, loss = 0.8280
# cuda
# Got 18941 / 30000 correct (63.14)
#
# Iteration 100, loss = 0.8180
# cuda
# Got 19222 / 30000 correct (64.07)
#
# Iteration 200, loss = 0.8222
# cuda
# Got 19308 / 30000 correct (64.36)
#
# Iteration 300, loss = 0.8072
# cuda
# Got 19574 / 30000 correct (65.25)
#
# Iteration 400, loss = 0.7933
# cuda
# Got 19631 / 30000 correct (65.44)
#
# Iteration 500, loss = 0.7661
# cuda
# Got 19846 / 30000 correct (66.15)
#
# Iteration 600, loss = 0.7796
# cuda
# Got 19735 / 30000 correct (65.78)
#
# Iteration 700, loss = 0.7820
# cuda
# Got 19830 / 30000 correct (66.10)
#
# cuda
# Got 118562 / 180000 correct (65.87)
# cuda
# Got 19744 / 30000 correct (65.81)
#
# Epoch 4/60:
# Iteration 0, loss = 0.7726
# cuda
# Got 19920 / 30000 correct (66.40)
#
# Iteration 100, loss = 0.7740
# cuda
# Got 20029 / 30000 correct (66.76)
#
# Iteration 200, loss = 0.7379
# cuda
# Got 20089 / 30000 correct (66.96)
#
# Iteration 300, loss = 0.7563
# cuda
# Got 20228 / 30000 correct (67.43)
#
# Iteration 400, loss = 0.7307
# cuda
# Got 20252 / 30000 correct (67.51)
#
# Iteration 500, loss = 0.8002
# cuda
# Got 20377 / 30000 correct (67.92)
#
# Iteration 600, loss = 0.7128
# cuda
# Got 20319 / 30000 correct (67.73)
#
# Iteration 700, loss = 0.7434
# cuda
# Got 20445 / 30000 correct (68.15)
#
# cuda
# Got 122333 / 180000 correct (67.96)
# cuda
# Got 20421 / 30000 correct (68.07)
#
# Epoch 5/60:
# Iteration 0, loss = 0.7121
# cuda
# Got 20444 / 30000 correct (68.15)
#
# Iteration 100, loss = 0.7187
# cuda
# Got 20609 / 30000 correct (68.70)
#
# Iteration 200, loss = 0.6906
# cuda
# Got 20730 / 30000 correct (69.10)
#
# Iteration 300, loss = 0.6870
# cuda
# Got 20652 / 30000 correct (68.84)
#
# Iteration 400, loss = 0.6733
# cuda
# Got 20860 / 30000 correct (69.53)
#
# Iteration 500, loss = 0.6757
# cuda
# Got 20909 / 30000 correct (69.70)
#
# Iteration 600, loss = 0.7024
# cuda
# Got 20951 / 30000 correct (69.84)
#
# Iteration 700, loss = 0.6833
# cuda
# Got 20920 / 30000 correct (69.73)
#
# cuda
# Got 125416 / 180000 correct (69.68)
# cuda
# Got 20889 / 30000 correct (69.63)
#
# Epoch 6/60:
# Iteration 0, loss = 0.6824
# cuda
# Got 21067 / 30000 correct (70.22)
#
# Iteration 100, loss = 0.6296
# cuda
# Got 21127 / 30000 correct (70.42)
#
# Iteration 200, loss = 0.6530
# cuda
# Got 20967 / 30000 correct (69.89)
#
# Iteration 300, loss = 0.6351
# cuda
# Got 21257 / 30000 correct (70.86)
#
# Iteration 400, loss = 0.6414
# cuda
# Got 21236 / 30000 correct (70.79)
#
# Iteration 500, loss = 0.6359
# cuda
# Got 21382 / 30000 correct (71.27)
#
# Iteration 600, loss = 0.6418
# cuda
# Got 21298 / 30000 correct (70.99)
#
# Iteration 700, loss = 0.6598
# cuda
# Got 21314 / 30000 correct (71.05)
#
# cuda
# Got 127241 / 180000 correct (70.69)
# cuda
# Got 21157 / 30000 correct (70.52)
#
# Epoch 7/60:
# Iteration 0, loss = 0.6366
# cuda
# Got 21210 / 30000 correct (70.70)
#
# Iteration 100, loss = 0.6303
# cuda
# Got 21253 / 30000 correct (70.84)
#
# Iteration 200, loss = 0.6347
# cuda
# Got 21449 / 30000 correct (71.50)
#
# Iteration 300, loss = 0.6324
# cuda
# Got 21476 / 30000 correct (71.59)
#
# Iteration 400, loss = 0.6170
# cuda
# Got 21545 / 30000 correct (71.82)
#
# Iteration 500, loss = 0.6668
# cuda
# Got 21489 / 30000 correct (71.63)
#
# Iteration 600, loss = 0.5750
# cuda
# Got 21641 / 30000 correct (72.14)
#
# Iteration 700, loss = 0.6368
# cuda
# Got 21501 / 30000 correct (71.67)
#
# cuda
# Got 129437 / 180000 correct (71.91)
# cuda
# Got 21549 / 30000 correct (71.83)
#
# Epoch 8/60:
# Iteration 0, loss = 0.6396
# cuda
# Got 21536 / 30000 correct (71.79)
#
# Iteration 100, loss = 0.6044
# cuda
# Got 21467 / 30000 correct (71.56)
#
# Iteration 200, loss = 0.6401
# cuda
# Got 21559 / 30000 correct (71.86)
#
# Iteration 300, loss = 0.6134
# cuda
# Got 21748 / 30000 correct (72.49)
#
# Iteration 400, loss = 0.5483
# cuda
# Got 21766 / 30000 correct (72.55)
#
# Iteration 500, loss = 0.6101
# cuda
# Got 21784 / 30000 correct (72.61)
#
# Iteration 600, loss = 0.6233
# cuda
# Got 21771 / 30000 correct (72.57)
#
# Iteration 700, loss = 0.6048
# cuda
# Got 21781 / 30000 correct (72.60)
#
# cuda
# Got 131011 / 180000 correct (72.78)
# cuda
# Got 21874 / 30000 correct (72.91)
#
# Epoch 9/60:
# Iteration 0, loss = 0.5702
# cuda
# Got 21816 / 30000 correct (72.72)
#
# Iteration 100, loss = 0.6565
# cuda
# Got 21831 / 30000 correct (72.77)
#
# Iteration 200, loss = 0.5887
# cuda
# Got 21842 / 30000 correct (72.81)
#
# Iteration 300, loss = 0.5657
# cuda
# Got 21843 / 30000 correct (72.81)
#
# Iteration 400, loss = 0.5967
# cuda
# Got 21812 / 30000 correct (72.71)
#
# Iteration 500, loss = 0.5896
# cuda
# Got 21849 / 30000 correct (72.83)
#
# Iteration 600, loss = 0.6043
# cuda
# Got 21953 / 30000 correct (73.18)
#
# Iteration 700, loss = 0.5989
# cuda
# Got 21894 / 30000 correct (72.98)
#
# cuda
# Got 131596 / 180000 correct (73.11)
# cuda
# Got 21953 / 30000 correct (73.18)
#
# Epoch 10/60:
# Iteration 0, loss = 0.5875
# cuda
# Got 21864 / 30000 correct (72.88)
#
# Iteration 100, loss = 0.5668
# cuda
# Got 21974 / 30000 correct (73.25)
#
# Iteration 200, loss = 0.5981
# cuda
# Got 21939 / 30000 correct (73.13)
#
# Iteration 300, loss = 0.5672
# cuda
# Got 21914 / 30000 correct (73.05)
#
# Iteration 400, loss = 0.5420
# cuda
# Got 22013 / 30000 correct (73.38)
#
# Iteration 500, loss = 0.5296
# cuda
# Got 21974 / 30000 correct (73.25)
#
# Iteration 600, loss = 0.5306
# cuda
# Got 22085 / 30000 correct (73.62)
#
# Iteration 700, loss = 0.5420
# cuda
# Got 22076 / 30000 correct (73.59)
#
# cuda
# Got 132344 / 180000 correct (73.52)
# cuda
# Got 22050 / 30000 correct (73.50)
#
# Epoch 11/60:
# Iteration 0, loss = 0.6001
# cuda
# Got 22041 / 30000 correct (73.47)
#
# Iteration 100, loss = 0.5998
# cuda
# Got 21991 / 30000 correct (73.30)
#
# Iteration 200, loss = 0.5884
# cuda
# Got 22082 / 30000 correct (73.61)
#
# Iteration 300, loss = 0.5039
# cuda
# Got 22072 / 30000 correct (73.57)
#
# Iteration 400, loss = 0.5717
# cuda
# Got 22004 / 30000 correct (73.35)
#
# Iteration 500, loss = 0.5951
# cuda
# Got 21994 / 30000 correct (73.31)
#
# Iteration 600, loss = 0.5765
# cuda
# Got 22076 / 30000 correct (73.59)
#
# Iteration 700, loss = 0.5551
# cuda
# Got 22126 / 30000 correct (73.75)
#
# cuda
# Got 132225 / 180000 correct (73.46)
# cuda
# Got 22030 / 30000 correct (73.43)
#
# Epoch 12/60:
# Iteration 0, loss = 0.5721
# cuda
# Got 22131 / 30000 correct (73.77)
#
# Iteration 100, loss = 0.6017
# cuda
# Got 22053 / 30000 correct (73.51)
#
# Iteration 200, loss = 0.5324
# cuda
# Got 22160 / 30000 correct (73.87)
#
# Iteration 300, loss = 0.5501
# cuda
# Got 22105 / 30000 correct (73.68)
#
# Iteration 400, loss = 0.6127
# cuda
# Got 22110 / 30000 correct (73.70)
#
# Iteration 500, loss = 0.5355
# cuda
# Got 22163 / 30000 correct (73.88)
#
# Iteration 600, loss = 0.5522
# cuda
# Got 22157 / 30000 correct (73.86)
#
# Iteration 700, loss = 0.5042
# cuda
# Got 22220 / 30000 correct (74.07)
#
# cuda
# Got 133016 / 180000 correct (73.90)
# cuda
# Got 22187 / 30000 correct (73.96)
#
# Epoch 13/60:
# Iteration 0, loss = 0.5353
# cuda
# Got 22205 / 30000 correct (74.02)
#
# Iteration 100, loss = 0.5251
# cuda
# Got 22223 / 30000 correct (74.08)
#
# Iteration 200, loss = 0.5395
# cuda
# Got 22175 / 30000 correct (73.92)
#
# Iteration 300, loss = 0.6285
# cuda
# Got 22133 / 30000 correct (73.78)
#
# Iteration 400, loss = 0.5215
# cuda
# Got 22143 / 30000 correct (73.81)
#
# Iteration 500, loss = 0.5308
# cuda
# Got 22222 / 30000 correct (74.07)
#
# Iteration 600, loss = 0.5911
# cuda
# Got 22162 / 30000 correct (73.87)
# Iteration 700, loss = 0.5538
# cuda
# Got 22269 / 30000 correct (74.23)
#
# cuda
# Got 133624 / 180000 correct (74.24)
# cuda
# Got 22292 / 30000 correct (74.31)
#
# Epoch 14/60:
# Iteration 0, loss = 0.5299
# cuda
# Got 22274 / 30000 correct (74.25)
#
# Iteration 100, loss = 0.5077
# cuda
# Got 22279 / 30000 correct (74.26)
#
# Iteration 200, loss = 0.5859
# cuda
# Got 22152 / 30000 correct (73.84)
#
# Iteration 300, loss = 0.5041
# cuda
# Got 22254 / 30000 correct (74.18)
#
# Iteration 400, loss = 0.5200
# cuda
# Got 22164 / 30000 correct (73.88)
#
# Iteration 500, loss = 0.5328
# cuda
# Got 22267 / 30000 correct (74.22)
#
# Iteration 600, loss = 0.5847
# cuda
# Got 22196 / 30000 correct (73.99)
#
# Iteration 700, loss = 0.5149
# cuda
# Got 22308 / 30000 correct (74.36)
#
# cuda
# Got 133712 / 180000 correct (74.28)
# cuda
# Got 22366 / 30000 correct (74.55)
#
# Epoch 15/60:
# Iteration 0, loss = 0.5674
# cuda
# Got 22328 / 30000 correct (74.43)
#
# Iteration 100, loss = 0.5081
# cuda
# Got 22302 / 30000 correct (74.34)
#
# Iteration 200, loss = 0.4726
# cuda
# Got 22245 / 30000 correct (74.15)
#
# Iteration 300, loss = 0.5518
# cuda
# Got 22169 / 30000 correct (73.90)
#
# Iteration 400, loss = 0.4958
# cuda
# Got 22319 / 30000 correct (74.40)
#
# Iteration 500, loss = 0.4814
# cuda
# Got 22269 / 30000 correct (74.23)
#
# Iteration 600, loss = 0.5515
# cuda
# Got 22273 / 30000 correct (74.24)
#
# Iteration 700, loss = 0.5415
# cuda
# Got 22299 / 30000 correct (74.33)
#
# cuda
# Got 133006 / 180000 correct (73.89)
# cuda
# Got 22171 / 30000 correct (73.90)
#
# Epoch 16/60:
# Iteration 0, loss = 0.4871
# cuda
# Got 22214 / 30000 correct (74.05)
#
# Iteration 100, loss = 0.4744
# cuda
# Got 22278 / 30000 correct (74.26)
#
# Iteration 200, loss = 0.5739
# cuda
# Got 22301 / 30000 correct (74.34)
#
# Iteration 300, loss = 0.4838
# cuda
# Got 22333 / 30000 correct (74.44)
#
# Iteration 400, loss = 0.5043
# cuda
# Got 22327 / 30000 correct (74.42)
#
# Iteration 500, loss = 0.4624
# cuda
# Got 22350 / 30000 correct (74.50)
#
# Iteration 600, loss = 0.5078
# cuda
# Got 22363 / 30000 correct (74.54)
#
# Iteration 700, loss = 0.4995
# cuda
# Got 22398 / 30000 correct (74.66)
#
# cuda
# Got 134096 / 180000 correct (74.50)
# cuda
# Got 22331 / 30000 correct (74.44)
#
# Epoch 17/60:
# Iteration 0, loss = 0.4754
# cuda
# Got 22350 / 30000 correct (74.50)
#
# Iteration 100, loss = 0.5691
# cuda
# Got 22316 / 30000 correct (74.39)
#
# Iteration 200, loss = 0.5067
# cuda
# Got 22336 / 30000 correct (74.45)
#
# Iteration 300, loss = 0.4864
# cuda
# Got 22393 / 30000 correct (74.64)
#
# Iteration 400, loss = 0.4910
# cuda
# Got 22318 / 30000 correct (74.39)
#
# Iteration 500, loss = 0.5242
# cuda
# Got 22311 / 30000 correct (74.37)
#
# Iteration 600, loss = 0.5173
# cuda
# Got 22293 / 30000 correct (74.31)
#
# Iteration 700, loss = 0.5025
# cuda
# Got 22392 / 30000 correct (74.64)
#
# cuda
# Got 134235 / 180000 correct (74.58)
# cuda
# Got 22382 / 30000 correct (74.61)
#
# Epoch 18/60:
# Iteration 0, loss = 0.4696
# cuda
# Got 22418 / 30000 correct (74.73)
#
# Iteration 100, loss = 0.5482
# cuda
# Got 22349 / 30000 correct (74.50)
#
# Iteration 200, loss = 0.5741
# cuda
# Got 22345 / 30000 correct (74.48)
#
# Iteration 300, loss = 0.4459
# cuda
# Got 22360 / 30000 correct (74.53)
#
# Iteration 400, loss = 0.4703
# cuda
# Got 22346 / 30000 correct (74.49)
#
# Iteration 500, loss = 0.4527
# cuda
# Got 22384 / 30000 correct (74.61)
#
# Iteration 600, loss = 0.5042
# cuda
# Got 22302 / 30000 correct (74.34)
#
# Iteration 700, loss = 0.5415
# cuda
# Got 22394 / 30000 correct (74.65)
#
# cuda
# Got 134307 / 180000 correct (74.61)
# cuda
# Got 22402 / 30000 correct (74.67)
#
# Epoch 19/60:
# Iteration 0, loss = 0.5413
# cuda
# Got 22409 / 30000 correct (74.70)
#
# Iteration 100, loss = 0.4823
# cuda
# Got 22333 / 30000 correct (74.44)
#
# Iteration 200, loss = 0.4799
# cuda
# Got 22434 / 30000 correct (74.78)
#
# Iteration 300, loss = 0.5073
# cuda
# Got 22396 / 30000 correct (74.65)
#
# Iteration 400, loss = 0.5213
# cuda
# Got 22473 / 30000 correct (74.91)
#
# Iteration 500, loss = 0.5705
# cuda
# Got 22299 / 30000 correct (74.33)
#
# Iteration 600, loss = 0.5192
# cuda
# Got 22356 / 30000 correct (74.52)
#
# Iteration 700, loss = 0.4982
# cuda
# Got 22435 / 30000 correct (74.78)
#
# cuda
# Got 134274 / 180000 correct (74.60)
# cuda
# Got 22406 / 30000 correct (74.69)
#
# Epoch 20/60:
# Iteration 0, loss = 0.5485
# cuda
# Got 22386 / 30000 correct (74.62)
#
# Iteration 100, loss = 0.5060
# cuda
# Got 22368 / 30000 correct (74.56)
#
# Iteration 200, loss = 0.4685
# cuda
# Got 22458 / 30000 correct (74.86)
#
# Iteration 300, loss = 0.4910
# cuda
# Got 22358 / 30000 correct (74.53)
#
# Iteration 400, loss = 0.5584
# cuda
# Got 22309 / 30000 correct (74.36)
#
# Iteration 500, loss = 0.5293
# cuda
# Got 22412 / 30000 correct (74.71)
#
# Iteration 600, loss = 0.4771
# cuda
# Got 22423 / 30000 correct (74.74)
#
# Iteration 700, loss = 0.6525
# cuda
# Got 22398 / 30000 correct (74.66)
#
# cuda
# Got 134696 / 180000 correct (74.83)
# cuda
# Got 22406 / 30000 correct (74.69)
#
# Epoch 21/60:
# Iteration 0, loss = 0.4852
# cuda
# Got 22391 / 30000 correct (74.64)
#
# Iteration 100, loss = 0.4605
# cuda
# Got 22432 / 30000 correct (74.77)
#
# Iteration 200, loss = 0.5010
# cuda
# Got 22440 / 30000 correct (74.80)
#
# Iteration 300, loss = 0.5016
# cuda
# Got 22400 / 30000 correct (74.67)
#
# Iteration 400, loss = 0.4985
# cuda
# Got 22287 / 30000 correct (74.29)
#
# Iteration 500, loss = 0.4859
# cuda
# Got 22335 / 30000 correct (74.45)
#
# Iteration 600, loss = 0.5595
# cuda
# Got 22436 / 30000 correct (74.79)
#
# Iteration 700, loss = 0.4940
# cuda
# Got 22454 / 30000 correct (74.85)
#
# cuda

# %%
check_accuracy(loader_val, myModel)
# Out:
# cuda
# Got 22778 / 30000 correct (75.93)

# %% [markdown]
# ## Plot the loss and accuracy curves
#
# - I'm only calculating the accuracies after each epoch, because it was prohibitively slow when I was printing after each iteration.

# %%
trainingMetrics(history)

# %% [markdown]
# ## Discriminant plots / ROC Curves
#
# Ok, so for the ROC curves, use the discriminant
#
# $$D_\gamma = \frac{p_\gamma}{p_\pi + p_e}$$
#
# Where $p_i$ corresponds to the output of the softmax node, and this discriminant separates a $\gamma$ signal from a $\pi$ and $e$ background, and we can define similar discriminants for $\pi^+$ or $e^+$ signal.

# %%
particles = ['gamma','pi','e']

for node in range(3):
    g_eff, pi_eff, e_eff = sigBkgEff(myModel, loader_val, node)
    mTag = '{}-sig_{}'.format(particles[node], myModel.modelName)
    
    # Plot the ROC curve using node as the signal and the other two as the bkg
    if node == 0:
        plotROC([g_eff, g_eff], [pi_eff, e_eff], ['$\pi^+$ rej', '$e^+$ rej'], title='$\gamma$ signal', tag=mTag)
    if node == 1:
        plotROC([pi_eff, pi_eff], [g_eff, e_eff], ['$\gamma$ rej', '$e^+$ rej'], title='$\pi^+$ signal', tag=mTag)
    elif node == 2:
        plotROC([e_eff, e_eff], [g_eff, pi_eff], ['$\gamma$ rej', '$\pi^+$ rej'], title='$e^+$ signal', tag=mTag)
# Out:
# ../plottingFcts.py:229: RuntimeWarning: divide by zero encountered in true_divide
#   plt.semilogy(teff, np.divide(1,beff), style, color=color, label=label)

# %% [markdown]
# **Notes:**
#
# To see which classes we tend to misclassify the most, look at the confusion matrix between the classes.

# %%
plotConfusion(myModel, loader_val, title="Multi Layer Perceptron Baseline")

# %% [markdown]
# # Other Experiments
#
# - I tried a fc model with more hidden neurons: 300-200-100 for 233k trainable parameters, training for 75 epochs with a learning rate $\alpha = 10^{-5}$, but the best validation accuracy I got was ()%, suggesting that my simpler 150-100-50 model was actually sufficiently complex for this architeture.
