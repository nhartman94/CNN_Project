# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Loading the other modules I have in parent directories
import sys
PYTHONPATH="../"
sys.path.append(PYTHONPATH)
from dataProcessing import getDataLoaders
from models import ThreeCNN, ThreeCNN_Module, rnn_2dCNN
from train import check_accuracy, train, train_ThreeCNN
from plottingFcts import trainingMetrics, sigBkgEff, plotROC

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
loader_train, loader_val, loader_test = getDataLoaders(batch_size=1024)

# %%
# establish network dimensions 
layer0_params = [1, 3, 3, 1, 1]
layer0_reduce = [1, 3, 93, 1, 1]

layer1_params = [1, 3, 3, 1, 1]
layer1_reduce = [1, 12, 9, 1, 1]

layer2_params = [1, 3, 3, 1, 1]
layer2_reduce = [1, 12, 3, 1, 1]

rnn_params = [18, 18, 1]

layer3_params = [1, 3, 3, 1, 1]

fc_params = [18, 150, 100, 50, 3, 0.5]

# %%
# Set up and train the model 
rnn_model = rnn_2dCNN(layer0_params, layer0_reduce, layer1_params, layer1_reduce, layer2_params, layer2_reduce, rnn_params, layer3_params, fc_params)

optimizer = optim.Adam(rnn_model.parameters(), lr=1e-5)

hist, bestModel = train(loader_train, loader_val, rnn_model, optimizer, epochs=60, returnBest=True)
# Out:
# Epoch 1/60:
# Iteration 0, loss = 1.1403
# cuda
# Got 8886 / 30000 correct (29.62)
#
# Iteration 100, loss = 1.1117
# cuda
# Got 9698 / 30000 correct (32.33)
#
# cuda
# Got 62442 / 180000 correct (34.69)
# cuda
# Got 10415 / 30000 correct (34.72)
#
# Epoch 2/60:
# Iteration 0, loss = 1.0894
# cuda
# Got 10507 / 30000 correct (35.02)
#
# Iteration 100, loss = 1.0731
# cuda
# Got 11422 / 30000 correct (38.07)
#
# cuda
# Got 73434 / 180000 correct (40.80)
# cuda
# Got 12179 / 30000 correct (40.60)
#
# Epoch 3/60:
# Iteration 0, loss = 1.0538
# cuda
# Got 12143 / 30000 correct (40.48)
#
# Iteration 100, loss = 1.0329
# cuda
# Got 13294 / 30000 correct (44.31)
#
# cuda
# Got 83968 / 180000 correct (46.65)
# cuda
# Got 14131 / 30000 correct (47.10)
#
# Epoch 4/60:
# Iteration 0, loss = 1.0115
# cuda
# Got 14006 / 30000 correct (46.69)
#
# Iteration 100, loss = 0.9773
# cuda
# Got 15018 / 30000 correct (50.06)
#
# cuda
# Got 93485 / 180000 correct (51.94)
# cuda
# Got 15551 / 30000 correct (51.84)
#
# Epoch 5/60:
# Iteration 0, loss = 0.9709
# cuda
# Got 15618 / 30000 correct (52.06)
#
# Iteration 100, loss = 0.9560
# cuda
# Got 16301 / 30000 correct (54.34)
#
# cuda
# Got 100817 / 180000 correct (56.01)
# cuda
# Got 16929 / 30000 correct (56.43)
#
# Epoch 6/60:
# Iteration 0, loss = 0.9467
# cuda
# Got 16744 / 30000 correct (55.81)
#
# Iteration 100, loss = 0.9164
# cuda
# Got 17391 / 30000 correct (57.97)
#
# cuda
# Got 106955 / 180000 correct (59.42)
# cuda
# Got 17664 / 30000 correct (58.88)
#
# Epoch 7/60:
# Iteration 0, loss = 0.9028
# cuda
# Got 17837 / 30000 correct (59.46)
#
# Iteration 100, loss = 0.8885
# cuda
# Got 18074 / 30000 correct (60.25)
#
# cuda
# Got 110711 / 180000 correct (61.51)
# cuda
# Got 18333 / 30000 correct (61.11)
#
# Epoch 8/60:
# Iteration 0, loss = 0.8808
# cuda
# Got 18300 / 30000 correct (61.00)
#
# Iteration 100, loss = 0.8677
# cuda
# Got 18684 / 30000 correct (62.28)
#
# cuda
# Got 113310 / 180000 correct (62.95)
# cuda
# Got 18895 / 30000 correct (62.98)
#
# Epoch 9/60:
# Iteration 0, loss = 0.8713
# cuda
# Got 18911 / 30000 correct (63.04)
#
# Iteration 100, loss = 0.8432
# cuda
# Got 18939 / 30000 correct (63.13)
#
# cuda
# Got 114866 / 180000 correct (63.81)
# cuda
# Got 19090 / 30000 correct (63.63)
#
# Epoch 10/60:
# Iteration 0, loss = 0.8383
# cuda
# Got 19137 / 30000 correct (63.79)
#
# Iteration 100, loss = 0.8347
# cuda
# Got 19185 / 30000 correct (63.95)
#
# cuda
# Got 116448 / 180000 correct (64.69)
# cuda
# Got 19327 / 30000 correct (64.42)
#
# Epoch 11/60:
# Iteration 0, loss = 0.8189
# cuda
# Got 19290 / 30000 correct (64.30)
#
# Iteration 100, loss = 0.8153
# cuda
# Got 19442 / 30000 correct (64.81)
#
# cuda
# Got 117094 / 180000 correct (65.05)
# cuda
# Got 19697 / 30000 correct (65.66)
#
# Epoch 12/60:
# Iteration 0, loss = 0.8085
# cuda
# Got 19566 / 30000 correct (65.22)
#
# Iteration 100, loss = 0.8037
# cuda
# Got 19615 / 30000 correct (65.38)
#
# cuda
# Got 117687 / 180000 correct (65.38)
# cuda
# Got 19578 / 30000 correct (65.26)
#
# Epoch 13/60:
# Iteration 0, loss = 0.7872
# cuda
# Got 19702 / 30000 correct (65.67)
#
# Iteration 100, loss = 0.7948
# cuda
# Got 19711 / 30000 correct (65.70)
#
# cuda
# Got 118325 / 180000 correct (65.74)
# cuda
# Got 19727 / 30000 correct (65.76)
#
# Epoch 14/60:
# Iteration 0, loss = 0.7796
# cuda
# Got 19773 / 30000 correct (65.91)
#
# Iteration 100, loss = 0.7463
# cuda
# Got 19785 / 30000 correct (65.95)
#
# cuda
# Got 118841 / 180000 correct (66.02)
# cuda
# Got 19894 / 30000 correct (66.31)
#
# Epoch 15/60:
# Iteration 0, loss = 0.7451
# cuda
# Got 19646 / 30000 correct (65.49)
#
# Iteration 100, loss = 0.7353
# cuda
# Got 19846 / 30000 correct (66.15)
#
# cuda
# Got 119002 / 180000 correct (66.11)
# cuda
# Got 19832 / 30000 correct (66.11)
#
# Epoch 16/60:
# Iteration 0, loss = 0.7439
# cuda
# Got 19742 / 30000 correct (65.81)
#
# Iteration 100, loss = 0.7365
# cuda
# Got 19939 / 30000 correct (66.46)
#
# cuda
# Got 119184 / 180000 correct (66.21)
# cuda
# Got 19850 / 30000 correct (66.17)
#
# Epoch 17/60:
# Iteration 0, loss = 0.7280
# cuda
# Got 19911 / 30000 correct (66.37)
#
# Iteration 100, loss = 0.7151
# cuda
# Got 19937 / 30000 correct (66.46)
#
# cuda
# Got 119654 / 180000 correct (66.47)
# cuda
# Got 19995 / 30000 correct (66.65)
#
# Epoch 18/60:
# Iteration 0, loss = 0.7188
# cuda
# Got 19969 / 30000 correct (66.56)
#
# Iteration 100, loss = 0.7162
# cuda
# Got 19900 / 30000 correct (66.33)
#
# cuda
# Got 120273 / 180000 correct (66.82)
# cuda
# Got 19927 / 30000 correct (66.42)
#
# Epoch 19/60:
# Iteration 0, loss = 0.7032
# cuda
# Got 20019 / 30000 correct (66.73)
#
# Iteration 100, loss = 0.6962
# cuda
# Got 19971 / 30000 correct (66.57)
#
# cuda
# Got 120127 / 180000 correct (66.74)
# cuda
# Got 20009 / 30000 correct (66.70)
#
# Epoch 20/60:
# Iteration 0, loss = 0.7052
# cuda
# Got 19948 / 30000 correct (66.49)
#
# Iteration 100, loss = 0.6967
# cuda
# Got 19978 / 30000 correct (66.59)
#
# cuda
# Got 120226 / 180000 correct (66.79)
# cuda
# Got 20023 / 30000 correct (66.74)
#
# Epoch 21/60:
# Iteration 0, loss = 0.6820
# cuda
# Got 20108 / 30000 correct (67.03)
#
# Iteration 100, loss = 0.6812
# cuda
# Got 20054 / 30000 correct (66.85)
#
# cuda
# Got 120734 / 180000 correct (67.07)
# cuda
# Got 20043 / 30000 correct (66.81)
#
# Epoch 22/60:
# Iteration 0, loss = 0.6744
# cuda
# Got 20114 / 30000 correct (67.05)
#
# Iteration 100, loss = 0.6582
# cuda
# Got 20113 / 30000 correct (67.04)
#
# cuda
# Got 121049 / 180000 correct (67.25)
# cuda
# Got 20199 / 30000 correct (67.33)
#
# Epoch 23/60:
# Iteration 0, loss = 0.6592
# cuda
# Got 20184 / 30000 correct (67.28)
#
# Iteration 100, loss = 0.6606
# cuda
# Got 20231 / 30000 correct (67.44)
#
# cuda
# Got 121302 / 180000 correct (67.39)
# cuda
# Got 20237 / 30000 correct (67.46)
#
# Epoch 24/60:
# Iteration 0, loss = 0.6753
# cuda
# Got 20249 / 30000 correct (67.50)
#
# Iteration 100, loss = 0.6631
# cuda
# Got 20171 / 30000 correct (67.24)
#
# cuda
# Got 121626 / 180000 correct (67.57)
# cuda
# Got 20213 / 30000 correct (67.38)
#
# Epoch 25/60:
# Iteration 0, loss = 0.6435
# cuda
# Got 20156 / 30000 correct (67.19)
#
# Iteration 100, loss = 0.6449
# cuda
# Got 20168 / 30000 correct (67.23)
#
# cuda
# Got 121677 / 180000 correct (67.60)
# cuda
# Got 20280 / 30000 correct (67.60)
#
# Epoch 26/60:
# Iteration 0, loss = 0.6399
# cuda
# Got 20365 / 30000 correct (67.88)
#
# Iteration 100, loss = 0.6315
# cuda
# Got 20357 / 30000 correct (67.86)
#
# cuda
# Got 122001 / 180000 correct (67.78)
# cuda
# Got 20475 / 30000 correct (68.25)
#
# Epoch 27/60:
# Iteration 0, loss = 0.6152
# cuda
# Got 20310 / 30000 correct (67.70)
#
# Iteration 100, loss = 0.6338
# cuda
# Got 20312 / 30000 correct (67.71)
#
# cuda
# Got 122300 / 180000 correct (67.94)
# cuda
# Got 20357 / 30000 correct (67.86)
#
# Epoch 28/60:
# Iteration 0, loss = 0.6515
# cuda
# Got 20322 / 30000 correct (67.74)
#
# Iteration 100, loss = 0.5946
# cuda
# Got 20285 / 30000 correct (67.62)
#
# cuda
# Got 122453 / 180000 correct (68.03)
# cuda
# Got 20368 / 30000 correct (67.89)
#
# Epoch 29/60:
# Iteration 0, loss = 0.6180
# cuda
# Got 20409 / 30000 correct (68.03)
#
# Iteration 100, loss = 0.6016
# cuda
# Got 20572 / 30000 correct (68.57)
#
# cuda
# Got 123114 / 180000 correct (68.40)
# cuda
# Got 20420 / 30000 correct (68.07)
#
# Epoch 30/60:
# Iteration 0, loss = 0.6380
# cuda
# Got 20425 / 30000 correct (68.08)
#
# Iteration 100, loss = 0.6066
# cuda
# Got 20600 / 30000 correct (68.67)
#
# cuda
# Got 123078 / 180000 correct (68.38)
# cuda
# Got 20603 / 30000 correct (68.68)
#
# Epoch 31/60:
# Iteration 0, loss = 0.6242
# cuda
# Got 20545 / 30000 correct (68.48)
#
# Iteration 100, loss = 0.6140
# cuda
# Got 20354 / 30000 correct (67.85)
#
# cuda
# Got 123257 / 180000 correct (68.48)
# cuda
# Got 20608 / 30000 correct (68.69)
#
# Epoch 32/60:
# Iteration 0, loss = 0.5961
# cuda
# Got 20503 / 30000 correct (68.34)
#
# Iteration 100, loss = 0.5900
# cuda
# Got 20652 / 30000 correct (68.84)
#
# cuda
# Got 123918 / 180000 correct (68.84)
# cuda
# Got 20571 / 30000 correct (68.57)
#
# Epoch 33/60:
# Iteration 0, loss = 0.5978
# cuda
# Got 20641 / 30000 correct (68.80)
#
# Iteration 100, loss = 0.5883
# cuda
# Got 20622 / 30000 correct (68.74)
#
# cuda
# Got 124274 / 180000 correct (69.04)
# cuda
# Got 20686 / 30000 correct (68.95)
#
# Epoch 34/60:
# Iteration 0, loss = 0.5830
# cuda
# Got 20758 / 30000 correct (69.19)
#
# Iteration 100, loss = 0.5816
# cuda
# Got 20826 / 30000 correct (69.42)
#
# cuda
# Got 124827 / 180000 correct (69.35)
# cuda
# Got 20785 / 30000 correct (69.28)
#
# Epoch 35/60:
# Iteration 0, loss = 0.5848
# cuda
# Got 20709 / 30000 correct (69.03)
#
# Iteration 100, loss = 0.6142
# cuda
# Got 20903 / 30000 correct (69.68)
#
# cuda
# Got 125323 / 180000 correct (69.62)
# cuda
# Got 20705 / 30000 correct (69.02)
#
# Epoch 36/60:
# Iteration 0, loss = 0.6002
# cuda
# Got 20756 / 30000 correct (69.19)
#
# Iteration 100, loss = 0.5732
# cuda
# Got 20856 / 30000 correct (69.52)
#
# cuda
# Got 125817 / 180000 correct (69.90)
# cuda
# Got 20753 / 30000 correct (69.18)
#
# Epoch 37/60:
# Iteration 0, loss = 0.5744
# cuda
# Got 20877 / 30000 correct (69.59)
#
# Iteration 100, loss = 0.5885
# cuda
# Got 20898 / 30000 correct (69.66)
#
# cuda
# Got 125737 / 180000 correct (69.85)
# cuda
# Got 20996 / 30000 correct (69.99)
#
# Epoch 38/60:
# Iteration 0, loss = 0.5683
# cuda
# Got 20957 / 30000 correct (69.86)
#
# Iteration 100, loss = 0.5841
# cuda
# Got 20921 / 30000 correct (69.74)
#
# cuda
# Got 126506 / 180000 correct (70.28)
# cuda
# Got 21049 / 30000 correct (70.16)
#
# Epoch 39/60:
# Iteration 0, loss = 0.5591
# cuda
# Got 21082 / 30000 correct (70.27)
#
# Iteration 100, loss = 0.5759
# cuda
# Got 21193 / 30000 correct (70.64)
#
# cuda
# Got 126733 / 180000 correct (70.41)
# cuda
# Got 21043 / 30000 correct (70.14)
#
# Epoch 40/60:
# Iteration 0, loss = 0.5551
# cuda
# Got 21107 / 30000 correct (70.36)
#
# Iteration 100, loss = 0.5547
# cuda
# Got 21133 / 30000 correct (70.44)
#
# cuda
# Got 127344 / 180000 correct (70.75)
# cuda
# Got 21156 / 30000 correct (70.52)
#
# Epoch 41/60:
# Iteration 0, loss = 0.5223
# cuda
# Got 21149 / 30000 correct (70.50)
#
# Iteration 100, loss = 0.5650
# cuda
# Got 21230 / 30000 correct (70.77)
#
# cuda
# Got 127571 / 180000 correct (70.87)
# cuda
# Got 21341 / 30000 correct (71.14)
#
# Epoch 42/60:
# Iteration 0, loss = 0.5554
# cuda
# Got 21262 / 30000 correct (70.87)
#
# Iteration 100, loss = 0.5622
# cuda
# Got 21355 / 30000 correct (71.18)
#
# cuda
# Got 128024 / 180000 correct (71.12)
# cuda
# Got 21347 / 30000 correct (71.16)
#
# Epoch 43/60:
# Iteration 0, loss = 0.5631
# cuda
# Got 21341 / 30000 correct (71.14)
#
# Iteration 100, loss = 0.5327
# cuda
# Got 21311 / 30000 correct (71.04)
#
# cuda
# Got 128714 / 180000 correct (71.51)
# cuda
# Got 21388 / 30000 correct (71.29)
#
# Epoch 44/60:
# Iteration 0, loss = 0.5625
# cuda
# Got 21436 / 30000 correct (71.45)
#
# Iteration 100, loss = 0.5636
# cuda
# Got 21524 / 30000 correct (71.75)
#
# cuda
# Got 129200 / 180000 correct (71.78)
# cuda
# Got 21524 / 30000 correct (71.75)
#
# Epoch 45/60:
# Iteration 0, loss = 0.5428
# cuda
# Got 21538 / 30000 correct (71.79)
#
# Iteration 100, loss = 0.5570
# cuda
# Got 21519 / 30000 correct (71.73)
#
# cuda
# Got 129747 / 180000 correct (72.08)
# cuda
# Got 21553 / 30000 correct (71.84)
#
# Epoch 46/60:
# Iteration 0, loss = 0.5406
# cuda
# Got 21537 / 30000 correct (71.79)
#
# Iteration 100, loss = 0.5434
# cuda
# Got 21616 / 30000 correct (72.05)
#
# cuda
# Got 129975 / 180000 correct (72.21)
# cuda
# Got 21652 / 30000 correct (72.17)
#
# Epoch 47/60:
# Iteration 0, loss = 0.5494
# cuda
# Got 21712 / 30000 correct (72.37)
#
# Iteration 100, loss = 0.5387
# cuda
# Got 21641 / 30000 correct (72.14)
#
# cuda
# Got 130380 / 180000 correct (72.43)
# cuda
# Got 21691 / 30000 correct (72.30)
#
# Epoch 48/60:
# Iteration 0, loss = 0.5346
# cuda
# Got 21663 / 30000 correct (72.21)
#
# Iteration 100, loss = 0.5456
# cuda
# Got 21655 / 30000 correct (72.18)
#
# cuda
# Got 130836 / 180000 correct (72.69)
# cuda
# Got 21734 / 30000 correct (72.45)
#
# Epoch 49/60:
# Iteration 0, loss = 0.5467
# cuda
# Got 21750 / 30000 correct (72.50)
#
# Iteration 100, loss = 0.5145
# cuda
# Got 21775 / 30000 correct (72.58)
#
# cuda
# Got 131123 / 180000 correct (72.85)
# cuda
# Got 21783 / 30000 correct (72.61)
#
# Epoch 50/60:
# Iteration 0, loss = 0.5035
# cuda
# Got 21850 / 30000 correct (72.83)
#
# Iteration 100, loss = 0.4998
# cuda
# Got 21890 / 30000 correct (72.97)
#
# cuda
# Got 131308 / 180000 correct (72.95)
# cuda
# Got 21884 / 30000 correct (72.95)
#
# Epoch 51/60:
# Iteration 0, loss = 0.5368
# cuda
# Got 21822 / 30000 correct (72.74)
#
# Iteration 100, loss = 0.5262
# cuda
# Got 21894 / 30000 correct (72.98)
#
# cuda
# Got 131653 / 180000 correct (73.14)
# cuda
# Got 21849 / 30000 correct (72.83)
#
# Epoch 52/60:
# Iteration 0, loss = 0.5306
# cuda
# Got 21925 / 30000 correct (73.08)
#
# Iteration 100, loss = 0.4985
# cuda
# Got 21894 / 30000 correct (72.98)
#
# cuda
# Got 131635 / 180000 correct (73.13)
# cuda
# Got 21938 / 30000 correct (73.13)
#
# Epoch 53/60:
# Iteration 0, loss = 0.4968
# cuda
# Got 21986 / 30000 correct (73.29)
#
# Iteration 100, loss = 0.5030
# cuda
# Got 21949 / 30000 correct (73.16)
#
# cuda
# Got 131914 / 180000 correct (73.29)
# cuda
# Got 21889 / 30000 correct (72.96)
#
# Epoch 54/60:
# Iteration 0, loss = 0.4884
# cuda
# Got 21946 / 30000 correct (73.15)
#
# Iteration 100, loss = 0.5152
# cuda
# Got 22023 / 30000 correct (73.41)
#
# cuda
# Got 132123 / 180000 correct (73.40)
# cuda
# Got 21995 / 30000 correct (73.32)
#
# Epoch 55/60:
# Iteration 0, loss = 0.4962
# cuda
# Got 21981 / 30000 correct (73.27)
#
# Iteration 100, loss = 0.4965
# cuda
# Got 21968 / 30000 correct (73.23)
#
# cuda
# Got 132110 / 180000 correct (73.39)
# cuda
# Got 22050 / 30000 correct (73.50)
#
# Epoch 56/60:
# Iteration 0, loss = 0.5066
# cuda
# Got 21987 / 30000 correct (73.29)
#
# Iteration 100, loss = 0.5022
# cuda
# Got 22098 / 30000 correct (73.66)
#
# cuda
# Got 132437 / 180000 correct (73.58)
# cuda
# Got 22054 / 30000 correct (73.51)
#
# Epoch 57/60:
# Iteration 0, loss = 0.4934
# cuda
# Got 22091 / 30000 correct (73.64)
#
# Iteration 100, loss = 0.4778
# cuda
# Got 22042 / 30000 correct (73.47)
#
# cuda
# Got 132387 / 180000 correct (73.55)
# cuda
# Got 22104 / 30000 correct (73.68)
#
# Epoch 58/60:
# Iteration 0, loss = 0.4950
# cuda
# Got 22104 / 30000 correct (73.68)
#
# Iteration 100, loss = 0.5140
# cuda
# Got 22074 / 30000 correct (73.58)
#
# cuda
# Got 132630 / 180000 correct (73.68)
# cuda
# Got 22008 / 30000 correct (73.36)
#
# Epoch 59/60:
# Iteration 0, loss = 0.5145
# cuda
# Got 22100 / 30000 correct (73.67)
#
# Iteration 100, loss = 0.4993
# cuda
# Got 22086 / 30000 correct (73.62)
#
# cuda
# Got 132810 / 180000 correct (73.78)
# cuda
# Got 22065 / 30000 correct (73.55)
#
# Epoch 60/60:
# Iteration 0, loss = 0.5004
# cuda
# Got 22107 / 30000 correct (73.69)
#
# Iteration 100, loss = 0.4963
# cuda
# Got 22003 / 30000 correct (73.34)
#
# cuda
# Got 133114 / 180000 correct (73.95)
# cuda
# Got 22106 / 30000 correct (73.69)

# %%
trainingMetrics(hist)

# %% [markdown]
# Note how the training and validation accuracy are tracking one another almost exactly--Nikhil suggested that we increase the number of filters in out convolutional layers (since before we only had one filter for each preprocessing layer)

# %%
"""
Only had one filter in the intial preprocessing CNN layers; increasing this to 32 filters.  
"""
layer0_params_2 = [32, 3, 3, 1, 1]
layer0_reduce_2 = [1, 3, 93, 1, 1] # ---> Downsampling with one filter at the end

layer1_params_2 = [32, 3, 3, 1, 1]
layer1_reduce_2 = [1, 12, 9, 1, 1] # ---> Downsampling with one filter 

layer2_params_2 = [32, 3, 3, 1, 1]
layer2_reduce_2 = [1, 12, 3, 1, 1] # --> downsampling with one filter 

rnn_params_2 = [18, 18, 1]

layer3_params_2 = [32, 3, 3, 1, 1]

fc_params_2 = [576, 150, 100, 50, 3, 0.5]

# %%
rnn_model_2 = rnn_2dCNN(layer0_params_2, layer0_reduce_2, layer1_params_2, layer1_reduce_2, layer2_params_2, layer2_reduce_2, rnn_params_2, layer3_params_2, fc_params_2)

optimizer_2 = optim.Adam(rnn_model_2.parameters(), lr=1e-5)

hist_2, bestModel_2 = train(loader_train, loader_val, rnn_model_2, optimizer_2, epochs=30, returnBest=True)
# Out:
# Epoch 1/30:
# Iteration 0, loss = 1.1604
# cuda
# Got 10086 / 30000 correct (33.62)
#
# Iteration 100, loss = 1.0437
# cuda
# Got 12250 / 30000 correct (40.83)
#
# cuda
# Got 82443 / 180000 correct (45.80)
# cuda
# Got 13665 / 30000 correct (45.55)
#
# Epoch 2/30:
# Iteration 0, loss = 1.0014
# cuda
# Got 13740 / 30000 correct (45.80)
#
# Iteration 100, loss = 0.9816
# cuda
# Got 15258 / 30000 correct (50.86)
#
# cuda
# Got 98771 / 180000 correct (54.87)
# cuda
# Got 16447 / 30000 correct (54.82)
#
# Epoch 3/30:
# Iteration 0, loss = 0.9636
# cuda
# Got 16457 / 30000 correct (54.86)
#
# Iteration 100, loss = 0.9386
# cuda
# Got 17781 / 30000 correct (59.27)
#
# cuda
# Got 111669 / 180000 correct (62.04)
# cuda
# Got 18461 / 30000 correct (61.54)
#
# Epoch 4/30:
# Iteration 0, loss = 0.9302
# cuda
# Got 18618 / 30000 correct (62.06)
#
# Iteration 100, loss = 0.8946
# cuda
# Got 19360 / 30000 correct (64.53)
#
# cuda
# Got 119403 / 180000 correct (66.33)
# cuda
# Got 20009 / 30000 correct (66.70)
#
# Epoch 5/30:
# Iteration 0, loss = 0.8929
# cuda
# Got 19918 / 30000 correct (66.39)
#
# Iteration 100, loss = 0.8897
# cuda
# Got 20448 / 30000 correct (68.16)
#
# cuda
# Got 124816 / 180000 correct (69.34)
# cuda
# Got 20830 / 30000 correct (69.43)
#
# Epoch 6/30:
# Iteration 0, loss = 0.8660
# cuda
# Got 20813 / 30000 correct (69.38)
#
# Iteration 100, loss = 0.8517
# cuda
# Got 21145 / 30000 correct (70.48)
#
# cuda
# Got 128078 / 180000 correct (71.15)
# cuda
# Got 21305 / 30000 correct (71.02)
#
# Epoch 7/30:
# Iteration 0, loss = 0.8433
# cuda
# Got 21260 / 30000 correct (70.87)
#
# Iteration 100, loss = 0.8368
# cuda
# Got 21556 / 30000 correct (71.85)
#
# cuda
# Got 130032 / 180000 correct (72.24)
# cuda
# Got 21675 / 30000 correct (72.25)
#
# Epoch 8/30:
# Iteration 0, loss = 0.8210
# cuda
# Got 21622 / 30000 correct (72.07)
#
# Iteration 100, loss = 0.8011
# cuda
# Got 21884 / 30000 correct (72.95)
#
# cuda
# Got 132072 / 180000 correct (73.37)
# cuda
# Got 21956 / 30000 correct (73.19)
#
# Epoch 9/30:
# Iteration 0, loss = 0.7998
# cuda
# Got 21981 / 30000 correct (73.27)
#
# Iteration 100, loss = 0.7891
# cuda
# Got 22100 / 30000 correct (73.67)
#
# cuda
# Got 133249 / 180000 correct (74.03)
# cuda
# Got 22209 / 30000 correct (74.03)
#
# Epoch 10/30:
# Iteration 0, loss = 0.7734
# cuda
# Got 22176 / 30000 correct (73.92)
#
# Iteration 100, loss = 0.7711
# cuda
# Got 22165 / 30000 correct (73.88)
#
# cuda
# Got 133945 / 180000 correct (74.41)
# cuda
# Got 22243 / 30000 correct (74.14)
#
# Epoch 11/30:
# Iteration 0, loss = 0.7631
# cuda
# Got 22244 / 30000 correct (74.15)
#
# Iteration 100, loss = 0.7521
# cuda
# Got 22481 / 30000 correct (74.94)
#
# cuda
# Got 135326 / 180000 correct (75.18)
# cuda
# Got 22569 / 30000 correct (75.23)
#
# Epoch 12/30:
# Iteration 0, loss = 0.7490
# cuda
# Got 22556 / 30000 correct (75.19)
#
# Iteration 100, loss = 0.7429
# cuda
# Got 22457 / 30000 correct (74.86)
#
# cuda
# Got 135768 / 180000 correct (75.43)
# cuda
# Got 22643 / 30000 correct (75.48)
#
# Epoch 13/30:
# Iteration 0, loss = 0.7340
# cuda
# Got 22663 / 30000 correct (75.54)
#
# Iteration 100, loss = 0.7317
# cuda
# Got 22624 / 30000 correct (75.41)
#
# cuda
# Got 136442 / 180000 correct (75.80)
# cuda
# Got 22655 / 30000 correct (75.52)
#
# Epoch 14/30:
# Iteration 0, loss = 0.7098
# cuda
# Got 22640 / 30000 correct (75.47)
#
# Iteration 100, loss = 0.7277
# cuda
# Got 22639 / 30000 correct (75.46)
#
# cuda
# Got 136950 / 180000 correct (76.08)
# cuda
# Got 22712 / 30000 correct (75.71)
#
# Epoch 15/30:
# Iteration 0, loss = 0.7024
# cuda
# Got 22619 / 30000 correct (75.40)
#
# Iteration 100, loss = 0.7021
# cuda
# Got 22830 / 30000 correct (76.10)
#
# cuda
# Got 136500 / 180000 correct (75.83)
# cuda
# Got 22650 / 30000 correct (75.50)
#
# Epoch 16/30:
# Iteration 0, loss = 0.6906
# cuda
# Got 22726 / 30000 correct (75.75)
#
# Iteration 100, loss = 0.6717
# cuda
# Got 22777 / 30000 correct (75.92)
#
# cuda
# Got 137385 / 180000 correct (76.33)
# cuda
# Got 22767 / 30000 correct (75.89)
#
# Epoch 17/30:
# Iteration 0, loss = 0.6849
# cuda
# Got 22791 / 30000 correct (75.97)
#
# Iteration 100, loss = 0.6694
# cuda
# Got 22808 / 30000 correct (76.03)
#
# cuda
# Got 137579 / 180000 correct (76.43)
# cuda
# Got 22877 / 30000 correct (76.26)
#
# Epoch 18/30:
# Iteration 0, loss = 0.6751
# cuda
# Got 22890 / 30000 correct (76.30)
#
# Iteration 100, loss = 0.6635
# cuda
# Got 22905 / 30000 correct (76.35)
#
# cuda
# Got 138045 / 180000 correct (76.69)
# cuda
# Got 22973 / 30000 correct (76.58)
#
# Epoch 19/30:
# Iteration 0, loss = 0.6653
# cuda
# Got 22935 / 30000 correct (76.45)
#
# Iteration 100, loss = 0.6511
# cuda
# Got 22916 / 30000 correct (76.39)
#
# cuda
# Got 138369 / 180000 correct (76.87)
# cuda
# Got 22958 / 30000 correct (76.53)
#
# Epoch 20/30:
# Iteration 0, loss = 0.6454
# cuda
# Got 22937 / 30000 correct (76.46)
#
# Iteration 100, loss = 0.6423
# cuda
# Got 23038 / 30000 correct (76.79)
#
# cuda
# Got 137795 / 180000 correct (76.55)
# cuda
# Got 22896 / 30000 correct (76.32)
#
# Epoch 21/30:
# Iteration 0, loss = 0.6426
# cuda
# Got 22852 / 30000 correct (76.17)
#
# Iteration 100, loss = 0.6380
# cuda
# Got 22977 / 30000 correct (76.59)
#
# cuda
# Got 138582 / 180000 correct (76.99)
# cuda
# Got 23004 / 30000 correct (76.68)
#
# Epoch 22/30:
# Iteration 0, loss = 0.6388
# cuda
# Got 23044 / 30000 correct (76.81)
#
# Iteration 100, loss = 0.6441
# cuda
# Got 23015 / 30000 correct (76.72)
#
# cuda
# Got 138699 / 180000 correct (77.05)
# cuda
# Got 23043 / 30000 correct (76.81)
#
# Epoch 23/30:
# Iteration 0, loss = 0.6170
# cuda
# Got 23001 / 30000 correct (76.67)
#
# Iteration 100, loss = 0.6106
# cuda
# Got 23023 / 30000 correct (76.74)
#
# cuda
# Got 138888 / 180000 correct (77.16)
# cuda
# Got 23086 / 30000 correct (76.95)
#
# Epoch 24/30:
# Iteration 0, loss = 0.6009
# cuda
# Got 23099 / 30000 correct (77.00)
#
# Iteration 100, loss = 0.6117
# cuda
# Got 23129 / 30000 correct (77.10)
#
# cuda
# Got 138808 / 180000 correct (77.12)
# cuda
# Got 23129 / 30000 correct (77.10)
#
# Epoch 25/30:
# Iteration 0, loss = 0.5994
# cuda
# Got 23103 / 30000 correct (77.01)
#
# Iteration 100, loss = 0.6031
# cuda
# Got 23055 / 30000 correct (76.85)
#
# cuda
# Got 138988 / 180000 correct (77.22)
# cuda
# Got 23070 / 30000 correct (76.90)
#
# Epoch 26/30:
# Iteration 0, loss = 0.6082
# cuda
# Got 23075 / 30000 correct (76.92)
#
# Iteration 100, loss = 0.5979
# cuda
# Got 23072 / 30000 correct (76.91)
#
# cuda
# Got 138888 / 180000 correct (77.16)
# cuda
# Got 23042 / 30000 correct (76.81)
#
# Epoch 27/30:
# Iteration 0, loss = 0.5892
# cuda
# Got 23040 / 30000 correct (76.80)
#
# Iteration 100, loss = 0.5843
# cuda
# Got 23022 / 30000 correct (76.74)
#
# cuda
# Got 139122 / 180000 correct (77.29)
# cuda
# Got 23163 / 30000 correct (77.21)
#
# Epoch 28/30:
# Iteration 0, loss = 0.5748
# cuda
# Got 23064 / 30000 correct (76.88)
#
# Iteration 100, loss = 0.5796
# cuda
# Got 23173 / 30000 correct (77.24)
#
# cuda
# Got 139166 / 180000 correct (77.31)
# cuda
# Got 23117 / 30000 correct (77.06)
#
# Epoch 29/30:
# Iteration 0, loss = 0.5856
# cuda
# Got 23174 / 30000 correct (77.25)
#
# Iteration 100, loss = 0.5700
# cuda
# Got 23092 / 30000 correct (76.97)
#
# cuda
# Got 139043 / 180000 correct (77.25)
# cuda
# Got 23121 / 30000 correct (77.07)
#
# Epoch 30/30:
# Iteration 0, loss = 0.5642
# cuda
# Got 23083 / 30000 correct (76.94)
#
# Iteration 100, loss = 0.5508
# cuda
# Got 23067 / 30000 correct (76.89)
#
# cuda
# Got 139169 / 180000 correct (77.32)
# cuda
# Got 23105 / 30000 correct (77.02)

# %%
trainingMetrics(hist_2)

# %%
# get ROC curves for model 
for node in range(3):
    g_eff, pi_eff, e_eff = sigBkgEff(bestModel_2, loader_val, node)
    
    # Plot the ROC curve using node as the signal and the other two as the bkg
    if node == 0:
        plotROC([g_eff, g_eff], [pi_eff, e_eff], ['$\pi^+$ rej', '$e^+$ rej'], title='$\gamma$ signal')
    if node == 1:
        plotROC([pi_eff, pi_eff], [g_eff, e_eff], ['$\gamma$ rej', '$e^+$ rej'], title='$\pi^+$ signal')
    elif node == 2:
        plotROC([e_eff, e_eff], [g_eff, pi_eff], ['$\gamma$ rej', '$\pi^+$ rej'], title='$e^+$ signal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6081e0bbcca8> in <module>()
#       1 # get ROC curves for model
#       2 for node in range(3):
# ----> 3     g_eff, pi_eff, e_eff = sigBkgEff(bestModel_2, loader_val, node)
#       4
#       5     # Plot the ROC curve using node as the signal and the other two as the bkg
#
# NameError: name 'bestModel_2' is not defined

# %%
#rnn_pres = rnn_2dCNN(layer0_params_2, layer0_reduce_2, layer1_params_2, layer1_reduce_2, layer2_params_2, layer2_reduce_2, rnn_params_2, layer3_params_2, fc_params_2)

rnn_pres =torch.load('../models/rnn_model.pth.tar')

# %%
# get ROC curves for model 
for node in range(3):
    g_eff, pi_eff, e_eff = sigBkgEff(rnn_pres, loader_val, node)
    
    # Plot the ROC curve using node as the signal and the other two as the bkg
    if node == 0:
        plotROC([g_eff, g_eff], [pi_eff, e_eff], ['$\pi^+$ rej', '$e^+$ rej'], title='$\gamma$ signal')
    if node == 1:
        plotROC([pi_eff, pi_eff], [g_eff, e_eff], ['$\gamma$ rej', '$e^+$ rej'], title='$\pi^+$ signal')
    elif node == 2:
        plotROC([e_eff, e_eff], [g_eff, pi_eff], ['$\gamma$ rej', '$\pi^+$ rej'], title='$e^+$ signal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-37f4980ab382> in <module>()
#       1 # get ROC curves for model
#       2 for node in range(3):
# ----> 3     g_eff, pi_eff, e_eff = sigBkgEff(rnn_pres, loader_val, node)
#       4
#       5     # Plot the ROC curve using node as the signal and the other two as the bkg
#
# ~/CNN_Project/plottingFcts.py in sigBkgEff(m, loader, signalNode)
#      88             l2 = l2.to(device=device, dtype=dtype)
#      89             y = y.to(device=device, dtype=torch.long)
# ---> 90             scores = m(l0, l1, l2)
#      91             probs = Softmax(dim=1)(scores)
#      92             predictions.append(probs.cpu().numpy())
#
# TypeError: 'collections.OrderedDict' object is not callable
