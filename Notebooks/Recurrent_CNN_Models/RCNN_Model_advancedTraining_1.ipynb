# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Loading the other modules I have in parent directories
import sys
PYTHONPATH="../"
sys.path.append(PYTHONPATH)
from dataProcessing import getDataLoaders
from models import ThreeCNN, ThreeCNN_Module, rnn_2dCNN
from train import check_accuracy, train, train_ThreeCNN
from plottingFcts import trainingMetrics, sigBkgEff, plotROC
from imageNumber_analysis import num_valAcc 
from learn_rate_optimize import filters_optimize, lr_optimize, lr_filters_optimize
import matplotlib.pyplot as plt

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload
# Out:
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# cuda

# %%
layer0_params = [32, 3, 3, 1, 1]
layer0_reduce = [1, 3, 93, 1, 1] # ---> Downsampling with one filter at the end

layer1_params = [32, 3, 3, 1, 1]
layer1_reduce = [1, 12, 9, 1, 1] # ---> Downsampling with one filter 

layer2_params = [32, 3, 3, 1, 1]
layer2_reduce = [1, 12, 3, 1, 1] # ---> downsampling with one filter 

rnn_params = [18, 18, 1]

layer3_params = [32, 3, 3, 1, 1]

fc_params = [18, 150, 100, 50, 3, 0.5]

# %%
# experiment 1 batch size: 64, image number: 30,000
# experiment 2 batch size: 1000, image number: 80,000 
batch_size = 1000
loader_train, loader_val, loader_test = getDataLoaders(batch_size=batch_size, N=80000)

# %%
advanced_rnn_1 = rnn_2dCNN(layer0_params, layer0_reduce, layer1_params, layer1_reduce, layer2_params, layer2_reduce, rnn_params, layer3_params, fc_params)

adv_optimizer = optim.Adam(advanced_rnn_1.parameters(), lr=4e-3)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(adv_optimizer, mode='max', patience=5, verbose=True)

hist, advModel = train(loader_train, loader_val, advanced_rnn_1, adv_optimizer, scheduler, epochs=50, returnBest=True)

# save the best model from training for 100 epochs 
torch.save(advModel.state_dict(), "../models/advTraining_1.pth.tar")
# Out:
# cuda
#
# Epoch 1/50:
# Iteration 0, loss = 1.2421
# cuda
# Got 2686 / 9000 correct (29.84)
#
# Iteration 100, loss = 0.6108
# cuda
# Got 6398 / 9000 correct (71.09)
#
# Iteration 200, loss = 0.5646
# cuda
# Got 6226 / 9000 correct (69.18)
#
# Iteration 300, loss = 0.5044
# cuda
# Got 6254 / 9000 correct (69.49)
#
# Iteration 400, loss = 0.5411
# cuda
# Got 6629 / 9000 correct (73.66)
#
# Iteration 500, loss = 0.4680
# cuda
# Got 6572 / 9000 correct (73.02)
#
# Iteration 600, loss = 0.4317
# cuda
# Got 6632 / 9000 correct (73.69)
#
# Iteration 700, loss = 0.5538
# cuda
# Got 6678 / 9000 correct (74.20)
#
# Iteration 800, loss = 0.5214
# cuda
# Got 6513 / 9000 correct (72.37)
#
# cuda
# Got 6721 / 9000 correct (74.68)
# cuda
# Got 40180 / 54000 correct (74.41)
#
# Epoch 2/50:
# Iteration 0, loss = 0.4407
# cuda
# Got 6677 / 9000 correct (74.19)
#
# Iteration 100, loss = 0.4089
# cuda
# Got 6714 / 9000 correct (74.60)
#
# Iteration 200, loss = 0.5499
# cuda
# Got 6707 / 9000 correct (74.52)
#
# Iteration 300, loss = 0.4441
# cuda
# Got 6698 / 9000 correct (74.42)
#
# Iteration 400, loss = 0.4807
# cuda
# Got 6804 / 9000 correct (75.60)
#
# Iteration 500, loss = 0.4471
# cuda
# Got 6754 / 9000 correct (75.04)
#
# Iteration 600, loss = 0.4592
# cuda
# Got 6775 / 9000 correct (75.28)
#
# Iteration 700, loss = 0.3159
# cuda
# Got 6768 / 9000 correct (75.20)
#
# Iteration 800, loss = 0.4154
# cuda
# Got 6633 / 9000 correct (73.70)
#
# cuda
# Got 6774 / 9000 correct (75.27)
# cuda
# Got 40654 / 54000 correct (75.29)
#
# Epoch 3/50:
# Iteration 0, loss = 0.4238
# cuda
# Got 6800 / 9000 correct (75.56)
#
# Iteration 100, loss = 0.4142
# cuda
# Got 6785 / 9000 correct (75.39)
#
# Iteration 200, loss = 0.3779
# cuda
# Got 6783 / 9000 correct (75.37)
#
# Iteration 300, loss = 0.4965
# cuda
# Got 6844 / 9000 correct (76.04)
#
# Iteration 400, loss = 0.3730
# cuda
# Got 6865 / 9000 correct (76.28)
#
# Iteration 500, loss = 0.4391
# cuda
# Got 6803 / 9000 correct (75.59)
#
# Iteration 600, loss = 0.4475
# cuda
# Got 6756 / 9000 correct (75.07)
#
# Iteration 700, loss = 0.4824
# cuda
# Got 6839 / 9000 correct (75.99)
#
# Iteration 800, loss = 0.5603
# cuda
# Got 6835 / 9000 correct (75.94)
#
# cuda
# Got 6840 / 9000 correct (76.00)
# cuda
# Got 40977 / 54000 correct (75.88)
#
# Epoch 4/50:
# Iteration 0, loss = 0.4028
# cuda
# Got 6851 / 9000 correct (76.12)
#
# Iteration 100, loss = 0.3722
# cuda
# Got 6810 / 9000 correct (75.67)
#
# Iteration 200, loss = 0.4161
# cuda
# Got 6764 / 9000 correct (75.16)
#
# Iteration 300, loss = 0.3607
# cuda
# Got 6826 / 9000 correct (75.84)
#
# Iteration 400, loss = 0.3920
# cuda
# Got 6830 / 9000 correct (75.89)
#
# Iteration 500, loss = 0.4025
# cuda
# Got 6868 / 9000 correct (76.31)
#
# Iteration 600, loss = 0.4790
# cuda
# Got 6869 / 9000 correct (76.32)
#
# Iteration 700, loss = 0.5010
# cuda
# Got 6771 / 9000 correct (75.23)
#
# Iteration 800, loss = 0.5314
# cuda
# Got 6845 / 9000 correct (76.06)
#
# cuda
# Got 6805 / 9000 correct (75.61)
# cuda
# Got 40906 / 54000 correct (75.75)
#
# Epoch 5/50:
# Iteration 0, loss = 0.5056
# cuda
# Got 6842 / 9000 correct (76.02)
#
# Iteration 100, loss = 0.4278
# cuda
# Got 6833 / 9000 correct (75.92)
#
# Iteration 200, loss = 0.5286
# cuda
# Got 6877 / 9000 correct (76.41)
#
# Iteration 300, loss = 0.4213
# cuda
# Got 6814 / 9000 correct (75.71)
#
# Iteration 400, loss = 0.5544
# cuda
# Got 6857 / 9000 correct (76.19)
#
# Iteration 500, loss = 0.3811
# cuda
# Got 6860 / 9000 correct (76.22)
#
# Iteration 600, loss = 0.3854
# cuda
# Got 6876 / 9000 correct (76.40)
#
# Iteration 700, loss = 0.4028
# cuda
# Got 6870 / 9000 correct (76.33)
#
# Iteration 800, loss = 0.3904
# cuda
# Got 6823 / 9000 correct (75.81)
#
# cuda
# Got 6810 / 9000 correct (75.67)
# cuda
# Got 40961 / 54000 correct (75.85)
#
# Epoch 6/50:
# Iteration 0, loss = 0.4629
# cuda
# Got 6804 / 9000 correct (75.60)
#
# Iteration 100, loss = 0.4482
# cuda
# Got 6849 / 9000 correct (76.10)
#
# Iteration 200, loss = 0.5696
# cuda
# Got 6904 / 9000 correct (76.71)
#
# Iteration 300, loss = 0.3979
# cuda
# Got 6917 / 9000 correct (76.86)
#
# Iteration 400, loss = 0.5820
# cuda
# Got 6789 / 9000 correct (75.43)
#
# Iteration 500, loss = 0.4183
# cuda
# Got 6889 / 9000 correct (76.54)
#
# Iteration 600, loss = 0.3971
# cuda
# Got 6955 / 9000 correct (77.28)
#
# Iteration 700, loss = 0.4289
# cuda
# Got 6892 / 9000 correct (76.58)
#
# Iteration 800, loss = 0.4540
# cuda
# Got 6875 / 9000 correct (76.39)
#
# cuda
# Got 6901 / 9000 correct (76.68)
# cuda
# Got 41425 / 54000 correct (76.71)
#
# Epoch 7/50:
# Iteration 0, loss = 0.4113
# cuda
# Got 6909 / 9000 correct (76.77)
#
# Iteration 100, loss = 0.5234
# cuda
# Got 6897 / 9000 correct (76.63)
#
# Iteration 200, loss = 0.5376
# cuda
# Got 6934 / 9000 correct (77.04)
#
# Iteration 300, loss = 0.5156
# cuda
# Got 6859 / 9000 correct (76.21)
#
# Iteration 400, loss = 0.3880
# cuda
# Got 6905 / 9000 correct (76.72)
#
# Iteration 500, loss = 0.3599
# cuda
# Got 6958 / 9000 correct (77.31)
#
# Iteration 600, loss = 0.4223
# cuda
# Got 6900 / 9000 correct (76.67)
#
# Iteration 700, loss = 0.2907
# cuda
# Got 6936 / 9000 correct (77.07)
#
# Iteration 800, loss = 0.4053
# cuda
# Got 6968 / 9000 correct (77.42)
#
# cuda
# Got 6861 / 9000 correct (76.23)
# cuda
# Got 41081 / 54000 correct (76.08)
#
# Epoch 8/50:
# Iteration 0, loss = 0.5424
# cuda
# Got 6872 / 9000 correct (76.36)
#
# Iteration 100, loss = 0.4769
# cuda
# Got 6905 / 9000 correct (76.72)
#
# Iteration 200, loss = 0.5729
# cuda
# Got 6897 / 9000 correct (76.63)
#
# Iteration 300, loss = 0.3751
# cuda
# Got 6933 / 9000 correct (77.03)
#
# Iteration 400, loss = 0.3699
# cuda
# Got 6890 / 9000 correct (76.56)
#
# Iteration 500, loss = 0.3613
# cuda
# Got 6911 / 9000 correct (76.79)
#
# Iteration 600, loss = 0.3858
# cuda
# Got 6943 / 9000 correct (77.14)
#
# Iteration 700, loss = 0.3796
# cuda
# Got 6940 / 9000 correct (77.11)
#
# Iteration 800, loss = 0.3898
# cuda
# Got 6922 / 9000 correct (76.91)
#
# cuda
# Got 6946 / 9000 correct (77.18)
# cuda
# Got 41615 / 54000 correct (77.06)
#
# Epoch 9/50:
# Iteration 0, loss = 0.4280
# cuda
# Got 6917 / 9000 correct (76.86)
#
# Iteration 100, loss = 0.4547
# cuda
# Got 6907 / 9000 correct (76.74)
#
# Iteration 200, loss = 0.3709
# cuda
# Got 6880 / 9000 correct (76.44)
#
# Iteration 300, loss = 0.4837
# cuda
# Got 6938 / 9000 correct (77.09)
#
# Iteration 400, loss = 0.4540
# cuda
# Got 6973 / 9000 correct (77.48)
#
# Iteration 500, loss = 0.4428
# cuda
# Got 6917 / 9000 correct (76.86)
#
# Iteration 600, loss = 0.3716
# cuda
# Got 6941 / 9000 correct (77.12)
#
# Iteration 700, loss = 0.3950
# cuda
# Got 6959 / 9000 correct (77.32)
#
# Iteration 800, loss = 0.3726
# cuda
# Got 6885 / 9000 correct (76.50)
#
# cuda
# Got 6963 / 9000 correct (77.37)
# cuda
# Got 41638 / 54000 correct (77.11)
#
# Epoch 10/50:
# Iteration 0, loss = 0.5249
# cuda
# Got 6948 / 9000 correct (77.20)
#
# Iteration 100, loss = 0.4224
# cuda
# Got 6927 / 9000 correct (76.97)
#
# Iteration 200, loss = 0.4607
# cuda
# Got 6902 / 9000 correct (76.69)
#
# Iteration 300, loss = 0.3312
# cuda
# Got 6933 / 9000 correct (77.03)
#
# Iteration 400, loss = 0.3461
# cuda
# Got 6952 / 9000 correct (77.24)
#
# Iteration 500, loss = 0.3153
# cuda
# Got 6955 / 9000 correct (77.28)
#
# Iteration 600, loss = 0.4820
# cuda
# Got 6958 / 9000 correct (77.31)
#
# Iteration 700, loss = 0.4601
# cuda
# Got 6923 / 9000 correct (76.92)
#
# Iteration 800, loss = 0.4530
# cuda
# Got 6850 / 9000 correct (76.11)
#
# cuda
# Got 6908 / 9000 correct (76.76)
# cuda
# Got 41605 / 54000 correct (77.05)
#
# Epoch 11/50:
# Iteration 0, loss = 0.4983
# cuda
# Got 6931 / 9000 correct (77.01)
#
# Iteration 100, loss = 0.3477
# cuda
# Got 6902 / 9000 correct (76.69)
#
# Iteration 200, loss = 0.5029
# cuda
# Got 6998 / 9000 correct (77.76)
#
# Iteration 300, loss = 0.4499
# cuda
# Got 6925 / 9000 correct (76.94)
#
# Iteration 400, loss = 0.3914
# cuda
# Got 6937 / 9000 correct (77.08)
#
# Iteration 500, loss = 0.3318
# cuda
# Got 6931 / 9000 correct (77.01)
#
# Iteration 600, loss = 0.3400
# cuda
# Got 6956 / 9000 correct (77.29)
#
# Iteration 700, loss = 0.4220
# cuda
# Got 6930 / 9000 correct (77.00)
#
# Iteration 800, loss = 0.4316
# cuda
# Got 6947 / 9000 correct (77.19)
#
# cuda
# Got 6863 / 9000 correct (76.26)
# cuda
# Got 41351 / 54000 correct (76.58)
#
# Epoch 12/50:
# Iteration 0, loss = 0.5277
# cuda
# Got 6858 / 9000 correct (76.20)
#
# Iteration 100, loss = 0.4884
# cuda
# Got 6941 / 9000 correct (77.12)
#
# Iteration 200, loss = 0.4159
# cuda
# Got 6930 / 9000 correct (77.00)
#
# Iteration 300, loss = 0.3892
# cuda
# Got 6938 / 9000 correct (77.09)
#
# Iteration 400, loss = 0.4851
# cuda
# Got 6955 / 9000 correct (77.28)
#
# Iteration 500, loss = 0.4953
# cuda
# Got 6937 / 9000 correct (77.08)
#
# Iteration 600, loss = 0.4111
# cuda
# Got 6989 / 9000 correct (77.66)
#
# Iteration 700, loss = 0.5980
# cuda
# Got 6955 / 9000 correct (77.28)
#
# Iteration 800, loss = 0.3653
# cuda
# Got 6990 / 9000 correct (77.67)
# cuda
# Got 6926 / 9000 correct (76.96)
# cuda
# Got 41640 / 54000 correct (77.11)
#
# Epoch 13/50:
# Iteration 0, loss = 0.4237
# cuda
# Got 6977 / 9000 correct (77.52)
#
# Iteration 100, loss = 0.4303
# cuda
# Got 6857 / 9000 correct (76.19)
#
# Iteration 200, loss = 0.4415
# cuda
# Got 6907 / 9000 correct (76.74)
#
# Iteration 300, loss = 0.3823
# cuda
# Got 6996 / 9000 correct (77.73)
#
# Iteration 400, loss = 0.3970
# cuda
# Got 6867 / 9000 correct (76.30)
#
# Iteration 500, loss = 0.4610
# cuda
# Got 6948 / 9000 correct (77.20)
#
# Iteration 600, loss = 0.4011
# cuda
# Got 6945 / 9000 correct (77.17)
#
# Iteration 700, loss = 0.3807
# cuda
# Got 6998 / 9000 correct (77.76)
#
# Iteration 800, loss = 0.3744
# cuda
# Got 6954 / 9000 correct (77.27)
#
# cuda
# Got 6900 / 9000 correct (76.67)
# cuda
# Got 41504 / 54000 correct (76.86)
#
# Epoch 14/50:
# Iteration 0, loss = 0.3474
# cuda
# Got 6929 / 9000 correct (76.99)
#
# Iteration 100, loss = 0.5515
# cuda
# Got 6983 / 9000 correct (77.59)
#
# Iteration 200, loss = 0.4093
# cuda
# Got 6908 / 9000 correct (76.76)
#
# Iteration 300, loss = 0.3779
# cuda
# Got 7000 / 9000 correct (77.78)
#
# Iteration 400, loss = 0.4149
# cuda
# Got 6982 / 9000 correct (77.58)
#
# Iteration 500, loss = 0.3790
# cuda
# Got 6864 / 9000 correct (76.27)
#
# Iteration 600, loss = 0.4127
# cuda
# Got 6963 / 9000 correct (77.37)
#
# Iteration 700, loss = 0.5101
# cuda
# Got 6985 / 9000 correct (77.61)
#
# Iteration 800, loss = 0.4627
# cuda
# Got 6882 / 9000 correct (76.47)
#
# cuda
# Got 6955 / 9000 correct (77.28)
# cuda
# Got 41764 / 54000 correct (77.34)
#
# Epoch 15/50:
# Iteration 0, loss = 0.3328
# cuda
# Got 6947 / 9000 correct (77.19)
#
# Iteration 100, loss = 0.4083
# cuda
# Got 7009 / 9000 correct (77.88)
#
# Iteration 200, loss = 0.4710
# cuda
# Got 6953 / 9000 correct (77.26)
#
# Iteration 300, loss = 0.4629
# cuda
# Got 6984 / 9000 correct (77.60)
#
# Iteration 400, loss = 0.3869
# cuda
# Got 6986 / 9000 correct (77.62)
#
# Iteration 500, loss = 0.4557
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 600, loss = 0.3303
# cuda
# Got 6965 / 9000 correct (77.39)
#
# Iteration 700, loss = 0.4524
# cuda
# Got 6970 / 9000 correct (77.44)
#
# Iteration 800, loss = 0.3521
# cuda
# Got 6985 / 9000 correct (77.61)
#
# cuda
# Got 7015 / 9000 correct (77.94)
# cuda
# Got 41984 / 54000 correct (77.75)
#
# Epoch 16/50:
# Iteration 0, loss = 0.3734
# cuda
# Got 6993 / 9000 correct (77.70)
#
# Iteration 100, loss = 0.3668
# cuda
# Got 6968 / 9000 correct (77.42)
#
# Iteration 200, loss = 0.3623
# cuda
# Got 6979 / 9000 correct (77.54)
#
# Iteration 300, loss = 0.4655
# cuda
# Got 6987 / 9000 correct (77.63)
#
# Iteration 400, loss = 0.4683
# cuda
# Got 6973 / 9000 correct (77.48)
#
# Iteration 500, loss = 0.4417
# cuda
# Got 6998 / 9000 correct (77.76)
#
# Iteration 600, loss = 0.4444
# cuda
# Got 6959 / 9000 correct (77.32)
#
# Iteration 700, loss = 0.4178
# cuda
# Got 6978 / 9000 correct (77.53)
#
# Iteration 800, loss = 0.4601
# cuda
# Got 7031 / 9000 correct (78.12)
#
# cuda
# Got 6972 / 9000 correct (77.47)
# cuda
# Got 41877 / 54000 correct (77.55)
#
# Epoch 17/50:
# Iteration 0, loss = 0.3363
# cuda
# Got 6970 / 9000 correct (77.44)
#
# Iteration 100, loss = 0.4406
# cuda
# Got 6973 / 9000 correct (77.48)
#
# Iteration 200, loss = 0.3820
# cuda
# Got 6953 / 9000 correct (77.26)
#
# Iteration 300, loss = 0.3499
# cuda
# Got 6948 / 9000 correct (77.20)
#
# Iteration 400, loss = 0.5108
# cuda
# Got 6997 / 9000 correct (77.74)
#
# Iteration 500, loss = 0.4578
# cuda
# Got 6987 / 9000 correct (77.63)
#
# Iteration 600, loss = 0.4727
# cuda
# Got 6920 / 9000 correct (76.89)
#
# Iteration 700, loss = 0.4913
# cuda
# Got 6936 / 9000 correct (77.07)
#
# Iteration 800, loss = 0.3900
# cuda
# Got 6975 / 9000 correct (77.50)
#
# cuda
# Got 6995 / 9000 correct (77.72)
# cuda
# Got 41926 / 54000 correct (77.64)
#
# Epoch 18/50:
# Iteration 0, loss = 0.4251
# cuda
# Got 6975 / 9000 correct (77.50)
#
# Iteration 100, loss = 0.3552
# cuda
# Got 7002 / 9000 correct (77.80)
#
# Iteration 200, loss = 0.3344
# cuda
# Got 6949 / 9000 correct (77.21)
#
# Iteration 300, loss = 0.5172
# cuda
# Got 6981 / 9000 correct (77.57)
#
# Iteration 400, loss = 0.4657
# cuda
# Got 6987 / 9000 correct (77.63)
#
# Iteration 500, loss = 0.3478
# cuda
# Got 6983 / 9000 correct (77.59)
#
# Iteration 600, loss = 0.4993
# cuda
# Got 7024 / 9000 correct (78.04)
#
# Iteration 700, loss = 0.4101
# cuda
# Got 6979 / 9000 correct (77.54)
#
# Iteration 800, loss = 0.3436
# cuda
# Got 6974 / 9000 correct (77.49)
#
# cuda
# Got 6951 / 9000 correct (77.23)
# cuda
# Got 41708 / 54000 correct (77.24)
#
# Epoch 19/50:
# Iteration 0, loss = 0.4238
# cuda
# Got 6959 / 9000 correct (77.32)
#
# Iteration 100, loss = 0.3965
# cuda
# Got 6980 / 9000 correct (77.56)
#
# Iteration 200, loss = 0.4641
# cuda
# Got 6981 / 9000 correct (77.57)
#
# Iteration 300, loss = 0.4414
# cuda
# Got 6994 / 9000 correct (77.71)
#
# Iteration 400, loss = 0.4919
# cuda
# Got 6975 / 9000 correct (77.50)
#
# Iteration 500, loss = 0.3171
# cuda
# Got 6952 / 9000 correct (77.24)
#
# Iteration 600, loss = 0.4201
# cuda
# Got 6997 / 9000 correct (77.74)
#
# Iteration 700, loss = 0.6129
# cuda
# Got 7009 / 9000 correct (77.88)
#
# Iteration 800, loss = 0.3880
# cuda
# Got 6970 / 9000 correct (77.44)
#
# cuda
# Got 6980 / 9000 correct (77.56)
# cuda
# Got 41871 / 54000 correct (77.54)
#
# Epoch 20/50:
# Iteration 0, loss = 0.3841
# cuda
# Got 7005 / 9000 correct (77.83)
#
# Iteration 100, loss = 0.4555
# cuda
# Got 6939 / 9000 correct (77.10)
#
# Iteration 200, loss = 0.4598
# cuda
# Got 6974 / 9000 correct (77.49)
#
# Iteration 300, loss = 0.3431
# cuda
# Got 6992 / 9000 correct (77.69)
#
# Iteration 400, loss = 0.4278
# cuda
# Got 6967 / 9000 correct (77.41)
#
# Iteration 500, loss = 0.3770
# cuda
# Got 7012 / 9000 correct (77.91)
#
# Iteration 600, loss = 0.3343
# cuda
# Got 6985 / 9000 correct (77.61)
#
# Iteration 700, loss = 0.4057
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 800, loss = 0.3582
# cuda
# Got 6949 / 9000 correct (77.21)
#
# cuda
# Got 6941 / 9000 correct (77.12)
# cuda
# Got 41623 / 54000 correct (77.08)
#
# Epoch 21/50:
# Iteration 0, loss = 0.4018
# cuda
# Got 6940 / 9000 correct (77.11)
#
# Iteration 100, loss = 0.4456
# cuda
# Got 6979 / 9000 correct (77.54)
#
# Iteration 200, loss = 0.4422
# cuda
# Got 6999 / 9000 correct (77.77)
#
# Iteration 300, loss = 0.4849
# cuda
# Got 6944 / 9000 correct (77.16)
#
# Iteration 400, loss = 0.4999
# cuda
# Got 6983 / 9000 correct (77.59)
#
# Iteration 500, loss = 0.5025
# cuda
# Got 7016 / 9000 correct (77.96)
#
# Iteration 600, loss = 0.4563
# cuda
# Got 7002 / 9000 correct (77.80)
#
# Iteration 700, loss = 0.3975
# cuda
# Got 6956 / 9000 correct (77.29)
#
# Iteration 800, loss = 0.4106
# cuda
# Got 6990 / 9000 correct (77.67)
#
# cuda
# Got 6994 / 9000 correct (77.71)
# Epoch    20: reducing learning rate of group 0 to 4.0000e-04.
# cuda
# Got 41934 / 54000 correct (77.66)
#
# Epoch 22/50:
# Iteration 0, loss = 0.4350
# cuda
# Got 6979 / 9000 correct (77.54)
#
# Iteration 100, loss = 0.4783
# cuda
# Got 6995 / 9000 correct (77.72)
#
# Iteration 200, loss = 0.4544
# cuda
# Got 7023 / 9000 correct (78.03)
#
# Iteration 300, loss = 0.3528
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 400, loss = 0.4707
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 500, loss = 0.3540
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 600, loss = 0.3777
# cuda
# Got 7004 / 9000 correct (77.82)
#
# Iteration 700, loss = 0.3810
# cuda
# Got 7017 / 9000 correct (77.97)
#
# Iteration 800, loss = 0.4639
# cuda
# Got 7005 / 9000 correct (77.83)
#
# cuda
# Got 7007 / 9000 correct (77.86)
# cuda
# Got 42073 / 54000 correct (77.91)
#
# Epoch 23/50:
# Iteration 0, loss = 0.3086
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 100, loss = 0.4341
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 200, loss = 0.4555
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 300, loss = 0.3949
# cuda
# Got 7010 / 9000 correct (77.89)
#
# Iteration 400, loss = 0.4896
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 500, loss = 0.3133
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 600, loss = 0.3064
# cuda
# Got 7010 / 9000 correct (77.89)
#
# Iteration 700, loss = 0.4506
# cuda
# Got 7026 / 9000 correct (78.07)
#
# Iteration 800, loss = 0.3992
# cuda
# Got 7059 / 9000 correct (78.43)
#
# cuda
# Got 7049 / 9000 correct (78.32)
# cuda
# Got 42175 / 54000 correct (78.10)
#
# Epoch 24/50:
# Iteration 0, loss = 0.4532
# cuda
# Got 7016 / 9000 correct (77.96)
#
# Iteration 100, loss = 0.3661
# cuda
# Got 7008 / 9000 correct (77.87)
#
# Iteration 200, loss = 0.4084
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 300, loss = 0.3681
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 400, loss = 0.4645
# cuda
# Got 7023 / 9000 correct (78.03)
#
# Iteration 500, loss = 0.3308
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 600, loss = 0.3179
# cuda
# Got 7039 / 9000 correct (78.21)
# Iteration 700, loss = 0.4487
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 800, loss = 0.4033
# cuda
# Got 7036 / 9000 correct (78.18)
#
# cuda
# Got 7033 / 9000 correct (78.14)
# cuda
# Got 42208 / 54000 correct (78.16)
#
# Epoch 25/50:
# Iteration 0, loss = 0.5174
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 100, loss = 0.4381
# cuda
# Got 7009 / 9000 correct (77.88)
#
# Iteration 200, loss = 0.4747
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 300, loss = 0.4117
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 400, loss = 0.2682
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 500, loss = 0.3947
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 600, loss = 0.3832
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 700, loss = 0.4246
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 800, loss = 0.4000
# cuda
# Got 7016 / 9000 correct (77.96)
#
# cuda
# Got 7028 / 9000 correct (78.09)
# cuda
# Got 42180 / 54000 correct (78.11)
#
# Epoch 26/50:
# Iteration 0, loss = 0.3897
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 100, loss = 0.3256
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 200, loss = 0.4159
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 300, loss = 0.3245
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 400, loss = 0.3797
# cuda
# Got 7015 / 9000 correct (77.94)
#
# Iteration 500, loss = 0.4783
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 600, loss = 0.3922
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 700, loss = 0.3446
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 800, loss = 0.4037
# cuda
# Got 7018 / 9000 correct (77.98)
#
# cuda
# Got 7051 / 9000 correct (78.34)
# cuda
# Got 42210 / 54000 correct (78.17)
#
# Epoch 27/50:
# Iteration 0, loss = 0.4214
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 100, loss = 0.3364
# cuda
# Got 7068 / 9000 correct (78.53)
#
# Iteration 200, loss = 0.5107
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 300, loss = 0.4016
# cuda
# Got 7022 / 9000 correct (78.02)
#
# Iteration 400, loss = 0.2674
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 500, loss = 0.3903
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 600, loss = 0.4316
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 700, loss = 0.4443
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 800, loss = 0.3487
# cuda
# Got 7052 / 9000 correct (78.36)
#
# cuda
# Got 7048 / 9000 correct (78.31)
# cuda
# Got 42222 / 54000 correct (78.19)
#
# Epoch 28/50:
# Iteration 0, loss = 0.4469
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 100, loss = 0.4158
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 200, loss = 0.3741
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 300, loss = 0.4362
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 400, loss = 0.4190
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 500, loss = 0.4392
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 600, loss = 0.3732
# cuda
# Got 7066 / 9000 correct (78.51)
#
# Iteration 700, loss = 0.4697
# cuda
# Got 7016 / 9000 correct (77.96)
#
# Iteration 800, loss = 0.5446
# cuda
# Got 7049 / 9000 correct (78.32)
#
# cuda
# Got 7045 / 9000 correct (78.28)
# cuda
# Got 42232 / 54000 correct (78.21)
#
# Epoch 29/50:
# Iteration 0, loss = 0.4025
# cuda
# Got 7021 / 9000 correct (78.01)
#
# Iteration 100, loss = 0.3004
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 200, loss = 0.3473
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 300, loss = 0.3959
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 400, loss = 0.3171
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 500, loss = 0.4442
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 600, loss = 0.4529
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 700, loss = 0.4041
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 800, loss = 0.3911
# cuda
# Got 7063 / 9000 correct (78.48)
#
# cuda
# Got 7045 / 9000 correct (78.28)
# cuda
# Got 42156 / 54000 correct (78.07)
#
# Epoch 30/50:
# Iteration 0, loss = 0.4287
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 100, loss = 0.4231
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 200, loss = 0.4364
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 300, loss = 0.3853
# cuda
# Got 7026 / 9000 correct (78.07)
#
# Iteration 400, loss = 0.4688
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 500, loss = 0.4027
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 600, loss = 0.3732
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 700, loss = 0.2740
# cuda
# Got 7074 / 9000 correct (78.60)
#
# Iteration 800, loss = 0.3680
# cuda
# Got 7062 / 9000 correct (78.47)
#
# cuda
# Got 7085 / 9000 correct (78.72)
# cuda
# Got 42231 / 54000 correct (78.21)
#
# Epoch 31/50:
# Iteration 0, loss = 0.3707
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 100, loss = 0.4512
# cuda
# Got 7035 / 9000 correct (78.17)
#
# Iteration 200, loss = 0.3651
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 300, loss = 0.3753
# cuda
# Got 7067 / 9000 correct (78.52)
#
# Iteration 400, loss = 0.3264
# cuda
# Got 7019 / 9000 correct (77.99)
#
# Iteration 500, loss = 0.3804
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 600, loss = 0.4657
# cuda
# Got 7073 / 9000 correct (78.59)
#
# Iteration 700, loss = 0.3948
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 800, loss = 0.3810
# cuda
# Got 7055 / 9000 correct (78.39)
#
# cuda
# Got 7022 / 9000 correct (78.02)
# cuda
# Got 42281 / 54000 correct (78.30)
#
# Epoch 32/50:
# Iteration 0, loss = 0.3481
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 100, loss = 0.3112
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 200, loss = 0.3970
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 300, loss = 0.3760
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 400, loss = 0.4875
# cuda
# Got 7008 / 9000 correct (77.87)
#
# Iteration 500, loss = 0.4031
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 600, loss = 0.3553
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 700, loss = 0.4343
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 800, loss = 0.3756
# cuda
# Got 7059 / 9000 correct (78.43)
#
# cuda
# Got 7035 / 9000 correct (78.17)
# cuda
# Got 42260 / 54000 correct (78.26)
#
# Epoch 33/50:
# Iteration 0, loss = 0.5723
# cuda
# Got 7026 / 9000 correct (78.07)
#
# Iteration 100, loss = 0.4077
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 200, loss = 0.3801
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 300, loss = 0.3947
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 400, loss = 0.3525
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 500, loss = 0.3999
# cuda
# Got 7023 / 9000 correct (78.03)
#
# Iteration 600, loss = 0.3507
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 700, loss = 0.5172
# cuda
# Got 7063 / 9000 correct (78.48)
#
# Iteration 800, loss = 0.3664
# cuda
# Got 7036 / 9000 correct (78.18)
#
# cuda
# Got 7077 / 9000 correct (78.63)
# cuda
# Got 42262 / 54000 correct (78.26)
#
# Epoch 34/50:
# Iteration 0, loss = 0.4372
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 100, loss = 0.3625
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 200, loss = 0.3706
# cuda
# Got 7026 / 9000 correct (78.07)
#
# Iteration 300, loss = 0.4192
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 400, loss = 0.3451
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 500, loss = 0.4188
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 600, loss = 0.5028
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 700, loss = 0.3338
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 800, loss = 0.3880
# cuda
# Got 7056 / 9000 correct (78.40)
#
# cuda
# Got 7061 / 9000 correct (78.46)
# cuda
# Got 42317 / 54000 correct (78.36)
#
# Epoch 35/50:
# Iteration 0, loss = 0.3020
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 100, loss = 0.3922
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 200, loss = 0.3567
# cuda
# Got 7069 / 9000 correct (78.54)
#
# Iteration 300, loss = 0.4144
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 400, loss = 0.4869
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 500, loss = 0.2896
# cuda
# Got 7089 / 9000 correct (78.77)
#
# Iteration 600, loss = 0.4053
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 700, loss = 0.4463
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 800, loss = 0.4403
# cuda
# Got 7055 / 9000 correct (78.39)
#
# cuda
# Got 7040 / 9000 correct (78.22)
# cuda
# Got 42313 / 54000 correct (78.36)
#
# Epoch 36/50:
# Iteration 0, loss = 0.5839
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 100, loss = 0.4135
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 200, loss = 0.4468
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 300, loss = 0.3511
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 400, loss = 0.4621
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 500, loss = 0.3585
# cuda
# Got 7069 / 9000 correct (78.54)
# Iteration 600, loss = 0.3448
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 700, loss = 0.4078
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 800, loss = 0.4025
# cuda
# Got 7026 / 9000 correct (78.07)
#
# cuda
# Got 7054 / 9000 correct (78.38)
# Epoch    35: reducing learning rate of group 0 to 4.0000e-05.
# cuda
# Got 42340 / 54000 correct (78.41)
#
# Epoch 37/50:
# Iteration 0, loss = 0.4019
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 100, loss = 0.3210
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 200, loss = 0.4128
# cuda
# Got 7082 / 9000 correct (78.69)
#
# Iteration 300, loss = 0.3830
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 400, loss = 0.4303
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 500, loss = 0.3342
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 600, loss = 0.3178
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 700, loss = 0.4182
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 800, loss = 0.3441
# cuda
# Got 7043 / 9000 correct (78.26)
#
# cuda
# Got 7061 / 9000 correct (78.46)
# cuda
# Got 42365 / 54000 correct (78.45)
#
# Epoch 38/50:
# Iteration 0, loss = 0.4107
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 100, loss = 0.3110
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 200, loss = 0.3681
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 300, loss = 0.3692
# cuda
# Got 7079 / 9000 correct (78.66)
#
# Iteration 400, loss = 0.4512
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 500, loss = 0.3990
# cuda
# Got 7067 / 9000 correct (78.52)
#
# Iteration 600, loss = 0.2875
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 700, loss = 0.4382
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 800, loss = 0.3143
# cuda
# Got 7065 / 9000 correct (78.50)
#
# cuda
# Got 7059 / 9000 correct (78.43)
# cuda
# Got 42296 / 54000 correct (78.33)
#
# Epoch 39/50:
# Iteration 0, loss = 0.4774
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 100, loss = 0.3700
# cuda
# Got 7086 / 9000 correct (78.73)
#
# Iteration 200, loss = 0.3853
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 300, loss = 0.4335
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 400, loss = 0.3915
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 500, loss = 0.3184
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 600, loss = 0.4569
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 700, loss = 0.3994
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 800, loss = 0.4743
# cuda
# Got 7045 / 9000 correct (78.28)
#
# cuda
# Got 7076 / 9000 correct (78.62)
# cuda
# Got 42298 / 54000 correct (78.33)
#
# Epoch 40/50:
# Iteration 0, loss = 0.4162
# cuda
# Got 7073 / 9000 correct (78.59)
#
# Iteration 100, loss = 0.3507
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 200, loss = 0.4171
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 300, loss = 0.3209
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 400, loss = 0.3621
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 500, loss = 0.4195
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 600, loss = 0.3796
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 700, loss = 0.3810
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 800, loss = 0.3661
# cuda
# Got 7061 / 9000 correct (78.46)
#
# cuda
# Got 7075 / 9000 correct (78.61)
# cuda
# Got 42282 / 54000 correct (78.30)
#
# Epoch 41/50:
# Iteration 0, loss = 0.3485
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 100, loss = 0.4104
# cuda
# Got 7080 / 9000 correct (78.67)
#
# Iteration 200, loss = 0.3722
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 300, loss = 0.3505
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 400, loss = 0.3801
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 500, loss = 0.3539
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 600, loss = 0.3396
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 700, loss = 0.3817
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 800, loss = 0.4164
# cuda
# Got 7051 / 9000 correct (78.34)
#
# cuda
# Got 7038 / 9000 correct (78.20)
# cuda
# Got 42355 / 54000 correct (78.44)
#
# Epoch 42/50:
# Iteration 0, loss = 0.3466
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 100, loss = 0.3689
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 200, loss = 0.4488
# cuda
# Got 7072 / 9000 correct (78.58)
#
# Iteration 300, loss = 0.3608
# cuda
# Got 7073 / 9000 correct (78.59)
#
# Iteration 400, loss = 0.3222
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 500, loss = 0.4443
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 600, loss = 0.3405
# cuda
# Got 7073 / 9000 correct (78.59)
#
# Iteration 700, loss = 0.4025
# cuda
# Got 7067 / 9000 correct (78.52)
#
# Iteration 800, loss = 0.3702
# cuda
# Got 7065 / 9000 correct (78.50)
#
# cuda
# Got 7081 / 9000 correct (78.68)
# Epoch    41: reducing learning rate of group 0 to 4.0000e-06.
# cuda
# Got 42288 / 54000 correct (78.31)
#
# Epoch 43/50:
# Iteration 0, loss = 0.3354
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 100, loss = 0.4429
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 200, loss = 0.4028
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 300, loss = 0.4128
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 400, loss = 0.4273
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 500, loss = 0.4464
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 600, loss = 0.5106
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 700, loss = 0.3214
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 800, loss = 0.4105
# cuda
# Got 7057 / 9000 correct (78.41)
#
# cuda
# Got 7056 / 9000 correct (78.40)
# cuda
# Got 42300 / 54000 correct (78.33)
#
# Epoch 44/50:
# Iteration 0, loss = 0.3409
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 100, loss = 0.3502
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 200, loss = 0.3836
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 300, loss = 0.3477
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 400, loss = 0.4334
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 500, loss = 0.2924
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 600, loss = 0.4060
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 700, loss = 0.2984
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 800, loss = 0.4757
# cuda
# Got 7053 / 9000 correct (78.37)
#
# cuda
# Got 7040 / 9000 correct (78.22)
# cuda
# Got 42264 / 54000 correct (78.27)
#
# Epoch 45/50:
# Iteration 0, loss = 0.3897
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 100, loss = 0.3245
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 200, loss = 0.3452
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 300, loss = 0.4073
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 400, loss = 0.3949
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 500, loss = 0.3769
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 600, loss = 0.4473
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 700, loss = 0.3505
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 800, loss = 0.5736
# cuda
# Got 7063 / 9000 correct (78.48)
#
# cuda
# Got 7047 / 9000 correct (78.30)
# cuda
# Got 42293 / 54000 correct (78.32)
#
# Epoch 46/50:
# Iteration 0, loss = 0.4525
# cuda
# Got 7078 / 9000 correct (78.64)
#
# Iteration 100, loss = 0.4066
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 200, loss = 0.4032
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 300, loss = 0.4881
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 400, loss = 0.3918
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 500, loss = 0.4343
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 600, loss = 0.3582
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 700, loss = 0.4406
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 800, loss = 0.3332
# cuda
# Got 7054 / 9000 correct (78.38)
#
# cuda
# Got 7030 / 9000 correct (78.11)
# cuda
# Got 42341 / 54000 correct (78.41)
#
# Epoch 47/50:
# Iteration 0, loss = 0.3371
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 100, loss = 0.5044
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 200, loss = 0.4177
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 300, loss = 0.4216
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 400, loss = 0.4213
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 500, loss = 0.3651
# cuda
# Got 7069 / 9000 correct (78.54)
#
# Iteration 600, loss = 0.4440
# cuda
# Got 7067 / 9000 correct (78.52)
#
# Iteration 700, loss = 0.3957
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 800, loss = 0.3958
# cuda
# Got 7057 / 9000 correct (78.41)
#
# cuda
# Got 7036 / 9000 correct (78.18)
# cuda
# Got 42274 / 54000 correct (78.29)
#
# Epoch 48/50:
# Iteration 0, loss = 0.3405
# cuda
# Got 7072 / 9000 correct (78.58)
#
# Iteration 100, loss = 0.4045
# cuda
# Got 7071 / 9000 correct (78.57)
#
# Iteration 200, loss = 0.3732
# cuda
# Got 7015 / 9000 correct (77.94)
# Iteration 300, loss = 0.3394
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 400, loss = 0.4035
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 500, loss = 0.2833
# cuda
# Got 7076 / 9000 correct (78.62)
#
# Iteration 600, loss = 0.3762
# cuda
# Got 7069 / 9000 correct (78.54)
#
# Iteration 700, loss = 0.4970
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 800, loss = 0.2725
# cuda
# Got 7042 / 9000 correct (78.24)
#
# cuda
# Got 7050 / 9000 correct (78.33)
# Epoch    47: reducing learning rate of group 0 to 4.0000e-07.
# cuda
# Got 42363 / 54000 correct (78.45)
#
# Epoch 49/50:
# Iteration 0, loss = 0.4316
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 100, loss = 0.3732
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 200, loss = 0.3334
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 300, loss = 0.3193
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 400, loss = 0.4149
# cuda
# Got 7071 / 9000 correct (78.57)
#
# Iteration 500, loss = 0.4232
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 600, loss = 0.4033
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 700, loss = 0.4202
# cuda
# Got 7061 / 9000 correct (78.46)
#
# Iteration 800, loss = 0.3961
# cuda
# Got 7044 / 9000 correct (78.27)
#
# cuda
# Got 7084 / 9000 correct (78.71)
# cuda
# Got 42323 / 54000 correct (78.38)
#
# Epoch 50/50:
# Iteration 0, loss = 0.3684
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 100, loss = 0.4758
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 200, loss = 0.3500
# cuda
# Got 7082 / 9000 correct (78.69)
#
# Iteration 300, loss = 0.4767
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 400, loss = 0.4209
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 500, loss = 0.3499
# cuda
# Got 7069 / 9000 correct (78.54)
#
# Iteration 600, loss = 0.5043
# cuda
# Got 7063 / 9000 correct (78.48)
#
# Iteration 700, loss = 0.4683
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 800, loss = 0.4577
# cuda
# Got 7010 / 9000 correct (77.89)
#
# cuda
# Got 7063 / 9000 correct (78.48)
# cuda
# Got 42385 / 54000 correct (78.49)

# %%
trainingMetrics(hist)

# %%
torch.save(advModel.state_dict(), "../models/advTraining_1.pth.tar")

# %%
# let's run the same neural network, but increase the batch size and the number of images --> does this
# smooth out the loss and accuracy curves? 

advanced_rnn_1_2 = rnn_2dCNN(layer0_params, layer0_reduce, layer1_params, layer1_reduce, layer2_params, layer2_reduce, rnn_params, layer3_params, fc_params)

adv_optimizer = optim.Adam(advanced_rnn_1_2.parameters(), lr=4e-3)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(adv_optimizer, mode='max', factor=0.6, patience=1, verbose=True)

hist, advModel_2 = train(loader_train, loader_val, advanced_rnn_1_2, adv_optimizer, scheduler, epochs=20, returnBest=True)

# save the best model from training for 100 epochs 
torch.save(advModel_2.state_dict(), "../models/advTraining_1_2.pth.tar")
# Out:
# cuda
#
# Epoch 1/20:
# Iteration 0, loss = 1.1139
# cuda
# Got 9309 / 24000 correct (38.79)
#
# Iteration 100, loss = 0.4572
# cuda
# Got 17943 / 24000 correct (74.76)
#
# cuda
# Got 17707 / 24000 correct (73.78)
# cuda
# Got 106707 / 144000 correct (74.10)
#
# Epoch 2/20:
# Iteration 0, loss = 0.4636
# cuda
# Got 17746 / 24000 correct (73.94)
#
# Iteration 100, loss = 0.4123
# cuda
# Got 18189 / 24000 correct (75.79)
#
# cuda
# Got 18362 / 24000 correct (76.51)
# cuda
# Got 110398 / 144000 correct (76.67)
#
# Epoch 3/20:
# Iteration 0, loss = 0.3907
# cuda
# Got 18325 / 24000 correct (76.35)
#
# Iteration 100, loss = 0.4586
# cuda
# Got 18318 / 24000 correct (76.33)
#
# cuda
# Got 18468 / 24000 correct (76.95)
# Epoch     2: reducing learning rate of group 0 to 2.4000e-03.
# cuda
# Got 110735 / 144000 correct (76.90)
#
# Epoch 4/20:
# Iteration 0, loss = 0.4335
# cuda
# Got 18506 / 24000 correct (77.11)
#
# Iteration 100, loss = 0.4309
# cuda
# Got 18484 / 24000 correct (77.02)
#
# cuda
# Got 18538 / 24000 correct (77.24)
# cuda
# Got 111380 / 144000 correct (77.35)
#
# Epoch 5/20:
# Iteration 0, loss = 0.4051
# cuda
# Got 18570 / 24000 correct (77.38)
#
# Iteration 100, loss = 0.4239
# cuda
# Got 18662 / 24000 correct (77.76)
#
# cuda
# Got 18597 / 24000 correct (77.49)
# Epoch     4: reducing learning rate of group 0 to 1.4400e-03.
# cuda
# Got 111685 / 144000 correct (77.56)
#
# Epoch 6/20:
# Iteration 0, loss = 0.4306
# cuda
# Got 18606 / 24000 correct (77.53)
#
# Iteration 100, loss = 0.3850
# cuda
# Got 18633 / 24000 correct (77.64)
#
# cuda
# Got 18629 / 24000 correct (77.62)
# cuda
# Got 112035 / 144000 correct (77.80)
#
# Epoch 7/20:
# Iteration 0, loss = 0.3649
# cuda
# Got 18568 / 24000 correct (77.37)
#
# Iteration 100, loss = 0.4106
# cuda
# Got 18617 / 24000 correct (77.57)
#
# cuda
# Got 18686 / 24000 correct (77.86)
# Epoch     6: reducing learning rate of group 0 to 8.6400e-04.
# cuda
# Got 112177 / 144000 correct (77.90)
#
# Epoch 8/20:
# Iteration 0, loss = 0.4078
# cuda
# Got 18635 / 24000 correct (77.65)
#
# Iteration 100, loss = 0.4042
# cuda
# Got 18681 / 24000 correct (77.84)
#
# cuda
# Got 18651 / 24000 correct (77.71)
# cuda
# Got 112262 / 144000 correct (77.96)
#
# Epoch 9/20:
# Iteration 0, loss = 0.4129
# cuda
# Got 18668 / 24000 correct (77.78)
#
# Iteration 100, loss = 0.4110
# cuda
# Got 18620 / 24000 correct (77.58)
#
# cuda
# Got 18670 / 24000 correct (77.79)
# Epoch     8: reducing learning rate of group 0 to 5.1840e-04.
# cuda
# Got 112160 / 144000 correct (77.89)
#
# Epoch 10/20:
# Iteration 0, loss = 0.4096
# cuda
# Got 18601 / 24000 correct (77.50)
#
# Iteration 100, loss = 0.4425
# cuda
# Got 18671 / 24000 correct (77.80)
#
# cuda
# Got 18663 / 24000 correct (77.76)
# cuda
# Got 112508 / 144000 correct (78.13)
#
# Epoch 11/20:
# Iteration 0, loss = 0.3829
# cuda
# Got 18663 / 24000 correct (77.76)
#
# Iteration 100, loss = 0.4054
# cuda
# Got 18638 / 24000 correct (77.66)
#
# cuda
# Got 18728 / 24000 correct (78.03)
# Epoch    10: reducing learning rate of group 0 to 3.1104e-04.
# cuda
# Got 112397 / 144000 correct (78.05)
#
# Epoch 12/20:
# Iteration 0, loss = 0.4100
# cuda
# Got 18695 / 24000 correct (77.90)
#
# Iteration 100, loss = 0.3960
# cuda
# Got 18679 / 24000 correct (77.83)
#
# cuda
# Got 18736 / 24000 correct (78.07)
# cuda
# Got 112475 / 144000 correct (78.11)
#
# Epoch 13/20:
# Iteration 0, loss = 0.3876
# cuda
# Got 18716 / 24000 correct (77.98)
#
# Iteration 100, loss = 0.3960
# cuda
# Got 18660 / 24000 correct (77.75)
#
# cuda
# Got 18709 / 24000 correct (77.95)
# Epoch    12: reducing learning rate of group 0 to 1.8662e-04.
# cuda
# Got 112397 / 144000 correct (78.05)
#
# Epoch 14/20:
# Iteration 0, loss = 0.4074
# cuda
# Got 18645 / 24000 correct (77.69)
#
# Iteration 100, loss = 0.4108
# cuda
# Got 18673 / 24000 correct (77.80)
#
# cuda
# Got 18663 / 24000 correct (77.76)
# cuda
# Got 112469 / 144000 correct (78.10)
#
# Epoch 15/20:
# Iteration 0, loss = 0.4033
# cuda
# Got 18669 / 24000 correct (77.79)
#
# Iteration 100, loss = 0.3892
# cuda
# Got 18689 / 24000 correct (77.87)
#
# cuda
# Got 18747 / 24000 correct (78.11)
# Epoch    14: reducing learning rate of group 0 to 1.1197e-04.
# cuda
# Got 112527 / 144000 correct (78.14)
#
# Epoch 16/20:
# Iteration 0, loss = 0.4356
# cuda
# Got 18681 / 24000 correct (77.84)
#
# Iteration 100, loss = 0.3899
# cuda
# Got 18706 / 24000 correct (77.94)
#
# cuda
# Got 18694 / 24000 correct (77.89)
# cuda
# Got 112521 / 144000 correct (78.14)
#
# Epoch 17/20:
# Iteration 0, loss = 0.4032
# cuda
# Got 18668 / 24000 correct (77.78)
#
# Iteration 100, loss = 0.3946
# cuda
# Got 18672 / 24000 correct (77.80)
#
# cuda
# Got 18711 / 24000 correct (77.96)
# Epoch    16: reducing learning rate of group 0 to 6.7185e-05.
# cuda
# Got 112544 / 144000 correct (78.16)
#
# Epoch 18/20:
# Iteration 0, loss = 0.4027
# cuda
# Got 18655 / 24000 correct (77.73)
#
# Iteration 100, loss = 0.4032
# cuda
# Got 18734 / 24000 correct (78.06)
#
# cuda
# Got 18731 / 24000 correct (78.05)
# cuda
# Got 112567 / 144000 correct (78.17)
#
# Epoch 19/20:
# Iteration 0, loss = 0.3977
# cuda
# Got 18681 / 24000 correct (77.84)
#
# Iteration 100, loss = 0.3799
# cuda
# Got 18665 / 24000 correct (77.77)
#
# cuda
# Got 18683 / 24000 correct (77.85)
# Epoch    18: reducing learning rate of group 0 to 4.0311e-05.
# cuda
# Got 112473 / 144000 correct (78.11)
#
# Epoch 20/20:
# Iteration 0, loss = 0.3909
# cuda
# Got 18733 / 24000 correct (78.05)
#
# Iteration 100, loss = 0.3769
# cuda
# Got 18651 / 24000 correct (77.71)
#
# cuda
# Got 18687 / 24000 correct (77.86)
# cuda
# Got 112614 / 144000 correct (78.20)

# %%
trainingMetrics(hist)

# %%
# it looks like our learning rate is too high, since the loss dives down to about 0.4 and stays there for the 
# rest of training. I'm going to try the scheduler again, with a smaller learning rate of ~ 1e-5
advanced_rnn_smLR = rnn_2dCNN(layer0_params, layer0_reduce, layer1_params, layer1_reduce, layer2_params, layer2_reduce, rnn_params, layer3_params, fc_params)

adv_optimizer = optim.Adam(advanced_rnn_smLR.parameters(), lr=1e-5)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(adv_optimizer, mode='max', factor=0.6, patience=5, verbose=True)

hist, advModel_3 = train(loader_train, loader_val, advanced_rnn_smLR, adv_optimizer, scheduler, epochs=20, returnBest=True)

# save the best model from training for 100 epochs 
torch.save(advModel_2.state_dict(), "../models/advTraining_smLR.pth.tar")
# Out:
# cuda
#
# Epoch 1/20:
# Iteration 0, loss = 1.1384
# cuda
# Got 7723 / 24000 correct (32.18)
#
# Iteration 100, loss = 1.0681
# cuda
# Got 9671 / 24000 correct (40.30)
#
# cuda
# Got 9958 / 24000 correct (41.49)
# cuda
# Got 60583 / 144000 correct (42.07)
#
# Epoch 2/20:
# Iteration 0, loss = 1.0730
# cuda
# Got 9969 / 24000 correct (41.54)
#
# Iteration 100, loss = 1.0520
# cuda
# Got 11010 / 24000 correct (45.88)
#
# cuda
# Got 11361 / 24000 correct (47.34)
# cuda
# Got 69386 / 144000 correct (48.18)
#
# Epoch 3/20:
# Iteration 0, loss = 1.0381
# cuda
# Got 11648 / 24000 correct (48.53)
#
# Iteration 100, loss = 1.0162
# cuda
# Got 12562 / 24000 correct (52.34)
#
# cuda
# Got 12798 / 24000 correct (53.33)
# cuda
# Got 77434 / 144000 correct (53.77)
#
# Epoch 4/20:
# Iteration 0, loss = 1.0099
# cuda
# Got 13062 / 24000 correct (54.43)
#
# Iteration 100, loss = 0.9736
# cuda
# Got 13683 / 24000 correct (57.01)
#
# cuda
# Got 14038 / 24000 correct (58.49)
# cuda
# Got 84024 / 144000 correct (58.35)
#
# Epoch 5/20:
# Iteration 0, loss = 0.9752
# cuda
# Got 14111 / 24000 correct (58.80)
#
# Iteration 100, loss = 0.9479
# cuda
# Got 14671 / 24000 correct (61.13)
#
# cuda
# Got 14911 / 24000 correct (62.13)
# cuda
# Got 89908 / 144000 correct (62.44)
#
# Epoch 6/20:
# Iteration 0, loss = 0.9334
# cuda
# Got 14902 / 24000 correct (62.09)
#
# Iteration 100, loss = 0.9098
# cuda
# Got 15433 / 24000 correct (64.30)
#
# cuda
# Got 15638 / 24000 correct (65.16)
# cuda
# Got 94018 / 144000 correct (65.29)
#
# Epoch 7/20:
# Iteration 0, loss = 0.8944
# cuda
# Got 15590 / 24000 correct (64.96)
#
# Iteration 100, loss = 0.8974
# cuda
# Got 15909 / 24000 correct (66.29)
#
# cuda
# Got 16119 / 24000 correct (67.16)
# Epoch     6: reducing learning rate of group 0 to 6.0000e-06.
# cuda
# Got 97153 / 144000 correct (67.47)
#
# Epoch 8/20:
# Iteration 0, loss = 0.8718
# cuda
# Got 16183 / 24000 correct (67.43)
#
# Iteration 100, loss = 0.8787
# cuda
# Got 16329 / 24000 correct (68.04)
#
# cuda
# Got 16469 / 24000 correct (68.62)
# cuda
# Got 98430 / 144000 correct (68.35)
#
# Epoch 9/20:
# Iteration 0, loss = 0.8664
# cuda
# Got 16570 / 24000 correct (69.04)
#
# Iteration 100, loss = 0.8567
# cuda
# Got 16604 / 24000 correct (69.18)
#
# cuda
# Got 16603 / 24000 correct (69.18)
# cuda
# Got 100041 / 144000 correct (69.47)
#
# Epoch 10/20:
# Iteration 0, loss = 0.8570
# cuda
# Got 16558 / 24000 correct (68.99)
#
# Iteration 100, loss = 0.8392
# cuda
# Got 16726 / 24000 correct (69.69)
#
# cuda
# Got 16897 / 24000 correct (70.40)
# cuda
# Got 100985 / 144000 correct (70.13)
#
# Epoch 11/20:
# Iteration 0, loss = 0.8312
# cuda
# Got 16793 / 24000 correct (69.97)
#
# Iteration 100, loss = 0.8370
# cuda
# Got 16935 / 24000 correct (70.56)
#
# cuda
# Got 16902 / 24000 correct (70.43)
# cuda
# Got 101874 / 144000 correct (70.75)
#
# Epoch 12/20:
# Iteration 0, loss = 0.8204
# cuda
# Got 16962 / 24000 correct (70.67)
#
# Iteration 100, loss = 0.8174
# cuda
# Got 17123 / 24000 correct (71.35)
#
# cuda
# Got 17091 / 24000 correct (71.21)
# cuda
# Got 102970 / 144000 correct (71.51)
#
# Epoch 13/20:
# Iteration 0, loss = 0.8186
# cuda
# Got 17152 / 24000 correct (71.47)
#
# Iteration 100, loss = 0.8095
# cuda
# Got 17189 / 24000 correct (71.62)
#
# cuda
# Got 17240 / 24000 correct (71.83)
# Epoch    12: reducing learning rate of group 0 to 3.6000e-06.
# cuda
# Got 103477 / 144000 correct (71.86)
#
# Epoch 14/20:
# Iteration 0, loss = 0.8047
# cuda
# Got 17230 / 24000 correct (71.79)
#
# Iteration 100, loss = 0.7982
# cuda
# Got 17402 / 24000 correct (72.51)
#
# cuda
# Got 17334 / 24000 correct (72.22)
# cuda
# Got 104197 / 144000 correct (72.36)
#
# Epoch 15/20:
# Iteration 0, loss = 0.8007
# cuda
# Got 17353 / 24000 correct (72.30)
#
# Iteration 100, loss = 0.7844
# cuda
# Got 17372 / 24000 correct (72.38)
#
# cuda
# Got 17522 / 24000 correct (73.01)
# cuda
# Got 104615 / 144000 correct (72.65)
#
# Epoch 16/20:
# Iteration 0, loss = 0.7855
# cuda
# Got 17404 / 24000 correct (72.52)
#
# Iteration 100, loss = 0.7876
# cuda
# Got 17563 / 24000 correct (73.18)
#
# cuda
# Got 17460 / 24000 correct (72.75)
# cuda
# Got 104684 / 144000 correct (72.70)
#
# Epoch 17/20:
# Iteration 0, loss = 0.7768
# cuda
# Got 17393 / 24000 correct (72.47)
#
# Iteration 100, loss = 0.7833
# cuda
# Got 17443 / 24000 correct (72.68)
#
# cuda
# Got 17541 / 24000 correct (73.09)
# cuda
# Got 104990 / 144000 correct (72.91)
#
# Epoch 18/20:
# Iteration 0, loss = 0.7682
# cuda
# Got 17508 / 24000 correct (72.95)
#
# Iteration 100, loss = 0.7768
# cuda
# Got 17552 / 24000 correct (73.13)
#
# cuda
# Got 17516 / 24000 correct (72.98)
# cuda
# Got 105498 / 144000 correct (73.26)
#
# Epoch 19/20:
# Iteration 0, loss = 0.7761
# cuda
# Got 17525 / 24000 correct (73.02)
#
# Iteration 100, loss = 0.7739
# cuda
# Got 17589 / 24000 correct (73.29)
#
# cuda
# Got 17645 / 24000 correct (73.52)
# Epoch    18: reducing learning rate of group 0 to 2.1600e-06.
# cuda
# Got 105615 / 144000 correct (73.34)
#
# Epoch 20/20:
# Iteration 0, loss = 0.7636
# cuda
# Got 17543 / 24000 correct (73.10)
#
# Iteration 100, loss = 0.7674
# cuda
# Got 17680 / 24000 correct (73.67)
#
# cuda
# Got 17601 / 24000 correct (73.34)
# cuda
# Got 105887 / 144000 correct (73.53)

# %%
trainingMetrics(hist)

# %%
# this loss curve looks better --> let's train this model again for 50 epochs or so, and train another model 
# that has a slightly higher initial learning rate ~ 1e-4
