# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Loading the other modules I have in parent directories
import sys
PYTHONPATH="../"
sys.path.append(PYTHONPATH)
from dataProcessing import getDataLoaders
from models import ThreeCNN, ThreeCNN_Module, rnn_2dCNN
from train import check_accuracy, train, train_ThreeCNN
from plottingFcts import trainingMetrics, sigBkgEff, plotROC
from imageNumber_analysis import num_valAcc 
from learn_rate_optimize import filters_optimize, lr_optimize, lr_filters_optimize
import matplotlib.pyplot as plt

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
layer0_params = [80, 3, 3, 1, 1]
layer0_reduce = [1, 3, 93, 1, 1] # ---> Downsampling with one filter at the end

layer1_params = [80, 3, 3, 1, 1]
layer1_reduce = [1, 12, 9, 1, 1] # ---> Downsampling with one filter 

layer2_params = [80, 3, 3, 1, 1]
layer2_reduce = [1, 12, 3, 1, 1] # ---> downsampling with one filter 

rnn_params = [18, 18, 1]

layer3_params = [32, 3, 3, 1, 1]

fc_params = [18, 150, 100, 50, 3, 0.5]

# %%
batch_size = 64
loader_train, loader_val, loader_test = getDataLoaders(batch_size=batch_size, N=30000)

# %%
advanced_rnn_2 = rnn_2dCNN(layer0_params, layer0_reduce, layer1_params, layer1_reduce, layer2_params, layer2_reduce, rnn_params, layer3_params, fc_params)

adv_optimizer = optim.Adam(advanced_rnn_2.parameters(), lr=4e-3)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(adv_optimizer, mode='max', patience=5, verbose=True)

hist, advModel = train(loader_train, loader_val, advanced_rnn_2, adv_optimizer, scheduler, epochs=50, returnBest=True)

# save the best movel from training for 100 epochs 
torch.save(advModel.state_dict(), "../models/advTraining_2.pth.tar")
# Out:
# cuda
#
# Epoch 1/50:
# Iteration 0, loss = 1.1670
# cuda
# Got 3139 / 9000 correct (34.88)
#
# Iteration 100, loss = 0.6833
# cuda
# Got 5863 / 9000 correct (65.14)
#
# Iteration 200, loss = 0.5442
# cuda
# Got 6029 / 9000 correct (66.99)
#
# Iteration 300, loss = 0.4638
# cuda
# Got 6162 / 9000 correct (68.47)
#
# Iteration 400, loss = 0.5616
# cuda
# Got 6507 / 9000 correct (72.30)
#
# Iteration 500, loss = 0.6775
# cuda
# Got 6464 / 9000 correct (71.82)
#
# Iteration 600, loss = 0.4839
# cuda
# Got 6715 / 9000 correct (74.61)
#
# Iteration 700, loss = 0.4409
# cuda
# Got 6624 / 9000 correct (73.60)
#
# Iteration 800, loss = 0.4549
# cuda
# Got 6722 / 9000 correct (74.69)
#
# cuda
# Got 6739 / 9000 correct (74.88)
# cuda
# Got 40233 / 54000 correct (74.51)
#
# Epoch 2/50:
# Iteration 0, loss = 0.3409
# cuda
# Got 6758 / 9000 correct (75.09)
#
# Iteration 100, loss = 0.5224
# cuda
# Got 6629 / 9000 correct (73.66)
#
# Iteration 200, loss = 0.4437
# cuda
# Got 6765 / 9000 correct (75.17)
#
# Iteration 300, loss = 0.4210
# cuda
# Got 6740 / 9000 correct (74.89)
#
# Iteration 400, loss = 0.4289
# cuda
# Got 6774 / 9000 correct (75.27)
#
# Iteration 500, loss = 0.5469
# cuda
# Got 6731 / 9000 correct (74.79)
#
# Iteration 600, loss = 0.4402
# cuda
# Got 6748 / 9000 correct (74.98)
#
# Iteration 700, loss = 0.4526
# cuda
# Got 6807 / 9000 correct (75.63)
#
# Iteration 800, loss = 0.5173
# cuda
# Got 6666 / 9000 correct (74.07)
#
# cuda
# Got 6826 / 9000 correct (75.84)
# cuda
# Got 40715 / 54000 correct (75.40)
#
# Epoch 3/50:
# Iteration 0, loss = 0.4223
# cuda
# Got 6809 / 9000 correct (75.66)
#
# Iteration 100, loss = 0.4555
# cuda
# Got 6799 / 9000 correct (75.54)
#
# Iteration 200, loss = 0.3811
# cuda
# Got 6825 / 9000 correct (75.83)
#
# Iteration 300, loss = 0.3512
# cuda
# Got 6827 / 9000 correct (75.86)
#
# Iteration 400, loss = 0.4118
# cuda
# Got 6776 / 9000 correct (75.29)
#
# Iteration 500, loss = 0.5589
# cuda
# Got 6719 / 9000 correct (74.66)
#
# Iteration 600, loss = 0.4611
# cuda
# Got 6819 / 9000 correct (75.77)
#
# Iteration 700, loss = 0.4139
# cuda
# Got 6853 / 9000 correct (76.14)
#
# Iteration 800, loss = 0.5409
# cuda
# Got 6860 / 9000 correct (76.22)
#
# cuda
# Got 6894 / 9000 correct (76.60)
# cuda
# Got 41228 / 54000 correct (76.35)
#
# Epoch 4/50:
# Iteration 0, loss = 0.3490
# cuda
# Got 6894 / 9000 correct (76.60)
#
# Iteration 100, loss = 0.5157
# cuda
# Got 6845 / 9000 correct (76.06)
#
# Iteration 200, loss = 0.4960
# cuda
# Got 6892 / 9000 correct (76.58)
#
# Iteration 300, loss = 0.4483
# cuda
# Got 6865 / 9000 correct (76.28)
#
# Iteration 400, loss = 0.6993
# cuda
# Got 6873 / 9000 correct (76.37)
#
# Iteration 500, loss = 0.5744
# cuda
# Got 6908 / 9000 correct (76.76)
#
# Iteration 600, loss = 0.3885
# cuda
# Got 6857 / 9000 correct (76.19)
#
# Iteration 700, loss = 0.5352
# cuda
# Got 6901 / 9000 correct (76.68)
#
# Iteration 800, loss = 0.3597
# cuda
# Got 6892 / 9000 correct (76.58)
#
# cuda
# Got 6941 / 9000 correct (77.12)
# cuda
# Got 41434 / 54000 correct (76.73)
#
# Epoch 5/50:
# Iteration 0, loss = 0.6917
# cuda
# Got 6902 / 9000 correct (76.69)
#
# Iteration 100, loss = 0.4914
# cuda
# Got 6793 / 9000 correct (75.48)
#
# Iteration 200, loss = 0.4203
# cuda
# Got 6848 / 9000 correct (76.09)
#
# Iteration 300, loss = 0.3298
# cuda
# Got 6885 / 9000 correct (76.50)
#
# Iteration 400, loss = 0.4079
# cuda
# Got 6912 / 9000 correct (76.80)
#
# Iteration 500, loss = 0.4940
# cuda
# Got 6886 / 9000 correct (76.51)
#
# Iteration 600, loss = 0.3365
# cuda
# Got 6914 / 9000 correct (76.82)
#
# Iteration 700, loss = 0.4046
# cuda
# Got 6930 / 9000 correct (77.00)
#
# Iteration 800, loss = 0.4808
# cuda
# Got 6884 / 9000 correct (76.49)
#
# cuda
# Got 6882 / 9000 correct (76.47)
# cuda
# Got 41187 / 54000 correct (76.27)
#
# Epoch 6/50:
# Iteration 0, loss = 0.4777
# cuda
# Got 6911 / 9000 correct (76.79)
#
# Iteration 100, loss = 0.3849
# cuda
# Got 6897 / 9000 correct (76.63)
#
# Iteration 200, loss = 0.4403
# cuda
# Got 6909 / 9000 correct (76.77)
#
# Iteration 300, loss = 0.4557
# cuda
# Got 6842 / 9000 correct (76.02)
#
# Iteration 400, loss = 0.4369
# cuda
# Got 6797 / 9000 correct (75.52)
#
# Iteration 500, loss = 0.4564
# cuda
# Got 6913 / 9000 correct (76.81)
#
# Iteration 600, loss = 0.4438
# cuda
# Got 6922 / 9000 correct (76.91)
#
# Iteration 700, loss = 0.3652
# cuda
# Got 6832 / 9000 correct (75.91)
#
# Iteration 800, loss = 0.3612
# cuda
# Got 6936 / 9000 correct (77.07)
#
# cuda
# Got 6974 / 9000 correct (77.49)
# cuda
# Got 41762 / 54000 correct (77.34)
#
# Epoch 7/50:
# Iteration 0, loss = 0.4546
# cuda
# Got 6988 / 9000 correct (77.64)
#
# Iteration 100, loss = 0.3875
# cuda
# Got 6969 / 9000 correct (77.43)
#
# Iteration 200, loss = 0.5057
# cuda
# Got 6915 / 9000 correct (76.83)
#
# Iteration 300, loss = 0.4209
# cuda
# Got 6941 / 9000 correct (77.12)
#
# Iteration 400, loss = 0.4316
# cuda
# Got 6767 / 9000 correct (75.19)
#
# Iteration 500, loss = 0.4079
# cuda
# Got 6874 / 9000 correct (76.38)
#
# Iteration 600, loss = 0.3559
# cuda
# Got 6933 / 9000 correct (77.03)
#
# Iteration 700, loss = 0.4875
# cuda
# Got 6955 / 9000 correct (77.28)
#
# Iteration 800, loss = 0.4606
# cuda
# Got 6953 / 9000 correct (77.26)
#
# cuda
# Got 6890 / 9000 correct (76.56)
# cuda
# Got 41440 / 54000 correct (76.74)
#
# Epoch 8/50:
# Iteration 0, loss = 0.4421
# cuda
# Got 6925 / 9000 correct (76.94)
#
# Iteration 100, loss = 0.4619
# cuda
# Got 6961 / 9000 correct (77.34)
#
# Iteration 200, loss = 0.4539
# cuda
# Got 6989 / 9000 correct (77.66)
#
# Iteration 300, loss = 0.4898
# cuda
# Got 6988 / 9000 correct (77.64)
#
# Iteration 400, loss = 0.3759
# cuda
# Got 6964 / 9000 correct (77.38)
#
# Iteration 500, loss = 0.4208
# cuda
# Got 6876 / 9000 correct (76.40)
#
# Iteration 600, loss = 0.4185
# cuda
# Got 6919 / 9000 correct (76.88)
#
# Iteration 700, loss = 0.3774
# cuda
# Got 6877 / 9000 correct (76.41)
#
# Iteration 800, loss = 0.5352
# cuda
# Got 6911 / 9000 correct (76.79)
#
# cuda
# Got 7028 / 9000 correct (78.09)
# cuda
# Got 41901 / 54000 correct (77.59)
#
# Epoch 9/50:
# Iteration 0, loss = 0.3503
# cuda
# Got 6990 / 9000 correct (77.67)
#
# Iteration 100, loss = 0.4511
# cuda
# Got 6891 / 9000 correct (76.57)
#
# Iteration 200, loss = 0.3756
# cuda
# Got 6964 / 9000 correct (77.38)
#
# Iteration 300, loss = 0.3884
# cuda
# Got 6879 / 9000 correct (76.43)
#
# Iteration 400, loss = 0.4703
# cuda
# Got 6838 / 9000 correct (75.98)
#
# Iteration 500, loss = 0.3471
# cuda
# Got 6891 / 9000 correct (76.57)
#
# Iteration 600, loss = 0.3865
# cuda
# Got 6983 / 9000 correct (77.59)
#
# Iteration 700, loss = 0.6220
# cuda
# Got 6925 / 9000 correct (76.94)
#
# Iteration 800, loss = 0.3672
# cuda
# Got 6858 / 9000 correct (76.20)
#
# cuda
# Got 6947 / 9000 correct (77.19)
# cuda
# Got 41726 / 54000 correct (77.27)
#
# Epoch 10/50:
# Iteration 0, loss = 0.3807
# cuda
# Got 6975 / 9000 correct (77.50)
#
# Iteration 100, loss = 0.3551
# cuda
# Got 6953 / 9000 correct (77.26)
#
# Iteration 200, loss = 0.3581
# cuda
# Got 6993 / 9000 correct (77.70)
#
# Iteration 300, loss = 0.4277
# cuda
# Got 6964 / 9000 correct (77.38)
#
# Iteration 400, loss = 0.4476
# cuda
# Got 6985 / 9000 correct (77.61)
#
# Iteration 500, loss = 0.4972
# cuda
# Got 6957 / 9000 correct (77.30)
#
# Iteration 600, loss = 0.3778
# cuda
# Got 6960 / 9000 correct (77.33)
#
# Iteration 700, loss = 0.4653
# cuda
# Got 6973 / 9000 correct (77.48)
#
# Iteration 800, loss = 0.4592
# cuda
# Got 6981 / 9000 correct (77.57)
#
# cuda
# Got 6944 / 9000 correct (77.16)
# cuda
# Got 41862 / 54000 correct (77.52)
#
# Epoch 11/50:
# Iteration 0, loss = 0.4385
# cuda
# Got 6988 / 9000 correct (77.64)
#
# Iteration 100, loss = 0.3924
# cuda
# Got 6976 / 9000 correct (77.51)
#
# Iteration 200, loss = 0.3505
# cuda
# Got 6980 / 9000 correct (77.56)
#
# Iteration 300, loss = 0.3895
# cuda
# Got 6974 / 9000 correct (77.49)
#
# Iteration 400, loss = 0.3814
# cuda
# Got 6878 / 9000 correct (76.42)
#
# Iteration 500, loss = 0.3597
# cuda
# Got 7010 / 9000 correct (77.89)
#
# Iteration 600, loss = 0.3584
# cuda
# Got 6910 / 9000 correct (76.78)
#
# Iteration 700, loss = 0.4869
# cuda
# Got 6970 / 9000 correct (77.44)
#
# Iteration 800, loss = 0.4522
# cuda
# Got 6959 / 9000 correct (77.32)
#
# cuda
# Got 6986 / 9000 correct (77.62)
# cuda
# Got 41863 / 54000 correct (77.52)
#
# Epoch 12/50:
# Iteration 0, loss = 0.4150
# cuda
# Got 7001 / 9000 correct (77.79)
#
# Iteration 100, loss = 0.3451
# cuda
# Got 6990 / 9000 correct (77.67)
#
# Iteration 200, loss = 0.4274
# cuda
# Got 6843 / 9000 correct (76.03)
#
# Iteration 300, loss = 0.3498
# cuda
# Got 6936 / 9000 correct (77.07)
#
# Iteration 400, loss = 0.4644
# cuda
# Got 6960 / 9000 correct (77.33)
#
# Iteration 500, loss = 0.4787
# cuda
# Got 6948 / 9000 correct (77.20)
#
# Iteration 600, loss = 0.3389
# cuda
# Got 7001 / 9000 correct (77.79)
#
# Iteration 700, loss = 0.4385
# cuda
# Got 7002 / 9000 correct (77.80)
#
# Iteration 800, loss = 0.3574
# cuda
# Got 7005 / 9000 correct (77.83)
# cuda
# Got 6986 / 9000 correct (77.62)
# cuda
# Got 41858 / 54000 correct (77.51)
#
# Epoch 13/50:
# Iteration 0, loss = 0.4080
# cuda
# Got 6980 / 9000 correct (77.56)
#
# Iteration 100, loss = 0.3789
# cuda
# Got 6906 / 9000 correct (76.73)
#
# Iteration 200, loss = 0.4271
# cuda
# Got 6901 / 9000 correct (76.68)
#
# Iteration 300, loss = 0.3438
# cuda
# Got 6950 / 9000 correct (77.22)
#
# Iteration 400, loss = 0.4811
# cuda
# Got 6990 / 9000 correct (77.67)
#
# Iteration 500, loss = 0.4662
# cuda
# Got 6980 / 9000 correct (77.56)
#
# Iteration 600, loss = 0.4974
# cuda
# Got 6886 / 9000 correct (76.51)
#
# Iteration 700, loss = 0.4832
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 800, loss = 0.3658
# cuda
# Got 7021 / 9000 correct (78.01)
#
# cuda
# Got 6964 / 9000 correct (77.38)
# cuda
# Got 41618 / 54000 correct (77.07)
#
# Epoch 14/50:
# Iteration 0, loss = 0.5075
# cuda
# Got 6973 / 9000 correct (77.48)
#
# Iteration 100, loss = 0.4127
# cuda
# Got 6982 / 9000 correct (77.58)
#
# Iteration 200, loss = 0.4417
# cuda
# Got 6972 / 9000 correct (77.47)
#
# Iteration 300, loss = 0.4364
# cuda
# Got 6934 / 9000 correct (77.04)
#
# Iteration 400, loss = 0.5212
# cuda
# Got 6974 / 9000 correct (77.49)
#
# Iteration 500, loss = 0.3933
# cuda
# Got 6991 / 9000 correct (77.68)
#
# Iteration 600, loss = 0.5282
# cuda
# Got 6937 / 9000 correct (77.08)
#
# Iteration 700, loss = 0.4891
# cuda
# Got 6881 / 9000 correct (76.46)
#
# Iteration 800, loss = 0.4431
# cuda
# Got 7001 / 9000 correct (77.79)
#
# cuda
# Got 6911 / 9000 correct (76.79)
# Epoch    13: reducing learning rate of group 0 to 4.0000e-04.
# cuda
# Got 41570 / 54000 correct (76.98)
#
# Epoch 15/50:
# Iteration 0, loss = 0.4869
# cuda
# Got 6929 / 9000 correct (76.99)
#
# Iteration 100, loss = 0.5635
# cuda
# Got 6992 / 9000 correct (77.69)
#
# Iteration 200, loss = 0.4267
# cuda
# Got 7006 / 9000 correct (77.84)
#
# Iteration 300, loss = 0.4642
# cuda
# Got 7009 / 9000 correct (77.88)
#
# Iteration 400, loss = 0.4314
# cuda
# Got 7018 / 9000 correct (77.98)
#
# Iteration 500, loss = 0.4290
# cuda
# Got 7018 / 9000 correct (77.98)
#
# Iteration 600, loss = 0.4256
# cuda
# Got 7001 / 9000 correct (77.79)
#
# Iteration 700, loss = 0.3939
# cuda
# Got 7015 / 9000 correct (77.94)
#
# Iteration 800, loss = 0.4427
# cuda
# Got 7043 / 9000 correct (78.26)
#
# cuda
# Got 7024 / 9000 correct (78.04)
# cuda
# Got 42048 / 54000 correct (77.87)
#
# Epoch 16/50:
# Iteration 0, loss = 0.3869
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 100, loss = 0.4754
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 200, loss = 0.3496
# cuda
# Got 7024 / 9000 correct (78.04)
#
# Iteration 300, loss = 0.4168
# cuda
# Got 7023 / 9000 correct (78.03)
#
# Iteration 400, loss = 0.4308
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 500, loss = 0.4275
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 600, loss = 0.3248
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 700, loss = 0.4437
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 800, loss = 0.4038
# cuda
# Got 7013 / 9000 correct (77.92)
#
# cuda
# Got 7066 / 9000 correct (78.51)
# cuda
# Got 42089 / 54000 correct (77.94)
#
# Epoch 17/50:
# Iteration 0, loss = 0.3130
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 100, loss = 0.3316
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 200, loss = 0.5003
# cuda
# Got 7024 / 9000 correct (78.04)
#
# Iteration 300, loss = 0.5730
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 400, loss = 0.3286
# cuda
# Got 7007 / 9000 correct (77.86)
#
# Iteration 500, loss = 0.4335
# cuda
# Got 7001 / 9000 correct (77.79)
#
# Iteration 600, loss = 0.3682
# cuda
# Got 7018 / 9000 correct (77.98)
#
# Iteration 700, loss = 0.3964
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 800, loss = 0.2798
# cuda
# Got 7032 / 9000 correct (78.13)
#
# cuda
# Got 7051 / 9000 correct (78.34)
# cuda
# Got 42123 / 54000 correct (78.01)
#
# Epoch 18/50:
# Iteration 0, loss = 0.3893
# cuda
# Got 7028 / 9000 correct (78.09)
#
# Iteration 100, loss = 0.5800
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 200, loss = 0.4527
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 300, loss = 0.3925
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 400, loss = 0.4604
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 500, loss = 0.3720
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 600, loss = 0.4335
# cuda
# Got 7035 / 9000 correct (78.17)
#
# Iteration 700, loss = 0.4480
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 800, loss = 0.3008
# cuda
# Got 7056 / 9000 correct (78.40)
#
# cuda
# Got 7024 / 9000 correct (78.04)
# cuda
# Got 42160 / 54000 correct (78.07)
#
# Epoch 19/50:
# Iteration 0, loss = 0.4020
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 100, loss = 0.3484
# cuda
# Got 7018 / 9000 correct (77.98)
#
# Iteration 200, loss = 0.4373
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 300, loss = 0.4517
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 400, loss = 0.4130
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 500, loss = 0.2991
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 600, loss = 0.5028
# cuda
# Got 7014 / 9000 correct (77.93)
#
# Iteration 700, loss = 0.4470
# cuda
# Got 7022 / 9000 correct (78.02)
#
# Iteration 800, loss = 0.4749
# cuda
# Got 7062 / 9000 correct (78.47)
#
# cuda
# Got 7048 / 9000 correct (78.31)
# cuda
# Got 42226 / 54000 correct (78.20)
#
# Epoch 20/50:
# Iteration 0, loss = 0.4038
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 100, loss = 0.3529
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 200, loss = 0.4021
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 300, loss = 0.3965
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 400, loss = 0.3332
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 500, loss = 0.4500
# cuda
# Got 7021 / 9000 correct (78.01)
#
# Iteration 600, loss = 0.4332
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 700, loss = 0.4867
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 800, loss = 0.3778
# cuda
# Got 7027 / 9000 correct (78.08)
#
# cuda
# Got 7026 / 9000 correct (78.07)
# cuda
# Got 42220 / 54000 correct (78.19)
#
# Epoch 21/50:
# Iteration 0, loss = 0.4164
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 100, loss = 0.4724
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 200, loss = 0.4389
# cuda
# Got 7016 / 9000 correct (77.96)
#
# Iteration 300, loss = 0.4019
# cuda
# Got 7024 / 9000 correct (78.04)
#
# Iteration 400, loss = 0.3338
# cuda
# Got 7017 / 9000 correct (77.97)
#
# Iteration 500, loss = 0.4004
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 600, loss = 0.5014
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 700, loss = 0.3787
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 800, loss = 0.3640
# cuda
# Got 7061 / 9000 correct (78.46)
#
# cuda
# Got 7054 / 9000 correct (78.38)
# cuda
# Got 42267 / 54000 correct (78.27)
#
# Epoch 22/50:
# Iteration 0, loss = 0.4125
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 100, loss = 0.5099
# cuda
# Got 6999 / 9000 correct (77.77)
#
# Iteration 200, loss = 0.4184
# cuda
# Got 7028 / 9000 correct (78.09)
#
# Iteration 300, loss = 0.3912
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 400, loss = 0.4488
# cuda
# Got 7067 / 9000 correct (78.52)
#
# Iteration 500, loss = 0.3854
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 600, loss = 0.3848
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 700, loss = 0.4041
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 800, loss = 0.4935
# cuda
# Got 7031 / 9000 correct (78.12)
#
# cuda
# Got 7056 / 9000 correct (78.40)
# Epoch    21: reducing learning rate of group 0 to 4.0000e-05.
# cuda
# Got 42144 / 54000 correct (78.04)
#
# Epoch 23/50:
# Iteration 0, loss = 0.4389
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 100, loss = 0.4044
# cuda
# Got 7019 / 9000 correct (77.99)
#
# Iteration 200, loss = 0.3103
# cuda
# Got 7068 / 9000 correct (78.53)
#
# Iteration 300, loss = 0.5169
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 400, loss = 0.3610
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 500, loss = 0.5161
# cuda
# Got 7011 / 9000 correct (77.90)
#
# Iteration 600, loss = 0.3870
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 700, loss = 0.4965
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 800, loss = 0.4775
# cuda
# Got 7040 / 9000 correct (78.22)
#
# cuda
# Got 7062 / 9000 correct (78.47)
# cuda
# Got 42181 / 54000 correct (78.11)
#
# Epoch 24/50:
# Iteration 0, loss = 0.4843
# cuda
# Got 7021 / 9000 correct (78.01)
#
# Iteration 100, loss = 0.4810
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 200, loss = 0.3136
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 300, loss = 0.4111
# cuda
# Got 7014 / 9000 correct (77.93)
#
# Iteration 400, loss = 0.3527
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 500, loss = 0.4276
# cuda
# Got 7040 / 9000 correct (78.22)
# Iteration 600, loss = 0.2998
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 700, loss = 0.2657
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 800, loss = 0.4462
# cuda
# Got 7043 / 9000 correct (78.26)
#
# cuda
# Got 7071 / 9000 correct (78.57)
# cuda
# Got 42224 / 54000 correct (78.19)
#
# Epoch 25/50:
# Iteration 0, loss = 0.4484
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 100, loss = 0.4232
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 200, loss = 0.3979
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 300, loss = 0.4604
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 400, loss = 0.3201
# cuda
# Got 7073 / 9000 correct (78.59)
#
# Iteration 500, loss = 0.3708
# cuda
# Got 7068 / 9000 correct (78.53)
#
# Iteration 600, loss = 0.4360
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 700, loss = 0.3959
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 800, loss = 0.3925
# cuda
# Got 7043 / 9000 correct (78.26)
#
# cuda
# Got 7072 / 9000 correct (78.58)
# cuda
# Got 42225 / 54000 correct (78.19)
#
# Epoch 26/50:
# Iteration 0, loss = 0.4263
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 100, loss = 0.4274
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 200, loss = 0.3967
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 300, loss = 0.3785
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 400, loss = 0.3124
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 500, loss = 0.4609
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 600, loss = 0.3470
# cuda
# Got 7017 / 9000 correct (77.97)
#
# Iteration 700, loss = 0.3861
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 800, loss = 0.3894
# cuda
# Got 7056 / 9000 correct (78.40)
#
# cuda
# Got 7084 / 9000 correct (78.71)
# cuda
# Got 42241 / 54000 correct (78.22)
#
# Epoch 27/50:
# Iteration 0, loss = 0.4168
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 100, loss = 0.4159
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 200, loss = 0.3774
# cuda
# Got 7031 / 9000 correct (78.12)
#
# Iteration 300, loss = 0.3845
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 400, loss = 0.3725
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 500, loss = 0.4364
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 600, loss = 0.3359
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 700, loss = 0.4337
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 800, loss = 0.4245
# cuda
# Got 7029 / 9000 correct (78.10)
#
# cuda
# Got 7023 / 9000 correct (78.03)
# cuda
# Got 42278 / 54000 correct (78.29)
#
# Epoch 28/50:
# Iteration 0, loss = 0.3633
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 100, loss = 0.4810
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 200, loss = 0.4564
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 300, loss = 0.4691
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 400, loss = 0.4836
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 500, loss = 0.3201
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 600, loss = 0.3636
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 700, loss = 0.4258
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 800, loss = 0.3232
# cuda
# Got 7048 / 9000 correct (78.31)
#
# cuda
# Got 7038 / 9000 correct (78.20)
# cuda
# Got 42287 / 54000 correct (78.31)
#
# Epoch 29/50:
# Iteration 0, loss = 0.3826
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 100, loss = 0.4652
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 200, loss = 0.3684
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 300, loss = 0.4064
# cuda
# Got 7066 / 9000 correct (78.51)
#
# Iteration 400, loss = 0.4100
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 500, loss = 0.4133
# cuda
# Got 7024 / 9000 correct (78.04)
#
# Iteration 600, loss = 0.4009
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 700, loss = 0.3689
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 800, loss = 0.3931
# cuda
# Got 7022 / 9000 correct (78.02)
#
# cuda
# Got 7045 / 9000 correct (78.28)
# cuda
# Got 42265 / 54000 correct (78.27)
#
# Epoch 30/50:
# Iteration 0, loss = 0.4029
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 100, loss = 0.4243
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 200, loss = 0.3767
# cuda
# Got 7072 / 9000 correct (78.58)
#
# Iteration 300, loss = 0.4184
# cuda
# Got 7069 / 9000 correct (78.54)
#
# Iteration 400, loss = 0.4605
# cuda
# Got 7080 / 9000 correct (78.67)
#
# Iteration 500, loss = 0.3628
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 600, loss = 0.6076
# cuda
# Got 7077 / 9000 correct (78.63)
#
# Iteration 700, loss = 0.4416
# cuda
# Got 7037 / 9000 correct (78.19)
#
# Iteration 800, loss = 0.3857
# cuda
# Got 7028 / 9000 correct (78.09)
#
# cuda
# Got 7031 / 9000 correct (78.12)
# cuda
# Got 42218 / 54000 correct (78.18)
#
# Epoch 31/50:
# Iteration 0, loss = 0.3730
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 100, loss = 0.3962
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 200, loss = 0.3963
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 300, loss = 0.3873
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 400, loss = 0.4767
# cuda
# Got 7028 / 9000 correct (78.09)
#
# Iteration 500, loss = 0.3821
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 600, loss = 0.4547
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 700, loss = 0.3978
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 800, loss = 0.3767
# cuda
# Got 7060 / 9000 correct (78.44)
#
# cuda
# Got 7059 / 9000 correct (78.43)
# cuda
# Got 42239 / 54000 correct (78.22)
#
# Epoch 32/50:
# Iteration 0, loss = 0.4488
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 100, loss = 0.3681
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 200, loss = 0.3811
# cuda
# Got 7068 / 9000 correct (78.53)
#
# Iteration 300, loss = 0.4045
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 400, loss = 0.4223
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 500, loss = 0.5382
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 600, loss = 0.3699
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 700, loss = 0.3582
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 800, loss = 0.3110
# cuda
# Got 7049 / 9000 correct (78.32)
#
# cuda
# Got 7029 / 9000 correct (78.10)
# Epoch    31: reducing learning rate of group 0 to 4.0000e-06.
# cuda
# Got 42222 / 54000 correct (78.19)
#
# Epoch 33/50:
# Iteration 0, loss = 0.3295
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 100, loss = 0.4247
# cuda
# Got 7004 / 9000 correct (77.82)
#
# Iteration 200, loss = 0.3887
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 300, loss = 0.4221
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 400, loss = 0.3542
# cuda
# Got 7060 / 9000 correct (78.44)
#
# Iteration 500, loss = 0.3615
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 600, loss = 0.3369
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 700, loss = 0.5329
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 800, loss = 0.4442
# cuda
# Got 7036 / 9000 correct (78.18)
#
# cuda
# Got 7048 / 9000 correct (78.31)
# cuda
# Got 42309 / 54000 correct (78.35)
#
# Epoch 34/50:
# Iteration 0, loss = 0.3908
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 100, loss = 0.4532
# cuda
# Got 7031 / 9000 correct (78.12)
#
# Iteration 200, loss = 0.4793
# cuda
# Got 7035 / 9000 correct (78.17)
#
# Iteration 300, loss = 0.4250
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 400, loss = 0.4119
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 500, loss = 0.3255
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 600, loss = 0.3672
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 700, loss = 0.3588
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 800, loss = 0.3034
# cuda
# Got 7019 / 9000 correct (77.99)
#
# cuda
# Got 7050 / 9000 correct (78.33)
# cuda
# Got 42258 / 54000 correct (78.26)
#
# Epoch 35/50:
# Iteration 0, loss = 0.4461
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 100, loss = 0.4248
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 200, loss = 0.4009
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 300, loss = 0.4633
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 400, loss = 0.5021
# cuda
# Got 7020 / 9000 correct (78.00)
#
# Iteration 500, loss = 0.4188
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 600, loss = 0.4450
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 700, loss = 0.4261
# cuda
# Got 7023 / 9000 correct (78.03)
#
# Iteration 800, loss = 0.3319
# cuda
# Got 7072 / 9000 correct (78.58)
#
# cuda
# Got 7037 / 9000 correct (78.19)
# cuda
# Got 42235 / 54000 correct (78.21)
#
# Epoch 36/50:
# Iteration 0, loss = 0.5309
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 100, loss = 0.4176
# cuda
# Got 7083 / 9000 correct (78.70)
#
# Iteration 200, loss = 0.4072
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 300, loss = 0.3288
# cuda
# Got 7033 / 9000 correct (78.14)
# Iteration 400, loss = 0.4980
# cuda
# Got 7026 / 9000 correct (78.07)
#
# Iteration 500, loss = 0.3127
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 600, loss = 0.3111
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 700, loss = 0.4280
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 800, loss = 0.3954
# cuda
# Got 7050 / 9000 correct (78.33)
#
# cuda
# Got 7033 / 9000 correct (78.14)
# cuda
# Got 42194 / 54000 correct (78.14)
#
# Epoch 37/50:
# Iteration 0, loss = 0.2903
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 100, loss = 0.3743
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 200, loss = 0.3573
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 300, loss = 0.2871
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 400, loss = 0.4185
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 500, loss = 0.4044
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 600, loss = 0.4538
# cuda
# Got 7008 / 9000 correct (77.87)
#
# Iteration 700, loss = 0.2897
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 800, loss = 0.4271
# cuda
# Got 7067 / 9000 correct (78.52)
#
# cuda
# Got 7048 / 9000 correct (78.31)
# cuda
# Got 42218 / 54000 correct (78.18)
#
# Epoch 38/50:
# Iteration 0, loss = 0.3666
# cuda
# Got 7041 / 9000 correct (78.23)
#
# Iteration 100, loss = 0.3516
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 200, loss = 0.3759
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 300, loss = 0.3324
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 400, loss = 0.3579
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 500, loss = 0.4334
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 600, loss = 0.5406
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 700, loss = 0.3619
# cuda
# Got 7069 / 9000 correct (78.54)
#
# Iteration 800, loss = 0.3603
# cuda
# Got 7031 / 9000 correct (78.12)
#
# cuda
# Got 7047 / 9000 correct (78.30)
# Epoch    37: reducing learning rate of group 0 to 4.0000e-07.
# cuda
# Got 42239 / 54000 correct (78.22)
#
# Epoch 39/50:
# Iteration 0, loss = 0.3721
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 100, loss = 0.3615
# cuda
# Got 7063 / 9000 correct (78.48)
#
# Iteration 200, loss = 0.3766
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 300, loss = 0.4583
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 400, loss = 0.2903
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 500, loss = 0.3302
# cuda
# Got 7071 / 9000 correct (78.57)
#
# Iteration 600, loss = 0.5204
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 700, loss = 0.4428
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 800, loss = 0.4215
# cuda
# Got 7054 / 9000 correct (78.38)
#
# cuda
# Got 7014 / 9000 correct (77.93)
# cuda
# Got 42262 / 54000 correct (78.26)
#
# Epoch 40/50:
# Iteration 0, loss = 0.3459
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 100, loss = 0.3826
# cuda
# Got 7013 / 9000 correct (77.92)
#
# Iteration 200, loss = 0.4640
# cuda
# Got 7049 / 9000 correct (78.32)
#
# Iteration 300, loss = 0.3328
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 400, loss = 0.3863
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 500, loss = 0.4140
# cuda
# Got 7064 / 9000 correct (78.49)
#
# Iteration 600, loss = 0.3084
# cuda
# Got 7066 / 9000 correct (78.51)
#
# Iteration 700, loss = 0.4638
# cuda
# Got 7021 / 9000 correct (78.01)
#
# Iteration 800, loss = 0.4355
# cuda
# Got 7014 / 9000 correct (77.93)
#
# cuda
# Got 7031 / 9000 correct (78.12)
# cuda
# Got 42187 / 54000 correct (78.12)
#
# Epoch 41/50:
# Iteration 0, loss = 0.4054
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 100, loss = 0.3879
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 200, loss = 0.3903
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 300, loss = 0.3341
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 400, loss = 0.4793
# cuda
# Got 7009 / 9000 correct (77.88)
#
# Iteration 500, loss = 0.3821
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 600, loss = 0.4565
# cuda
# Got 7063 / 9000 correct (78.48)
#
# Iteration 700, loss = 0.2696
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 800, loss = 0.4426
# cuda
# Got 7030 / 9000 correct (78.11)
#
# cuda
# Got 7060 / 9000 correct (78.44)
# cuda
# Got 42207 / 54000 correct (78.16)
#
# Epoch 42/50:
# Iteration 0, loss = 0.4956
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 100, loss = 0.4204
# cuda
# Got 7029 / 9000 correct (78.10)
#
# Iteration 200, loss = 0.4020
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 300, loss = 0.3054
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 400, loss = 0.3771
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 500, loss = 0.4705
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 600, loss = 0.3587
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 700, loss = 0.3964
# cuda
# Got 7055 / 9000 correct (78.39)
#
# Iteration 800, loss = 0.3491
# cuda
# Got 7041 / 9000 correct (78.23)
#
# cuda
# Got 7062 / 9000 correct (78.47)
# cuda
# Got 42261 / 54000 correct (78.26)
#
# Epoch 43/50:
# Iteration 0, loss = 0.4164
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 100, loss = 0.3694
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 200, loss = 0.3741
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 300, loss = 0.3956
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 400, loss = 0.3357
# cuda
# Got 7027 / 9000 correct (78.08)
#
# Iteration 500, loss = 0.3292
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 600, loss = 0.5291
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 700, loss = 0.5133
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 800, loss = 0.4507
# cuda
# Got 7063 / 9000 correct (78.48)
#
# cuda
# Got 7055 / 9000 correct (78.39)
# cuda
# Got 42200 / 54000 correct (78.15)
#
# Epoch 44/50:
# Iteration 0, loss = 0.3945
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 100, loss = 0.5909
# cuda
# Got 7028 / 9000 correct (78.09)
#
# Iteration 200, loss = 0.3621
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 300, loss = 0.4415
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 400, loss = 0.3762
# cuda
# Got 7071 / 9000 correct (78.57)
#
# Iteration 500, loss = 0.3657
# cuda
# Got 7070 / 9000 correct (78.56)
#
# Iteration 600, loss = 0.3251
# cuda
# Got 7033 / 9000 correct (78.14)
#
# Iteration 700, loss = 0.3018
# cuda
# Got 7047 / 9000 correct (78.30)
#
# Iteration 800, loss = 0.4153
# cuda
# Got 7059 / 9000 correct (78.43)
#
# cuda
# Got 7039 / 9000 correct (78.21)
# Epoch    43: reducing learning rate of group 0 to 4.0000e-08.
# cuda
# Got 42225 / 54000 correct (78.19)
#
# Epoch 45/50:
# Iteration 0, loss = 0.4185
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 100, loss = 0.3690
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 200, loss = 0.3861
# cuda
# Got 7025 / 9000 correct (78.06)
#
# Iteration 300, loss = 0.4122
# cuda
# Got 7038 / 9000 correct (78.20)
#
# Iteration 400, loss = 0.3244
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 500, loss = 0.3444
# cuda
# Got 7030 / 9000 correct (78.11)
#
# Iteration 600, loss = 0.3350
# cuda
# Got 7059 / 9000 correct (78.43)
#
# Iteration 700, loss = 0.3897
# cuda
# Got 7054 / 9000 correct (78.38)
#
# Iteration 800, loss = 0.3931
# cuda
# Got 7063 / 9000 correct (78.48)
#
# cuda
# Got 7045 / 9000 correct (78.28)
# cuda
# Got 42299 / 54000 correct (78.33)
#
# Epoch 46/50:
# Iteration 0, loss = 0.4096
# cuda
# Got 7045 / 9000 correct (78.28)
#
# Iteration 100, loss = 0.4300
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 200, loss = 0.2755
# cuda
# Got 7028 / 9000 correct (78.09)
#
# Iteration 300, loss = 0.3651
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 400, loss = 0.3745
# cuda
# Got 7043 / 9000 correct (78.26)
#
# Iteration 500, loss = 0.3539
# cuda
# Got 7065 / 9000 correct (78.50)
#
# Iteration 600, loss = 0.3651
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 700, loss = 0.3747
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 800, loss = 0.3494
# cuda
# Got 7049 / 9000 correct (78.32)
#
# cuda
# Got 7066 / 9000 correct (78.51)
# cuda
# Got 42251 / 54000 correct (78.24)
#
# Epoch 47/50:
# Iteration 0, loss = 0.3239
# cuda
# Got 7057 / 9000 correct (78.41)
#
# Iteration 100, loss = 0.4592
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 200, loss = 0.3594
# cuda
# Got 7062 / 9000 correct (78.47)
#
# Iteration 300, loss = 0.3550
# cuda
# Got 7039 / 9000 correct (78.21)
#
# Iteration 400, loss = 0.4809
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 500, loss = 0.3530
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 600, loss = 0.4169
# cuda
# Got 7053 / 9000 correct (78.37)
#
# Iteration 700, loss = 0.3605
# cuda
# Got 7036 / 9000 correct (78.18)
#
# Iteration 800, loss = 0.4532
# cuda
# Got 7032 / 9000 correct (78.13)
#
# cuda
# Got 7052 / 9000 correct (78.36)
# cuda
# Got 42256 / 54000 correct (78.25)
#
# Epoch 48/50:
# Iteration 0, loss = 0.4267
# cuda
# Got 7029 / 9000 correct (78.10)
# Iteration 100, loss = 0.3564
# cuda
# Got 7052 / 9000 correct (78.36)
#
# Iteration 200, loss = 0.3597
# cuda
# Got 7022 / 9000 correct (78.02)
#
# Iteration 300, loss = 0.3296
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 400, loss = 0.4020
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 500, loss = 0.4288
# cuda
# Got 7074 / 9000 correct (78.60)
#
# Iteration 600, loss = 0.4631
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 700, loss = 0.6058
# cuda
# Got 7051 / 9000 correct (78.34)
#
# Iteration 800, loss = 0.3808
# cuda
# Got 7045 / 9000 correct (78.28)
#
# cuda
# Got 7026 / 9000 correct (78.07)
# cuda
# Got 42271 / 54000 correct (78.28)
#
# Epoch 49/50:
# Iteration 0, loss = 0.4273
# cuda
# Got 7011 / 9000 correct (77.90)
#
# Iteration 100, loss = 0.3611
# cuda
# Got 7048 / 9000 correct (78.31)
#
# Iteration 200, loss = 0.3940
# cuda
# Got 7056 / 9000 correct (78.40)
#
# Iteration 300, loss = 0.4649
# cuda
# Got 7013 / 9000 correct (77.92)
#
# Iteration 400, loss = 0.4245
# cuda
# Got 7040 / 9000 correct (78.22)
#
# Iteration 500, loss = 0.4611
# cuda
# Got 7058 / 9000 correct (78.42)
#
# Iteration 600, loss = 0.3877
# cuda
# Got 7035 / 9000 correct (78.17)
#
# Iteration 700, loss = 0.3946
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 800, loss = 0.5252
# cuda
# Got 7051 / 9000 correct (78.34)
#
# cuda
# Got 7062 / 9000 correct (78.47)
# cuda
# Got 42161 / 54000 correct (78.08)
#
# Epoch 50/50:
# Iteration 0, loss = 0.2959
# cuda
# Got 7050 / 9000 correct (78.33)
#
# Iteration 100, loss = 0.4645
# cuda
# Got 7022 / 9000 correct (78.02)
#
# Iteration 200, loss = 0.4389
# cuda
# Got 7032 / 9000 correct (78.13)
#
# Iteration 300, loss = 0.3676
# cuda
# Got 7046 / 9000 correct (78.29)
#
# Iteration 400, loss = 0.3829
# cuda
# Got 7042 / 9000 correct (78.24)
#
# Iteration 500, loss = 0.4849
# cuda
# Got 7044 / 9000 correct (78.27)
#
# Iteration 600, loss = 0.4393
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 700, loss = 0.4003
# cuda
# Got 7034 / 9000 correct (78.16)
#
# Iteration 800, loss = 0.3075
# cuda
# Got 7039 / 9000 correct (78.21)
#
# cuda
# Got 7044 / 9000 correct (78.27)
# Epoch    49: reducing learning rate of group 0 to 4.0000e-09.
# cuda
# Got 42292 / 54000 correct (78.32)

# %%
trainingMetrics(hist)

# %%
torch.save(advModel.state_dict(), "../models/advTraining_2.pth.tar")
