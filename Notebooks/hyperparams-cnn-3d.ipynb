# %% [markdown]
# # Hyperparameter search for the 3d cnn
#
# In our class presentation 5/31/18, Justin told us that based on the accuracy training curve that we showed, it looks like we're *underfitting*, so he suggested that we use *less* data for this project.
#
# Honestly, this is probably something that we should have tried before, because they told us in lecture that an important step in making sure you're in a good hyperparameter space is being able to **overfit** the training data.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Loading the other modules I have in parent directories
import sys
PYTHONPATH="../"
sys.path.append(PYTHONPATH)
from dataProcessing import getDataLoaders
from models import FCNet, CNN_3d, layer0_12x12, layer2_12x12, layer0_3x6, count_parameters
from train import check_accuracy, train
from plottingFcts import trainingMetrics, sigBkgEff, plotROC, plotConfusion

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
loader_train, loader_val, loader_test = getDataLoaders(batch_size=256, N=1000)

# %%
#optimizer = optim.Adam(myModel.parameters(), lr = 1e-3)

myModel = CNN_3d()
optimizer = optim.SGD(myModel.parameters(), lr=1e-9, momentum=0.9, nesterov=True)
# Out:
# Output size after the first conv: 16,2.0,6.0,6.0
# Output size after the second conv: 8,1.0,4.0,4.0

# %%
history, myModel = train(loader_train, loader_val, myModel, 
                         optimizer, epochs=100, returnBest=True)
# Out:
# Epoch 1/100:
# Iteration 0, loss = 1.0438
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 2/100:
# Iteration 0, loss = 1.0838
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 3/100:
# Iteration 0, loss = 1.0824
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 4/100:
# Iteration 0, loss = 0.9288
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 5/100:
# Iteration 0, loss = 1.1211
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 6/100:
# Iteration 0, loss = 0.8687
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 7/100:
# Iteration 0, loss = 1.2415
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 8/100:
# Iteration 0, loss = 1.3375
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 9/100:
# Iteration 0, loss = 1.3289
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 10/100:
# Iteration 0, loss = 1.0809
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 11/100:
# Iteration 0, loss = 1.1964
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 12/100:
# Iteration 0, loss = 1.0213
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 13/100:
# Iteration 0, loss = 1.0950
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 14/100:
# Iteration 0, loss = 1.1810
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 15/100:
# Iteration 0, loss = 1.0869
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 16/100:
# Iteration 0, loss = 0.9995
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 3 / 18 correct (16.67)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 17/100:
# Iteration 0, loss = 1.0554
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 18/100:
# Iteration 0, loss = 1.0765
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 19/100:
# Iteration 0, loss = 0.8943
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 20/100:
# Iteration 0, loss = 0.8613
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 21/100:
# Iteration 0, loss = 1.0890
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 22/100:
# Iteration 0, loss = 1.0803
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 2 / 18 correct (11.11)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 23/100:
# Iteration 0, loss = 1.2215
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 24/100:
# Iteration 0, loss = 0.9280
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 25/100:
# Iteration 0, loss = 0.9621
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 26/100:
# Iteration 0, loss = 1.1414
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 27/100:
# Iteration 0, loss = 1.0697
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 28/100:
# Iteration 0, loss = 0.9205
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 29/100:
# Iteration 0, loss = 1.3190
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 30/100:
# Iteration 0, loss = 1.0881
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 31/100:
# Iteration 0, loss = 1.0861
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 32/100:
# Iteration 0, loss = 1.3120
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 33/100:
# Iteration 0, loss = 1.0618
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 34/100:
# Iteration 0, loss = 1.1877
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 35/100:
# Iteration 0, loss = 0.9276
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 36/100:
# Iteration 0, loss = 1.3179
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 37/100:
# Iteration 0, loss = 1.1369
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 38/100:
# Iteration 0, loss = 1.1123
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 39/100:
# Iteration 0, loss = 1.2303
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 40/100:
# Iteration 0, loss = 0.8740
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 41/100:
# Iteration 0, loss = 1.4583
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 42/100:
# Iteration 0, loss = 1.2155
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 43/100:
# Iteration 0, loss = 0.9559
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 44/100:
# Iteration 0, loss = 1.0766
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 45/100:
# Iteration 0, loss = 1.2969
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 46/100:
# Iteration 0, loss = 1.1915
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 47/100:
# Iteration 0, loss = 0.8628
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 48/100:
# Iteration 0, loss = 0.9615
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 49/100:
# Iteration 0, loss = 1.0442
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 50/100:
# Iteration 0, loss = 1.1349
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 51/100:
# Iteration 0, loss = 1.0406
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 2 / 18 correct (11.11)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 52/100:
# Iteration 0, loss = 1.0107
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 53/100:
# Iteration 0, loss = 1.0718
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 54/100:
# Iteration 0, loss = 1.0435
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 55/100:
# Iteration 0, loss = 1.0789
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 56/100:
# Iteration 0, loss = 1.3039
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 57/100:
# Iteration 0, loss = 1.1415
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 3 / 18 correct (16.67)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 58/100:
# Iteration 0, loss = 1.1398
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 59/100:
# Iteration 0, loss = 1.3046
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 60/100:
# Iteration 0, loss = 1.3191
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 61/100:
# Iteration 0, loss = 1.1119
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 62/100:
# Iteration 0, loss = 1.2103
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 63/100:
# Iteration 0, loss = 1.3087
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 64/100:
# Iteration 0, loss = 1.0099
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 65/100:
# Iteration 0, loss = 0.9503
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 3 / 18 correct (16.67)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 66/100:
# Iteration 0, loss = 1.3185
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 67/100:
# Iteration 0, loss = 1.1068
# cpu
# Got 2 / 3 correct (66.67)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 68/100:
# Iteration 0, loss = 1.1766
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 69/100:
# Iteration 0, loss = 1.3735
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 70/100:
# Iteration 0, loss = 1.3079
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 2 / 18 correct (11.11)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 71/100:
# Iteration 0, loss = 0.9660
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 72/100:
# Iteration 0, loss = 1.1907
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 73/100:
# Iteration 0, loss = 1.1777
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 74/100:
# Iteration 0, loss = 0.9333
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 75/100:
# Iteration 0, loss = 1.1342
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 76/100:
# Iteration 0, loss = 1.0897
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 77/100:
# Iteration 0, loss = 1.1456
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 78/100:
# Iteration 0, loss = 0.9121
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 4 / 18 correct (22.22)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 79/100:
# Iteration 0, loss = 1.1147
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 80/100:
# Iteration 0, loss = 1.0797
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 10 / 18 correct (55.56)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 81/100:
# Iteration 0, loss = 1.0040
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 82/100:
# Iteration 0, loss = 1.0815
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 3 / 18 correct (16.67)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 83/100:
# Iteration 0, loss = 1.1025
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 84/100:
# Iteration 0, loss = 1.0071
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 85/100:
# Iteration 0, loss = 1.2513
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 86/100:
# Iteration 0, loss = 0.9933
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 87/100:
# Iteration 0, loss = 0.9598
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 88/100:
# Iteration 0, loss = 1.0841
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 89/100:
# Iteration 0, loss = 1.0649
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 2 / 3 correct (66.67)
#
# Epoch 90/100:
# Iteration 0, loss = 0.9540
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 12 / 18 correct (66.67)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 91/100:
# Iteration 0, loss = 1.1561
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 0 / 3 correct (0.00)
#
# Epoch 92/100:
# Iteration 0, loss = 0.9699
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 7 / 18 correct (38.89)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 93/100:
# Iteration 0, loss = 1.2551
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 94/100:
# Iteration 0, loss = 1.1769
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 8 / 18 correct (44.44)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 95/100:
# Iteration 0, loss = 1.0886
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 96/100:
# Iteration 0, loss = 1.1024
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 5 / 18 correct (27.78)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 97/100:
# Iteration 0, loss = 0.7971
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 98/100:
# Iteration 0, loss = 1.0237
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 9 / 18 correct (50.00)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 99/100:
# Iteration 0, loss = 1.3160
# cpu
# Got 0 / 3 correct (0.00)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 1 / 3 correct (33.33)
#
# Epoch 100/100:
# Iteration 0, loss = 1.0613
# cpu
# Got 1 / 3 correct (33.33)
#
# cpu
# Got 6 / 18 correct (33.33)
# cpu
# Got 0 / 3 correct (0.00)

# %%
trainingMetrics(history)

# %%
?

# %%
fc = myModel = FCNet()

#optim_fc = optim.Adam(myModel.parameters(), lr = 5e-6)
optim_fc = optim.SGD(myModel.parameters(), lr = 5e-5, momentum=.9,nesterov=True)
history, fc = train(loader_train, loader_val, fc, 
                         optim_fc, epochs=1000, returnBest=True)
# Out:
# Epoch 1/1000:
# Iteration 0, loss = 1.1130
# cpu
# Got 107 / 300 correct (35.67)
#
# cpu
# Got 670 / 1800 correct (37.22)
# cpu
# Got 95 / 300 correct (31.67)
#
# Epoch 2/1000:
# Iteration 0, loss = 1.0929
# cpu
# Got 116 / 300 correct (38.67)
#
# cpu
# Got 646 / 1800 correct (35.89)
# cpu
# Got 112 / 300 correct (37.33)
#
# Epoch 3/1000:
# Iteration 0, loss = 1.0739
# cpu
# Got 108 / 300 correct (36.00)
#
# cpu
# Got 667 / 1800 correct (37.06)
# cpu
# Got 112 / 300 correct (37.33)
#
# Epoch 4/1000:
# Iteration 0, loss = 1.0775
# cpu
# Got 114 / 300 correct (38.00)
#
# cpu
# Got 704 / 1800 correct (39.11)
# cpu
# Got 122 / 300 correct (40.67)
#
# Epoch 5/1000:
# Iteration 0, loss = 1.0851
# cpu
# Got 115 / 300 correct (38.33)
#
# cpu
# Got 720 / 1800 correct (40.00)
# cpu
# Got 107 / 300 correct (35.67)
#
# Epoch 6/1000:
# Iteration 0, loss = 1.0765
# cpu
# Got 110 / 300 correct (36.67)
#
# cpu
# Got 714 / 1800 correct (39.67)
# cpu
# Got 113 / 300 correct (37.67)
#
# Epoch 7/1000:
# Iteration 0, loss = 1.0797
# cpu
# Got 113 / 300 correct (37.67)
#
# cpu
# Got 679 / 1800 correct (37.72)
# cpu
# Got 112 / 300 correct (37.33)
#
# Epoch 8/1000:
# Iteration 0, loss = 1.0706
# cpu
# Got 104 / 300 correct (34.67)
#
# cpu
# Got 703 / 1800 correct (39.06)
# cpu
# Got 121 / 300 correct (40.33)
#
# Epoch 9/1000:
# Iteration 0, loss = 1.0576
# cpu
# Got 121 / 300 correct (40.33)
#
# cpu
# Got 733 / 1800 correct (40.72)
# cpu
# Got 126 / 300 correct (42.00)
#
# Epoch 10/1000:
# Iteration 0, loss = 1.0905
# cpu
# Got 123 / 300 correct (41.00)
#
# cpu
# Got 743 / 1800 correct (41.28)
# cpu
# Got 133 / 300 correct (44.33)
#
# Epoch 11/1000:
# Iteration 0, loss = 1.0673
# cpu
# Got 112 / 300 correct (37.33)
#
# cpu
# Got 746 / 1800 correct (41.44)
# cpu
# Got 128 / 300 correct (42.67)
#
# Epoch 12/1000:
# Iteration 0, loss = 1.0668
# cpu
# Got 120 / 300 correct (40.00)
#
# cpu
# Got 768 / 1800 correct (42.67)
# cpu
# Got 123 / 300 correct (41.00)
#
# Epoch 13/1000:
# Iteration 0, loss = 1.0710
# cpu
# Got 122 / 300 correct (40.67)
#
# cpu
# Got 795 / 1800 correct (44.17)
# cpu
# Got 131 / 300 correct (43.67)
#
# Epoch 14/1000:
# Iteration 0, loss = 1.0737
# cpu
# Got 127 / 300 correct (42.33)
#
# cpu
# Got 763 / 1800 correct (42.39)
# cpu
# Got 123 / 300 correct (41.00)
#
# Epoch 15/1000:
# Iteration 0, loss = 1.0714
# cpu
# Got 123 / 300 correct (41.00)
#
# cpu
# Got 790 / 1800 correct (43.89)
# cpu
# Got 124 / 300 correct (41.33)
#
# Epoch 16/1000:
# Iteration 0, loss = 1.0719
# cpu
# Got 123 / 300 correct (41.00)
#
# cpu
# Got 767 / 1800 correct (42.61)
# cpu
# Got 130 / 300 correct (43.33)
#
# Epoch 17/1000:
# Iteration 0, loss = 1.0752
# cpu
# Got 111 / 300 correct (37.00)
#
# cpu
# Got 809 / 1800 correct (44.94)
# cpu
# Got 133 / 300 correct (44.33)
#
# Epoch 18/1000:
# Iteration 0, loss = 1.0626
# cpu
# Got 117 / 300 correct (39.00)
#
# cpu
# Got 783 / 1800 correct (43.50)
# cpu
# Got 130 / 300 correct (43.33)
#
# Epoch 19/1000:
# Iteration 0, loss = 1.0555
# cpu
# Got 128 / 300 correct (42.67)
#
# cpu
# Got 824 / 1800 correct (45.78)
# cpu
# Got 136 / 300 correct (45.33)
#
# Epoch 20/1000:
# Iteration 0, loss = 1.0724
# cpu
# Got 140 / 300 correct (46.67)
#
# cpu
# Got 766 / 1800 correct (42.56)
# cpu
# Got 133 / 300 correct (44.33)
#
# Epoch 21/1000:
# Iteration 0, loss = 1.0497
# cpu
# Got 127 / 300 correct (42.33)
#
# cpu
# Got 791 / 1800 correct (43.94)
# cpu
# Got 133 / 300 correct (44.33)
#
# Epoch 22/1000:
# Iteration 0, loss = 1.0541
# cpu
# Got 120 / 300 correct (40.00)
#
# cpu
# Got 804 / 1800 correct (44.67)
# cpu
# Got 134 / 300 correct (44.67)
#
# Epoch 23/1000:
# Iteration 0, loss = 1.0464
# cpu
# Got 138 / 300 correct (46.00)
#
# cpu
# Got 814 / 1800 correct (45.22)
# cpu
# Got 129 / 300 correct (43.00)
#
# Epoch 24/1000:
# Iteration 0, loss = 1.0767
# cpu
# Got 117 / 300 correct (39.00)
#
# cpu
# Got 841 / 1800 correct (46.72)
# cpu
# Got 138 / 300 correct (46.00)
#
# Epoch 25/1000:
# Iteration 0, loss = 1.0552
# cpu
# Got 134 / 300 correct (44.67)
#
# cpu
# Got 821 / 1800 correct (45.61)
# cpu
# Got 128 / 300 correct (42.67)
#
# Epoch 26/1000:
# Iteration 0, loss = 1.0515
# cpu
# Got 132 / 300 correct (44.00)
#
# cpu
# Got 805 / 1800 correct (44.72)
# cpu
# Got 147 / 300 correct (49.00)
#
# Epoch 27/1000:
# Iteration 0, loss = 1.0513
# cpu
# Got 131 / 300 correct (43.67)
#
# cpu
# Got 839 / 1800 correct (46.61)
# cpu
# Got 137 / 300 correct (45.67)
#
# Epoch 28/1000:
# Iteration 0, loss = 1.0570
# cpu
# Got 149 / 300 correct (49.67)
#
# cpu
# Got 877 / 1800 correct (48.72)
# cpu
# Got 129 / 300 correct (43.00)
#
# Epoch 29/1000:
# Iteration 0, loss = 1.0377
# cpu
# Got 129 / 300 correct (43.00)
#
# cpu
# Got 836 / 1800 correct (46.44)
# cpu
# Got 138 / 300 correct (46.00)
#
# Epoch 30/1000:
# Iteration 0, loss = 1.0581
# cpu
# Got 128 / 300 correct (42.67)
#
# cpu
# Got 859 / 1800 correct (47.72)
# cpu
# Got 134 / 300 correct (44.67)
#
# Epoch 31/1000:
# Iteration 0, loss = 1.0511
# cpu
# Got 136 / 300 correct (45.33)
#
# cpu
# Got 817 / 1800 correct (45.39)
# cpu
# Got 131 / 300 correct (43.67)
#
# Epoch 32/1000:
# Iteration 0, loss = 1.0419
# cpu
# Got 156 / 300 correct (52.00)
#
# cpu
# Got 861 / 1800 correct (47.83)
# cpu
# Got 133 / 300 correct (44.33)
#
# Epoch 33/1000:
# Iteration 0, loss = 1.0522
# cpu
# Got 137 / 300 correct (45.67)
#
# cpu
# Got 854 / 1800 correct (47.44)
# cpu
# Got 128 / 300 correct (42.67)
#
# Epoch 34/1000:
# Iteration 0, loss = 1.0278
# cpu
# Got 134 / 300 correct (44.67)
#
# cpu
# Got 858 / 1800 correct (47.67)
# cpu
# Got 147 / 300 correct (49.00)
#
# Epoch 35/1000:
# Iteration 0, loss = 1.0600
# cpu
# Got 134 / 300 correct (44.67)
#
# cpu
# Got 846 / 1800 correct (47.00)
# cpu
# Got 137 / 300 correct (45.67)
#
# Epoch 36/1000:
# Iteration 0, loss = 1.0520
# cpu
# Got 137 / 300 correct (45.67)
#
# cpu
# Got 870 / 1800 correct (48.33)
# cpu
# Got 143 / 300 correct (47.67)
#
# Epoch 37/1000:
# Iteration 0, loss = 1.0674
# cpu
# Got 138 / 300 correct (46.00)
#
# cpu
# Got 835 / 1800 correct (46.39)
# cpu
# Got 134 / 300 correct (44.67)
#
# Epoch 38/1000:
# Iteration 0, loss = 1.0408
# cpu
# Got 137 / 300 correct (45.67)
#
# cpu
# Got 862 / 1800 correct (47.89)
# cpu
# Got 139 / 300 correct (46.33)
#
# Epoch 39/1000:
# Iteration 0, loss = 1.0319
# cpu
# Got 156 / 300 correct (52.00)
#
# cpu
# Got 857 / 1800 correct (47.61)
# cpu
# Got 140 / 300 correct (46.67)
#
# Epoch 40/1000:
# Iteration 0, loss = 1.0386
# cpu
# Got 155 / 300 correct (51.67)
#
# cpu
# Got 872 / 1800 correct (48.44)
# cpu
# Got 149 / 300 correct (49.67)
#
# Epoch 41/1000:
# Iteration 0, loss = 1.0390
# cpu
# Got 140 / 300 correct (46.67)
#
# cpu
# Got 847 / 1800 correct (47.06)
# cpu
# Got 142 / 300 correct (47.33)
#
# Epoch 42/1000:
# Iteration 0, loss = 1.0302
# cpu
# Got 143 / 300 correct (47.67)
#
# cpu
# Got 883 / 1800 correct (49.06)
# cpu
# Got 143 / 300 correct (47.67)
#
# Epoch 43/1000:
# Iteration 0, loss = 1.0244
# cpu
# Got 132 / 300 correct (44.00)
#
# cpu
# Got 852 / 1800 correct (47.33)
# cpu
# Got 132 / 300 correct (44.00)
#
# Epoch 44/1000:
# Iteration 0, loss = 1.0362
# cpu
# Got 135 / 300 correct (45.00)
#
# cpu
# Got 854 / 1800 correct (47.44)
# cpu
# Got 138 / 300 correct (46.00)
#
# Epoch 45/1000:
# Iteration 0, loss = 1.0858
# cpu
# Got 140 / 300 correct (46.67)
#
# cpu
# Got 879 / 1800 correct (48.83)
# cpu
# Got 135 / 300 correct (45.00)
#
# Epoch 46/1000:
# Iteration 0, loss = 1.0321
# cpu
# Got 141 / 300 correct (47.00)
#
# cpu
# Got 868 / 1800 correct (48.22)
# cpu
# Got 144 / 300 correct (48.00)
#
# Epoch 47/1000:
# Iteration 0, loss = 1.0415
# cpu
# Got 138 / 300 correct (46.00)
#
# cpu
# Got 847 / 1800 correct (47.06)
# cpu
# Got 140 / 300 correct (46.67)
#
# Epoch 48/1000:
# Iteration 0, loss = 1.0272
# cpu
# Got 149 / 300 correct (49.67)
#
# cpu
# Got 886 / 1800 correct (49.22)
# cpu
# Got 145 / 300 correct (48.33)
#
# Epoch 49/1000:
# Iteration 0, loss = 1.0412
# cpu
# Got 140 / 300 correct (46.67)
#
# cpu
# Got 881 / 1800 correct (48.94)
# cpu
# Got 162 / 300 correct (54.00)
#
# Epoch 50/1000:
# Iteration 0, loss = 1.0521
# cpu
# Got 147 / 300 correct (49.00)
#
# cpu
# Got 866 / 1800 correct (48.11)
# cpu
# Got 135 / 300 correct (45.00)
#
# Epoch 51/1000:
# Iteration 0, loss = 1.0469
# cpu
# Got 146 / 300 correct (48.67)
#
# cpu
# Got 871 / 1800 correct (48.39)
# cpu
# Got 144 / 300 correct (48.00)
#
# Epoch 52/1000:
# Iteration 0, loss = 1.0472
# cpu
# Got 141 / 300 correct (47.00)
#
# cpu
# Got 887 / 1800 correct (49.28)
# cpu
# Got 134 / 300 correct (44.67)
#
# Epoch 53/1000:
# Iteration 0, loss = 1.0432
# cpu
# Got 143 / 300 correct (47.67)
#
# cpu
# Got 918 / 1800 correct (51.00)
# cpu
# Got 146 / 300 correct (48.67)
#
# Epoch 54/1000:
# Iteration 0, loss = 1.0532
# cpu
# Got 148 / 300 correct (49.33)
#
# cpu
# Got 912 / 1800 correct (50.67)
# cpu
# Got 153 / 300 correct (51.00)
#
# Epoch 55/1000:
# Iteration 0, loss = 1.0302
# cpu
# Got 144 / 300 correct (48.00)
#
# cpu
# Got 870 / 1800 correct (48.33)
# cpu
# Got 168 / 300 correct (56.00)
#
# Epoch 56/1000:
# Iteration 0, loss = 1.0375
# cpu
# Got 140 / 300 correct (46.67)
#
# cpu
# Got 913 / 1800 correct (50.72)
# cpu
# Got 146 / 300 correct (48.67)
#
# Epoch 57/1000:
# Iteration 0, loss = 1.0321
# cpu
# Got 145 / 300 correct (48.33)
#
# cpu
# Got 941 / 1800 correct (52.28)
# cpu
# Got 138 / 300 correct (46.00)
#
# Epoch 58/1000:
# Iteration 0, loss = 1.0280
# cpu
# Got 144 / 300 correct (48.00)
#
# cpu
# Got 889 / 1800 correct (49.39)
# cpu
# Got 147 / 300 correct (49.00)
#
# Epoch 59/1000:
# Iteration 0, loss = 1.0187
# cpu
# Got 145 / 300 correct (48.33)
#
# cpu
# Got 912 / 1800 correct (50.67)
# cpu
# Got 159 / 300 correct (53.00)
#
# Epoch 60/1000:
# Iteration 0, loss = 1.0280
# cpu
# Got 151 / 300 correct (50.33)
#
# cpu
# Got 944 / 1800 correct (52.44)
# cpu
# Got 148 / 300 correct (49.33)
#
# Epoch 61/1000:
# Iteration 0, loss = 1.0315
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 929 / 1800 correct (51.61)
# cpu
# Got 146 / 300 correct (48.67)
#
# Epoch 62/1000:
# Iteration 0, loss = 1.0211
# cpu
# Got 149 / 300 correct (49.67)
#
# cpu
# Got 904 / 1800 correct (50.22)
# cpu
# Got 149 / 300 correct (49.67)
#
# Epoch 63/1000:
# Iteration 0, loss = 1.0333
# cpu
# Got 154 / 300 correct (51.33)
#
# cpu
# Got 923 / 1800 correct (51.28)
# cpu
# Got 156 / 300 correct (52.00)
#
# Epoch 64/1000:
# Iteration 0, loss = 1.0233
# cpu
# Got 154 / 300 correct (51.33)
#
# cpu
# Got 907 / 1800 correct (50.39)
# cpu
# Got 152 / 300 correct (50.67)
#
# Epoch 65/1000:
# Iteration 0, loss = 1.0543
# cpu
# Got 153 / 300 correct (51.00)
#
# cpu
# Got 936 / 1800 correct (52.00)
# cpu
# Got 153 / 300 correct (51.00)
#
# Epoch 66/1000:
# Iteration 0, loss = 1.0202
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 916 / 1800 correct (50.89)
# cpu
# Got 152 / 300 correct (50.67)
#
# Epoch 67/1000:
# Iteration 0, loss = 1.0302
# cpu
# Got 162 / 300 correct (54.00)
#
# cpu
# Got 937 / 1800 correct (52.06)
# cpu
# Got 154 / 300 correct (51.33)
#
# Epoch 68/1000:
# Iteration 0, loss = 1.0095
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 953 / 1800 correct (52.94)
# cpu
# Got 148 / 300 correct (49.33)
#
# Epoch 69/1000:
# Iteration 0, loss = 1.0156
# cpu
# Got 156 / 300 correct (52.00)
#
# cpu
# Got 947 / 1800 correct (52.61)
# cpu
# Got 155 / 300 correct (51.67)
#
# Epoch 70/1000:
# Iteration 0, loss = 1.0187
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 951 / 1800 correct (52.83)
# cpu
# Got 157 / 300 correct (52.33)
#
# Epoch 71/1000:
# Iteration 0, loss = 1.0195
# cpu
# Got 150 / 300 correct (50.00)
#
# cpu
# Got 930 / 1800 correct (51.67)
# cpu
# Got 153 / 300 correct (51.00)
#
# Epoch 72/1000:
# Iteration 0, loss = 1.0227
# cpu
# Got 156 / 300 correct (52.00)
#
# cpu
# Got 950 / 1800 correct (52.78)
# cpu
# Got 159 / 300 correct (53.00)
#
# Epoch 73/1000:
# Iteration 0, loss = 1.0325
# cpu
# Got 153 / 300 correct (51.00)
#
# cpu
# Got 948 / 1800 correct (52.67)
# cpu
# Got 143 / 300 correct (47.67)
#
# Epoch 74/1000:
# Iteration 0, loss = 1.0348
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 968 / 1800 correct (53.78)
# cpu
# Got 157 / 300 correct (52.33)
#
# Epoch 75/1000:
# Iteration 0, loss = 1.0041
# cpu
# Got 151 / 300 correct (50.33)
#
# cpu
# Got 921 / 1800 correct (51.17)
# cpu
# Got 150 / 300 correct (50.00)
#
# Epoch 76/1000:
# Iteration 0, loss = 1.0326
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 940 / 1800 correct (52.22)
# cpu
# Got 169 / 300 correct (56.33)
#
# Epoch 77/1000:
# Iteration 0, loss = 1.0086
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 941 / 1800 correct (52.28)
# cpu
# Got 151 / 300 correct (50.33)
#
# Epoch 78/1000:
# Iteration 0, loss = 1.0055
# cpu
# Got 156 / 300 correct (52.00)
#
# cpu
# Got 925 / 1800 correct (51.39)
# cpu
# Got 153 / 300 correct (51.00)
#
# Epoch 79/1000:
# Iteration 0, loss = 0.9963
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 950 / 1800 correct (52.78)
# cpu
# Got 155 / 300 correct (51.67)
#
# Epoch 80/1000:
# Iteration 0, loss = 1.0132
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 942 / 1800 correct (52.33)
# cpu
# Got 154 / 300 correct (51.33)
#
# Epoch 81/1000:
# Iteration 0, loss = 1.0269
# cpu
# Got 152 / 300 correct (50.67)
#
# cpu
# Got 950 / 1800 correct (52.78)
# cpu
# Got 172 / 300 correct (57.33)
#
# Epoch 82/1000:
# Iteration 0, loss = 1.0049
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 985 / 1800 correct (54.72)
# cpu
# Got 156 / 300 correct (52.00)
#
# Epoch 83/1000:
# Iteration 0, loss = 1.0336
# cpu
# Got 158 / 300 correct (52.67)
#
# cpu
# Got 943 / 1800 correct (52.39)
# cpu
# Got 159 / 300 correct (53.00)
#
# Epoch 84/1000:
# Iteration 0, loss = 1.0256
# cpu
# Got 161 / 300 correct (53.67)
#
# cpu
# Got 963 / 1800 correct (53.50)
# cpu
# Got 162 / 300 correct (54.00)
#
# Epoch 85/1000:
# Iteration 0, loss = 1.0004
# cpu
# Got 166 / 300 correct (55.33)
#
# cpu
# Got 949 / 1800 correct (52.72)
# cpu
# Got 161 / 300 correct (53.67)
#
# Epoch 86/1000:
# Iteration 0, loss = 0.9963
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 960 / 1800 correct (53.33)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 87/1000:
# Iteration 0, loss = 1.0164
# cpu
# Got 160 / 300 correct (53.33)
#
# cpu
# Got 963 / 1800 correct (53.50)
# cpu
# Got 170 / 300 correct (56.67)
#
# Epoch 88/1000:
# Iteration 0, loss = 1.0132
# cpu
# Got 163 / 300 correct (54.33)
#
# cpu
# Got 995 / 1800 correct (55.28)
# cpu
# Got 155 / 300 correct (51.67)
#
# Epoch 89/1000:
# Iteration 0, loss = 1.0000
# cpu
# Got 162 / 300 correct (54.00)
#
# cpu
# Got 978 / 1800 correct (54.33)
# cpu
# Got 162 / 300 correct (54.00)
#
# Epoch 90/1000:
# Iteration 0, loss = 1.0123
# cpu
# Got 155 / 300 correct (51.67)
#
# cpu
# Got 977 / 1800 correct (54.28)
# cpu
# Got 163 / 300 correct (54.33)
#
# Epoch 91/1000:
# Iteration 0, loss = 0.9866
# cpu
# Got 153 / 300 correct (51.00)
#
# cpu
# Got 963 / 1800 correct (53.50)
# cpu
# Got 161 / 300 correct (53.67)
#
# Epoch 92/1000:
# Iteration 0, loss = 1.0291
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 934 / 1800 correct (51.89)
# cpu
# Got 155 / 300 correct (51.67)
#
# Epoch 93/1000:
# Iteration 0, loss = 0.9868
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 993 / 1800 correct (55.17)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 94/1000:
# Iteration 0, loss = 1.0166
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 962 / 1800 correct (53.44)
# cpu
# Got 159 / 300 correct (53.00)
#
# Epoch 95/1000:
# Iteration 0, loss = 1.0080
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 986 / 1800 correct (54.78)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 96/1000:
# Iteration 0, loss = 1.0277
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 957 / 1800 correct (53.17)
# cpu
# Got 156 / 300 correct (52.00)
#
# Epoch 97/1000:
# Iteration 0, loss = 1.0170
# cpu
# Got 157 / 300 correct (52.33)
#
# cpu
# Got 988 / 1800 correct (54.89)
# cpu
# Got 169 / 300 correct (56.33)
#
# Epoch 98/1000:
# Iteration 0, loss = 1.0097
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 996 / 1800 correct (55.33)
# cpu
# Got 148 / 300 correct (49.33)
#
# Epoch 99/1000:
# Iteration 0, loss = 1.0165
# cpu
# Got 155 / 300 correct (51.67)
#
# cpu
# Got 950 / 1800 correct (52.78)
# cpu
# Got 154 / 300 correct (51.33)
#
# Epoch 100/1000:
# Iteration 0, loss = 1.0010
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 977 / 1800 correct (54.28)
# cpu
# Got 160 / 300 correct (53.33)
#
# Epoch 101/1000:
# Iteration 0, loss = 0.9974
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 946 / 1800 correct (52.56)
# cpu
# Got 159 / 300 correct (53.00)
#
# Epoch 102/1000:
# Iteration 0, loss = 0.9839
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1007 / 1800 correct (55.94)
# cpu
# Got 161 / 300 correct (53.67)
#
# Epoch 103/1000:
# Iteration 0, loss = 0.9908
# cpu
# Got 163 / 300 correct (54.33)
#
# cpu
# Got 983 / 1800 correct (54.61)
# cpu
# Got 162 / 300 correct (54.00)
#
# Epoch 104/1000:
# Iteration 0, loss = 1.0064
# cpu
# Got 155 / 300 correct (51.67)
#
# cpu
# Got 960 / 1800 correct (53.33)
# cpu
# Got 155 / 300 correct (51.67)
#
# Epoch 105/1000:
# Iteration 0, loss = 0.9843
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 976 / 1800 correct (54.22)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 106/1000:
# Iteration 0, loss = 1.0071
# cpu
# Got 160 / 300 correct (53.33)
#
# cpu
# Got 958 / 1800 correct (53.22)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 107/1000:
# Iteration 0, loss = 1.0054
# cpu
# Got 160 / 300 correct (53.33)
#
# cpu
# Got 973 / 1800 correct (54.06)
# cpu
# Got 170 / 300 correct (56.67)
#
# Epoch 108/1000:
# Iteration 0, loss = 1.0249
# cpu
# Got 157 / 300 correct (52.33)
#
# cpu
# Got 984 / 1800 correct (54.67)
# cpu
# Got 165 / 300 correct (55.00)
#
# Epoch 109/1000:
# Iteration 0, loss = 0.9813
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 961 / 1800 correct (53.39)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 110/1000:
# Iteration 0, loss = 1.0031
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 967 / 1800 correct (53.72)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 111/1000:
# Iteration 0, loss = 1.0042
# cpu
# Got 156 / 300 correct (52.00)
#
# cpu
# Got 977 / 1800 correct (54.28)
# cpu
# Got 165 / 300 correct (55.00)
#
# Epoch 112/1000:
# Iteration 0, loss = 0.9926
# cpu
# Got 166 / 300 correct (55.33)
#
# cpu
# Got 1030 / 1800 correct (57.22)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 113/1000:
# Iteration 0, loss = 0.9957
# cpu
# Got 150 / 300 correct (50.00)
# cpu
# Got 1001 / 1800 correct (55.61)
# cpu
# Got 160 / 300 correct (53.33)
#
# Epoch 114/1000:
# Iteration 0, loss = 0.9938
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 993 / 1800 correct (55.17)
# cpu
# Got 165 / 300 correct (55.00)
#
# Epoch 115/1000:
# Iteration 0, loss = 0.9859
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 995 / 1800 correct (55.28)
# cpu
# Got 146 / 300 correct (48.67)
#
# Epoch 116/1000:
# Iteration 0, loss = 0.9869
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1006 / 1800 correct (55.89)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 117/1000:
# Iteration 0, loss = 0.9958
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 998 / 1800 correct (55.44)
# cpu
# Got 155 / 300 correct (51.67)
#
# Epoch 118/1000:
# Iteration 0, loss = 1.0145
# cpu
# Got 176 / 300 correct (58.67)
#
# cpu
# Got 1010 / 1800 correct (56.11)
# cpu
# Got 168 / 300 correct (56.00)
#
# Epoch 119/1000:
# Iteration 0, loss = 0.9924
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 988 / 1800 correct (54.89)
# cpu
# Got 162 / 300 correct (54.00)
#
# Epoch 120/1000:
# Iteration 0, loss = 1.0013
# cpu
# Got 161 / 300 correct (53.67)
#
# cpu
# Got 993 / 1800 correct (55.17)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 121/1000:
# Iteration 0, loss = 0.9918
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 984 / 1800 correct (54.67)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 122/1000:
# Iteration 0, loss = 0.9847
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1020 / 1800 correct (56.67)
# cpu
# Got 158 / 300 correct (52.67)
#
# Epoch 123/1000:
# Iteration 0, loss = 0.9818
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 993 / 1800 correct (55.17)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 124/1000:
# Iteration 0, loss = 1.0025
# cpu
# Got 171 / 300 correct (57.00)
#
# cpu
# Got 1002 / 1800 correct (55.67)
# cpu
# Got 168 / 300 correct (56.00)
#
# Epoch 125/1000:
# Iteration 0, loss = 1.0099
# cpu
# Got 164 / 300 correct (54.67)
#
# cpu
# Got 1010 / 1800 correct (56.11)
# cpu
# Got 166 / 300 correct (55.33)
#
# Epoch 126/1000:
# Iteration 0, loss = 0.9760
# cpu
# Got 166 / 300 correct (55.33)
#
# cpu
# Got 1004 / 1800 correct (55.78)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 127/1000:
# Iteration 0, loss = 0.9842
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 1024 / 1800 correct (56.89)
# cpu
# Got 165 / 300 correct (55.00)
#
# Epoch 128/1000:
# Iteration 0, loss = 0.9882
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1027 / 1800 correct (57.06)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 129/1000:
# Iteration 0, loss = 1.0013
# cpu
# Got 164 / 300 correct (54.67)
#
# cpu
# Got 1014 / 1800 correct (56.33)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 130/1000:
# Iteration 0, loss = 1.0004
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1020 / 1800 correct (56.67)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 131/1000:
# Iteration 0, loss = 0.9675
# cpu
# Got 166 / 300 correct (55.33)
#
# cpu
# Got 1007 / 1800 correct (55.94)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 132/1000:
# Iteration 0, loss = 1.0052
# cpu
# Got 163 / 300 correct (54.33)
#
# cpu
# Got 1024 / 1800 correct (56.89)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 133/1000:
# Iteration 0, loss = 0.9860
# cpu
# Got 164 / 300 correct (54.67)
#
# cpu
# Got 1044 / 1800 correct (58.00)
# cpu
# Got 168 / 300 correct (56.00)
#
# Epoch 134/1000:
# Iteration 0, loss = 0.9779
# cpu
# Got 157 / 300 correct (52.33)
#
# cpu
# Got 1002 / 1800 correct (55.67)
# cpu
# Got 186 / 300 correct (62.00)
#
# Epoch 135/1000:
# Iteration 0, loss = 0.9814
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1027 / 1800 correct (57.06)
# cpu
# Got 169 / 300 correct (56.33)
#
# Epoch 136/1000:
# Iteration 0, loss = 0.9788
# cpu
# Got 163 / 300 correct (54.33)
#
# cpu
# Got 1030 / 1800 correct (57.22)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 137/1000:
# Iteration 0, loss = 0.9656
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 1017 / 1800 correct (56.50)
# cpu
# Got 172 / 300 correct (57.33)
#
# Epoch 138/1000:
# Iteration 0, loss = 0.9807
# cpu
# Got 170 / 300 correct (56.67)
#
# cpu
# Got 1041 / 1800 correct (57.83)
# cpu
# Got 163 / 300 correct (54.33)
#
# Epoch 139/1000:
# Iteration 0, loss = 1.0009
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 1050 / 1800 correct (58.33)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 140/1000:
# Iteration 0, loss = 0.9874
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1025 / 1800 correct (56.94)
# cpu
# Got 180 / 300 correct (60.00)
#
# Epoch 141/1000:
# Iteration 0, loss = 0.9799
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1029 / 1800 correct (57.17)
# cpu
# Got 172 / 300 correct (57.33)
#
# Epoch 142/1000:
# Iteration 0, loss = 0.9576
# cpu
# Got 159 / 300 correct (53.00)
#
# cpu
# Got 1044 / 1800 correct (58.00)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 143/1000:
# Iteration 0, loss = 0.9785
# cpu
# Got 158 / 300 correct (52.67)
#
# cpu
# Got 1025 / 1800 correct (56.94)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 144/1000:
# Iteration 0, loss = 0.9720
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1014 / 1800 correct (56.33)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 145/1000:
# Iteration 0, loss = 0.9923
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 992 / 1800 correct (55.11)
# cpu
# Got 161 / 300 correct (53.67)
#
# Epoch 146/1000:
# Iteration 0, loss = 0.9850
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1024 / 1800 correct (56.89)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 147/1000:
# Iteration 0, loss = 0.9831
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 1071 / 1800 correct (59.50)
# cpu
# Got 165 / 300 correct (55.00)
#
# Epoch 148/1000:
# Iteration 0, loss = 0.9680
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1055 / 1800 correct (58.61)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 149/1000:
# Iteration 0, loss = 0.9683
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1044 / 1800 correct (58.00)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 150/1000:
# Iteration 0, loss = 0.9684
# cpu
# Got 157 / 300 correct (52.33)
#
# cpu
# Got 1019 / 1800 correct (56.61)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 151/1000:
# Iteration 0, loss = 0.9795
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1045 / 1800 correct (58.06)
# cpu
# Got 167 / 300 correct (55.67)
#
# Epoch 152/1000:
# Iteration 0, loss = 0.9694
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1045 / 1800 correct (58.06)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 153/1000:
# Iteration 0, loss = 0.9734
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1015 / 1800 correct (56.39)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 154/1000:
# Iteration 0, loss = 0.9613
# cpu
# Got 164 / 300 correct (54.67)
#
# cpu
# Got 1021 / 1800 correct (56.72)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 155/1000:
# Iteration 0, loss = 0.9776
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 1047 / 1800 correct (58.17)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 156/1000:
# Iteration 0, loss = 0.9903
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1026 / 1800 correct (57.00)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 157/1000:
# Iteration 0, loss = 0.9944
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1051 / 1800 correct (58.39)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 158/1000:
# Iteration 0, loss = 0.9646
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 1035 / 1800 correct (57.50)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 159/1000:
# Iteration 0, loss = 0.9801
# cpu
# Got 162 / 300 correct (54.00)
#
# cpu
# Got 1064 / 1800 correct (59.11)
# cpu
# Got 184 / 300 correct (61.33)
#
# Epoch 160/1000:
# Iteration 0, loss = 0.9554
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1046 / 1800 correct (58.11)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 161/1000:
# Iteration 0, loss = 0.9664
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 1008 / 1800 correct (56.00)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 162/1000:
# Iteration 0, loss = 0.9818
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 1041 / 1800 correct (57.83)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 163/1000:
# Iteration 0, loss = 0.9597
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1072 / 1800 correct (59.56)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 164/1000:
# Iteration 0, loss = 0.9628
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1035 / 1800 correct (57.50)
# cpu
# Got 164 / 300 correct (54.67)
#
# Epoch 165/1000:
# Iteration 0, loss = 0.9679
# cpu
# Got 168 / 300 correct (56.00)
#
# cpu
# Got 1054 / 1800 correct (58.56)
# cpu
# Got 161 / 300 correct (53.67)
#
# Epoch 166/1000:
# Iteration 0, loss = 0.9555
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1045 / 1800 correct (58.06)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 167/1000:
# Iteration 0, loss = 0.9433
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1044 / 1800 correct (58.00)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 168/1000:
# Iteration 0, loss = 0.9439
# cpu
# Got 160 / 300 correct (53.33)
#
# cpu
# Got 1052 / 1800 correct (58.44)
# cpu
# Got 166 / 300 correct (55.33)
#
# Epoch 169/1000:
# Iteration 0, loss = 0.9318
# cpu
# Got 180 / 300 correct (60.00)
# cpu
# Got 1050 / 1800 correct (58.33)
# cpu
# Got 163 / 300 correct (54.33)
#
# Epoch 170/1000:
# Iteration 0, loss = 0.9750
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 1056 / 1800 correct (58.67)
# cpu
# Got 168 / 300 correct (56.00)
#
# Epoch 171/1000:
# Iteration 0, loss = 0.9760
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1041 / 1800 correct (57.83)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 172/1000:
# Iteration 0, loss = 0.9738
# cpu
# Got 166 / 300 correct (55.33)
#
# cpu
# Got 1070 / 1800 correct (59.44)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 173/1000:
# Iteration 0, loss = 0.9412
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1054 / 1800 correct (58.56)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 174/1000:
# Iteration 0, loss = 0.9986
# cpu
# Got 188 / 300 correct (62.67)
#
# cpu
# Got 1051 / 1800 correct (58.39)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 175/1000:
# Iteration 0, loss = 0.9672
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 1072 / 1800 correct (59.56)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 176/1000:
# Iteration 0, loss = 0.9561
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1065 / 1800 correct (59.17)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 177/1000:
# Iteration 0, loss = 0.9623
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1062 / 1800 correct (59.00)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 178/1000:
# Iteration 0, loss = 0.9477
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1060 / 1800 correct (58.89)
# cpu
# Got 186 / 300 correct (62.00)
#
# Epoch 179/1000:
# Iteration 0, loss = 0.9486
# cpu
# Got 171 / 300 correct (57.00)
#
# cpu
# Got 1047 / 1800 correct (58.17)
# cpu
# Got 166 / 300 correct (55.33)
#
# Epoch 180/1000:
# Iteration 0, loss = 0.9389
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1046 / 1800 correct (58.11)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 181/1000:
# Iteration 0, loss = 0.9797
# cpu
# Got 176 / 300 correct (58.67)
#
# cpu
# Got 1079 / 1800 correct (59.94)
# cpu
# Got 165 / 300 correct (55.00)
#
# Epoch 182/1000:
# Iteration 0, loss = 0.9526
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1085 / 1800 correct (60.28)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 183/1000:
# Iteration 0, loss = 0.9511
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1077 / 1800 correct (59.83)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 184/1000:
# Iteration 0, loss = 0.9427
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1071 / 1800 correct (59.50)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 185/1000:
# Iteration 0, loss = 0.9564
# cpu
# Got 165 / 300 correct (55.00)
#
# cpu
# Got 1067 / 1800 correct (59.28)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 186/1000:
# Iteration 0, loss = 0.9558
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1070 / 1800 correct (59.44)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 187/1000:
# Iteration 0, loss = 0.9583
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 1076 / 1800 correct (59.78)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 188/1000:
# Iteration 0, loss = 0.9728
# cpu
# Got 176 / 300 correct (58.67)
#
# cpu
# Got 1075 / 1800 correct (59.72)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 189/1000:
# Iteration 0, loss = 0.9568
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1082 / 1800 correct (60.11)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 190/1000:
# Iteration 0, loss = 0.9479
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1063 / 1800 correct (59.06)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 191/1000:
# Iteration 0, loss = 0.9319
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 1050 / 1800 correct (58.33)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 192/1000:
# Iteration 0, loss = 0.9349
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1062 / 1800 correct (59.00)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 193/1000:
# Iteration 0, loss = 0.9588
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1106 / 1800 correct (61.44)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 194/1000:
# Iteration 0, loss = 0.9775
# cpu
# Got 172 / 300 correct (57.33)
#
# cpu
# Got 1078 / 1800 correct (59.89)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 195/1000:
# Iteration 0, loss = 0.9492
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1065 / 1800 correct (59.17)
# cpu
# Got 186 / 300 correct (62.00)
#
# Epoch 196/1000:
# Iteration 0, loss = 0.9375
# cpu
# Got 176 / 300 correct (58.67)
#
# cpu
# Got 1113 / 1800 correct (61.83)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 197/1000:
# Iteration 0, loss = 0.9298
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1082 / 1800 correct (60.11)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 198/1000:
# Iteration 0, loss = 0.9446
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1077 / 1800 correct (59.83)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 199/1000:
# Iteration 0, loss = 0.9360
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1075 / 1800 correct (59.72)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 200/1000:
# Iteration 0, loss = 0.9479
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1093 / 1800 correct (60.72)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 201/1000:
# Iteration 0, loss = 0.9206
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1071 / 1800 correct (59.50)
# cpu
# Got 184 / 300 correct (61.33)
#
# Epoch 202/1000:
# Iteration 0, loss = 0.9393
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 1046 / 1800 correct (58.11)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 203/1000:
# Iteration 0, loss = 0.9473
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1070 / 1800 correct (59.44)
# cpu
# Got 180 / 300 correct (60.00)
#
# Epoch 204/1000:
# Iteration 0, loss = 0.9575
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1078 / 1800 correct (59.89)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 205/1000:
# Iteration 0, loss = 0.9453
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1087 / 1800 correct (60.39)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 206/1000:
# Iteration 0, loss = 0.9407
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1081 / 1800 correct (60.06)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 207/1000:
# Iteration 0, loss = 0.9206
# cpu
# Got 190 / 300 correct (63.33)
#
# cpu
# Got 1092 / 1800 correct (60.67)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 208/1000:
# Iteration 0, loss = 0.9156
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 1079 / 1800 correct (59.94)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 209/1000:
# Iteration 0, loss = 0.9370
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1081 / 1800 correct (60.06)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 210/1000:
# Iteration 0, loss = 0.9246
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1042 / 1800 correct (57.89)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 211/1000:
# Iteration 0, loss = 0.9368
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1067 / 1800 correct (59.28)
# cpu
# Got 192 / 300 correct (64.00)
#
# Epoch 212/1000:
# Iteration 0, loss = 0.9330
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1107 / 1800 correct (61.50)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 213/1000:
# Iteration 0, loss = 0.9410
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1098 / 1800 correct (61.00)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 214/1000:
# Iteration 0, loss = 0.9393
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 1092 / 1800 correct (60.67)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 215/1000:
# Iteration 0, loss = 0.9049
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1069 / 1800 correct (59.39)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 216/1000:
# Iteration 0, loss = 0.9147
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1089 / 1800 correct (60.50)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 217/1000:
# Iteration 0, loss = 0.9473
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1114 / 1800 correct (61.89)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 218/1000:
# Iteration 0, loss = 0.9380
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1103 / 1800 correct (61.28)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 219/1000:
# Iteration 0, loss = 0.9125
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1102 / 1800 correct (61.22)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 220/1000:
# Iteration 0, loss = 0.9384
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1079 / 1800 correct (59.94)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 221/1000:
# Iteration 0, loss = 0.9365
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1102 / 1800 correct (61.22)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 222/1000:
# Iteration 0, loss = 0.9263
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1106 / 1800 correct (61.44)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 223/1000:
# Iteration 0, loss = 0.9555
# cpu
# Got 176 / 300 correct (58.67)
#
# cpu
# Got 1098 / 1800 correct (61.00)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 224/1000:
# Iteration 0, loss = 0.9288
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1116 / 1800 correct (62.00)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 225/1000:
# Iteration 0, loss = 0.9080
# cpu
# Got 164 / 300 correct (54.67)
#
# cpu
# Got 1091 / 1800 correct (60.61)
# cpu
# Got 180 / 300 correct (60.00)
#
# Epoch 226/1000:
# Iteration 0, loss = 0.9240
# cpu
# Got 171 / 300 correct (57.00)
#
# cpu
# Got 1115 / 1800 correct (61.94)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 227/1000:
# Iteration 0, loss = 0.8968
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1088 / 1800 correct (60.44)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 228/1000:
# Iteration 0, loss = 0.9568
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1082 / 1800 correct (60.11)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 229/1000:
# Iteration 0, loss = 0.9386
# cpu
# Got 174 / 300 correct (58.00)
#
# cpu
# Got 1093 / 1800 correct (60.72)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 230/1000:
# Iteration 0, loss = 0.9181
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1108 / 1800 correct (61.56)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 231/1000:
# Iteration 0, loss = 0.9245
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1089 / 1800 correct (60.50)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 232/1000:
# Iteration 0, loss = 0.9057
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1104 / 1800 correct (61.33)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 233/1000:
# Iteration 0, loss = 0.9227
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1106 / 1800 correct (61.44)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 234/1000:
# Iteration 0, loss = 0.9510
# cpu
# Got 171 / 300 correct (57.00)
#
# cpu
# Got 1109 / 1800 correct (61.61)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 235/1000:
# Iteration 0, loss = 0.9075
# cpu
# Got 192 / 300 correct (64.00)
#
# cpu
# Got 1097 / 1800 correct (60.94)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 236/1000:
# Iteration 0, loss = 0.9289
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1123 / 1800 correct (62.39)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 237/1000:
# Iteration 0, loss = 0.9252
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1101 / 1800 correct (61.17)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 238/1000:
# Iteration 0, loss = 0.9185
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1107 / 1800 correct (61.50)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 239/1000:
# Iteration 0, loss = 0.9307
# cpu
# Got 167 / 300 correct (55.67)
#
# cpu
# Got 1123 / 1800 correct (62.39)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 240/1000:
# Iteration 0, loss = 0.8998
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1108 / 1800 correct (61.56)
# cpu
# Got 171 / 300 correct (57.00)
#
# Epoch 241/1000:
# Iteration 0, loss = 0.9045
# cpu
# Got 176 / 300 correct (58.67)
#
# cpu
# Got 1088 / 1800 correct (60.44)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 242/1000:
# Iteration 0, loss = 0.9192
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1088 / 1800 correct (60.44)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 243/1000:
# Iteration 0, loss = 0.9060
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1105 / 1800 correct (61.39)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 244/1000:
# Iteration 0, loss = 0.9075
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1103 / 1800 correct (61.28)
# cpu
# Got 174 / 300 correct (58.00)
#
# Epoch 245/1000:
# Iteration 0, loss = 0.9164
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1105 / 1800 correct (61.39)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 246/1000:
# Iteration 0, loss = 0.9022
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1128 / 1800 correct (62.67)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 247/1000:
# Iteration 0, loss = 0.9281
# cpu
# Got 190 / 300 correct (63.33)
#
# cpu
# Got 1099 / 1800 correct (61.06)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 248/1000:
# Iteration 0, loss = 0.9352
# cpu
# Got 169 / 300 correct (56.33)
#
# cpu
# Got 1107 / 1800 correct (61.50)
# cpu
# Got 168 / 300 correct (56.00)
#
# Epoch 249/1000:
# Iteration 0, loss = 0.9305
# cpu
# Got 190 / 300 correct (63.33)
#
# cpu
# Got 1085 / 1800 correct (60.28)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 250/1000:
# Iteration 0, loss = 0.9280
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1116 / 1800 correct (62.00)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 251/1000:
# Iteration 0, loss = 0.9169
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1108 / 1800 correct (61.56)
# cpu
# Got 192 / 300 correct (64.00)
#
# Epoch 252/1000:
# Iteration 0, loss = 0.9040
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1122 / 1800 correct (62.33)
# cpu
# Got 195 / 300 correct (65.00)
#
# Epoch 253/1000:
# Iteration 0, loss = 0.9047
# cpu
# Got 188 / 300 correct (62.67)
#
# cpu
# Got 1107 / 1800 correct (61.50)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 254/1000:
# Iteration 0, loss = 0.9003
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1112 / 1800 correct (61.78)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 255/1000:
# Iteration 0, loss = 0.8856
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1115 / 1800 correct (61.94)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 256/1000:
# Iteration 0, loss = 0.9041
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1101 / 1800 correct (61.17)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 257/1000:
# Iteration 0, loss = 0.9190
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1087 / 1800 correct (60.39)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 258/1000:
# Iteration 0, loss = 0.9150
# cpu
# Got 175 / 300 correct (58.33)
#
# cpu
# Got 1099 / 1800 correct (61.06)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 259/1000:
# Iteration 0, loss = 0.9384
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1096 / 1800 correct (60.89)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 260/1000:
# Iteration 0, loss = 0.8877
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1118 / 1800 correct (62.11)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 261/1000:
# Iteration 0, loss = 0.9136
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1155 / 1800 correct (64.17)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 262/1000:
# Iteration 0, loss = 0.9293
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1133 / 1800 correct (62.94)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 263/1000:
# Iteration 0, loss = 0.9221
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1105 / 1800 correct (61.39)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 264/1000:
# Iteration 0, loss = 0.9003
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1107 / 1800 correct (61.50)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 265/1000:
# Iteration 0, loss = 0.9006
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1101 / 1800 correct (61.17)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 266/1000:
# Iteration 0, loss = 0.8785
# cpu
# Got 190 / 300 correct (63.33)
#
# cpu
# Got 1108 / 1800 correct (61.56)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 267/1000:
# Iteration 0, loss = 0.8913
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1084 / 1800 correct (60.22)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 268/1000:
# Iteration 0, loss = 0.9079
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1097 / 1800 correct (60.94)
# cpu
# Got 175 / 300 correct (58.33)
#
# Epoch 269/1000:
# Iteration 0, loss = 0.9111
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1103 / 1800 correct (61.28)
# cpu
# Got 186 / 300 correct (62.00)
#
# Epoch 270/1000:
# Iteration 0, loss = 0.8686
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1112 / 1800 correct (61.78)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 271/1000:
# Iteration 0, loss = 0.8935
# cpu
# Got 179 / 300 correct (59.67)
#
# cpu
# Got 1079 / 1800 correct (59.94)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 272/1000:
# Iteration 0, loss = 0.8953
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1099 / 1800 correct (61.06)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 273/1000:
# Iteration 0, loss = 0.9186
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1117 / 1800 correct (62.06)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 274/1000:
# Iteration 0, loss = 0.8921
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1114 / 1800 correct (61.89)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 275/1000:
# Iteration 0, loss = 0.9211
# cpu
# Got 178 / 300 correct (59.33)
#
# cpu
# Got 1140 / 1800 correct (63.33)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 276/1000:
# Iteration 0, loss = 0.8936
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1141 / 1800 correct (63.39)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 277/1000:
# Iteration 0, loss = 0.9123
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1135 / 1800 correct (63.06)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 278/1000:
# Iteration 0, loss = 0.9135
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1127 / 1800 correct (62.61)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 279/1000:
# Iteration 0, loss = 0.8998
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1105 / 1800 correct (61.39)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 280/1000:
# Iteration 0, loss = 0.8942
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1128 / 1800 correct (62.67)
# cpu
# Got 170 / 300 correct (56.67)
#
# Epoch 281/1000:
# Iteration 0, loss = 0.9115
# cpu
# Got 193 / 300 correct (64.33)
#
# cpu
# Got 1120 / 1800 correct (62.22)
# cpu
# Got 186 / 300 correct (62.00)
#
# Epoch 282/1000:
# Iteration 0, loss = 0.8741
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1134 / 1800 correct (63.00)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 283/1000:
# Iteration 0, loss = 0.8988
# cpu
# Got 201 / 300 correct (67.00)
#
# cpu
# Got 1134 / 1800 correct (63.00)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 284/1000:
# Iteration 0, loss = 0.8797
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1117 / 1800 correct (62.06)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 285/1000:
# Iteration 0, loss = 0.8737
# cpu
# Got 192 / 300 correct (64.00)
#
# cpu
# Got 1105 / 1800 correct (61.39)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 286/1000:
# Iteration 0, loss = 0.8793
# cpu
# Got 188 / 300 correct (62.67)
#
# cpu
# Got 1121 / 1800 correct (62.28)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 287/1000:
# Iteration 0, loss = 0.9041
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1128 / 1800 correct (62.67)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 288/1000:
# Iteration 0, loss = 0.8802
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1136 / 1800 correct (63.11)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 289/1000:
# Iteration 0, loss = 0.8989
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1108 / 1800 correct (61.56)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 290/1000:
# Iteration 0, loss = 0.8792
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1114 / 1800 correct (61.89)
# cpu
# Got 192 / 300 correct (64.00)
#
# Epoch 291/1000:
# Iteration 0, loss = 0.9060
# cpu
# Got 194 / 300 correct (64.67)
#
# cpu
# Got 1116 / 1800 correct (62.00)
# cpu
# Got 173 / 300 correct (57.67)
#
# Epoch 292/1000:
# Iteration 0, loss = 0.8856
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1113 / 1800 correct (61.83)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 293/1000:
# Iteration 0, loss = 0.8684
# cpu
# Got 173 / 300 correct (57.67)
#
# cpu
# Got 1100 / 1800 correct (61.11)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 294/1000:
# Iteration 0, loss = 0.9135
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1068 / 1800 correct (59.33)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 295/1000:
# Iteration 0, loss = 0.8730
# cpu
# Got 191 / 300 correct (63.67)
#
# cpu
# Got 1120 / 1800 correct (62.22)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 296/1000:
# Iteration 0, loss = 0.9161
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1113 / 1800 correct (61.83)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 297/1000:
# Iteration 0, loss = 0.8714
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1140 / 1800 correct (63.33)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 298/1000:
# Iteration 0, loss = 0.8746
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1114 / 1800 correct (61.89)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 299/1000:
# Iteration 0, loss = 0.9027
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1135 / 1800 correct (63.06)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 300/1000:
# Iteration 0, loss = 0.8648
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1154 / 1800 correct (64.11)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 301/1000:
# Iteration 0, loss = 0.8934
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1088 / 1800 correct (60.44)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 302/1000:
# Iteration 0, loss = 0.8795
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1118 / 1800 correct (62.11)
# cpu
# Got 178 / 300 correct (59.33)
#
# Epoch 303/1000:
# Iteration 0, loss = 0.8847
# cpu
# Got 177 / 300 correct (59.00)
#
# cpu
# Got 1137 / 1800 correct (63.17)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 304/1000:
# Iteration 0, loss = 0.8988
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1124 / 1800 correct (62.44)
# cpu
# Got 179 / 300 correct (59.67)
#
# Epoch 305/1000:
# Iteration 0, loss = 0.8787
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1138 / 1800 correct (63.22)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 306/1000:
# Iteration 0, loss = 0.8915
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1143 / 1800 correct (63.50)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 307/1000:
# Iteration 0, loss = 0.8777
# cpu
# Got 195 / 300 correct (65.00)
#
# cpu
# Got 1134 / 1800 correct (63.00)
# cpu
# Got 180 / 300 correct (60.00)
#
# Epoch 308/1000:
# Iteration 0, loss = 0.8671
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1125 / 1800 correct (62.50)
# cpu
# Got 176 / 300 correct (58.67)
#
# Epoch 309/1000:
# Iteration 0, loss = 0.8592
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1152 / 1800 correct (64.00)
# cpu
# Got 182 / 300 correct (60.67)
#
# Epoch 310/1000:
# Iteration 0, loss = 0.8897
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1122 / 1800 correct (62.33)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 311/1000:
# Iteration 0, loss = 0.8884
# cpu
# Got 180 / 300 correct (60.00)
#
# cpu
# Got 1158 / 1800 correct (64.33)
# cpu
# Got 181 / 300 correct (60.33)
#
# Epoch 312/1000:
# Iteration 0, loss = 0.8529
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1119 / 1800 correct (62.17)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 313/1000:
# Iteration 0, loss = 0.8725
# cpu
# Got 193 / 300 correct (64.33)
#
# cpu
# Got 1131 / 1800 correct (62.83)
# cpu
# Got 191 / 300 correct (63.67)
#
# Epoch 314/1000:
# Iteration 0, loss = 0.8791
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1139 / 1800 correct (63.28)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 315/1000:
# Iteration 0, loss = 0.8819
# cpu
# Got 184 / 300 correct (61.33)
#
# cpu
# Got 1122 / 1800 correct (62.33)
# cpu
# Got 195 / 300 correct (65.00)
#
# Epoch 316/1000:
# Iteration 0, loss = 0.8515
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1155 / 1800 correct (64.17)
# cpu
# Got 183 / 300 correct (61.00)
#
# Epoch 317/1000:
# Iteration 0, loss = 0.8673
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1138 / 1800 correct (63.22)
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 318/1000:
# Iteration 0, loss = 0.8644
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1170 / 1800 correct (65.00)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 319/1000:
# Iteration 0, loss = 0.8909
# cpu
# Got 183 / 300 correct (61.00)
#
# cpu
# Got 1146 / 1800 correct (63.67)
# cpu
# Got 177 / 300 correct (59.00)
#
# Epoch 320/1000:
# Iteration 0, loss = 0.8941
# cpu
# Got 187 / 300 correct (62.33)
#
# cpu
# Got 1117 / 1800 correct (62.06)
# cpu
# Got 193 / 300 correct (64.33)
#
# Epoch 321/1000:
# Iteration 0, loss = 0.8399
# cpu
# Got 182 / 300 correct (60.67)
#
# cpu
# Got 1148 / 1800 correct (63.78)
# cpu
# Got 193 / 300 correct (64.33)
#
# Epoch 322/1000:
# Iteration 0, loss = 0.8792
# cpu
# Got 185 / 300 correct (61.67)
#
# cpu
# Got 1148 / 1800 correct (63.78)
# cpu
# Got 188 / 300 correct (62.67)
#
# Epoch 323/1000:
# Iteration 0, loss = 0.8517
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1129 / 1800 correct (62.72)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 324/1000:
# Iteration 0, loss = 0.8975
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# ...
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 894/1000:
# Iteration 0, loss = 0.7078
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1242 / 1800 correct (69.00)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 895/1000:
# Iteration 0, loss = 0.6838
# cpu
# Got 209 / 300 correct (69.67)
#
# cpu
# Got 1268 / 1800 correct (70.44)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 896/1000:
# Iteration 0, loss = 0.6739
# cpu
# Got 194 / 300 correct (64.67)
#
# cpu
# Got 1265 / 1800 correct (70.28)
# cpu
# Got 206 / 300 correct (68.67)
#
# Epoch 897/1000:
# Iteration 0, loss = 0.7198
# cpu
# Got 204 / 300 correct (68.00)
#
# cpu
# Got 1276 / 1800 correct (70.89)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 898/1000:
# Iteration 0, loss = 0.6786
# cpu
# Got 209 / 300 correct (69.67)
#
# cpu
# Got 1251 / 1800 correct (69.50)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 899/1000:
# Iteration 0, loss = 0.6630
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1264 / 1800 correct (70.22)
# cpu
# Got 206 / 300 correct (68.67)
#
# Epoch 900/1000:
# Iteration 0, loss = 0.6323
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1268 / 1800 correct (70.44)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 901/1000:
# Iteration 0, loss = 0.6908
# cpu
# Got 204 / 300 correct (68.00)
#
# cpu
# Got 1256 / 1800 correct (69.78)
# cpu
# Got 195 / 300 correct (65.00)
#
# Epoch 902/1000:
# Iteration 0, loss = 0.6789
# cpu
# Got 201 / 300 correct (67.00)
#
# cpu
# Got 1254 / 1800 correct (69.67)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 903/1000:
# Iteration 0, loss = 0.6791
# cpu
# Got 205 / 300 correct (68.33)
#
# cpu
# Got 1258 / 1800 correct (69.89)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 904/1000:
# Iteration 0, loss = 0.7036
# cpu
# Got 194 / 300 correct (64.67)
#
# cpu
# Got 1229 / 1800 correct (68.28)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 905/1000:
# Iteration 0, loss = 0.6907
# cpu
# Got 195 / 300 correct (65.00)
#
# cpu
# Got 1235 / 1800 correct (68.61)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 906/1000:
# Iteration 0, loss = 0.7006
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1245 / 1800 correct (69.17)
# cpu
# Got 195 / 300 correct (65.00)
#
# Epoch 907/1000:
# Iteration 0, loss = 0.6978
# cpu
# Got 195 / 300 correct (65.00)
#
# cpu
# Got 1253 / 1800 correct (69.61)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 908/1000:
# Iteration 0, loss = 0.6822
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1260 / 1800 correct (70.00)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 909/1000:
# Iteration 0, loss = 0.7046
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1233 / 1800 correct (68.50)
# cpu
# Got 204 / 300 correct (68.00)
#
# Epoch 910/1000:
# Iteration 0, loss = 0.6860
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 911/1000:
# Iteration 0, loss = 0.6830
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1237 / 1800 correct (68.72)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 912/1000:
# Iteration 0, loss = 0.6772
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1222 / 1800 correct (67.89)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 913/1000:
# Iteration 0, loss = 0.6969
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1221 / 1800 correct (67.83)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 914/1000:
# Iteration 0, loss = 0.7071
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1227 / 1800 correct (68.17)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 915/1000:
# Iteration 0, loss = 0.6954
# cpu
# Got 190 / 300 correct (63.33)
#
# cpu
# Got 1226 / 1800 correct (68.11)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 916/1000:
# Iteration 0, loss = 0.6577
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1240 / 1800 correct (68.89)
# cpu
# Got 191 / 300 correct (63.67)
#
# Epoch 917/1000:
# Iteration 0, loss = 0.6931
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1230 / 1800 correct (68.33)
# cpu
# Got 204 / 300 correct (68.00)
#
# Epoch 918/1000:
# Iteration 0, loss = 0.6997
# cpu
# Got 201 / 300 correct (67.00)
#
# cpu
# Got 1223 / 1800 correct (67.94)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 919/1000:
# Iteration 0, loss = 0.6925
# cpu
# Got 204 / 300 correct (68.00)
#
# cpu
# Got 1230 / 1800 correct (68.33)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 920/1000:
# Iteration 0, loss = 0.6847
# cpu
# Got 205 / 300 correct (68.33)
#
# cpu
# Got 1265 / 1800 correct (70.28)
# cpu
# Got 193 / 300 correct (64.33)
#
# Epoch 921/1000:
# Iteration 0, loss = 0.7069
# cpu
# Got 197 / 300 correct (65.67)
#
# cpu
# Got 1233 / 1800 correct (68.50)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 922/1000:
# Iteration 0, loss = 0.6621
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1235 / 1800 correct (68.61)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 923/1000:
# Iteration 0, loss = 0.7565
# cpu
# Got 192 / 300 correct (64.00)
#
# cpu
# Got 1256 / 1800 correct (69.78)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 924/1000:
# Iteration 0, loss = 0.6830
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1238 / 1800 correct (68.78)
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 925/1000:
# Iteration 0, loss = 0.6852
# cpu
# Got 201 / 300 correct (67.00)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 926/1000:
# Iteration 0, loss = 0.7137
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1246 / 1800 correct (69.22)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 927/1000:
# Iteration 0, loss = 0.6729
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1238 / 1800 correct (68.78)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 928/1000:
# Iteration 0, loss = 0.6843
# cpu
# Got 191 / 300 correct (63.67)
#
# cpu
# Got 1248 / 1800 correct (69.33)
# cpu
# Got 190 / 300 correct (63.33)
#
# Epoch 929/1000:
# Iteration 0, loss = 0.6953
# cpu
# Got 207 / 300 correct (69.00)
#
# cpu
# Got 1230 / 1800 correct (68.33)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 930/1000:
# Iteration 0, loss = 0.6779
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1228 / 1800 correct (68.22)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 931/1000:
# Iteration 0, loss = 0.6483
# cpu
# Got 198 / 300 correct (66.00)
#
# cpu
# Got 1239 / 1800 correct (68.83)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 932/1000:
# Iteration 0, loss = 0.6814
# cpu
# Got 207 / 300 correct (69.00)
#
# cpu
# Got 1271 / 1800 correct (70.61)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 933/1000:
# Iteration 0, loss = 0.6710
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1255 / 1800 correct (69.72)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 934/1000:
# Iteration 0, loss = 0.6855
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1279 / 1800 correct (71.06)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 935/1000:
# Iteration 0, loss = 0.6391
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1257 / 1800 correct (69.83)
# cpu
# Got 191 / 300 correct (63.67)
#
# Epoch 936/1000:
# Iteration 0, loss = 0.7204
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1262 / 1800 correct (70.11)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 937/1000:
# Iteration 0, loss = 0.6996
# cpu
# Got 210 / 300 correct (70.00)
#
# cpu
# Got 1244 / 1800 correct (69.11)
# cpu
# Got 206 / 300 correct (68.67)
#
# Epoch 938/1000:
# Iteration 0, loss = 0.6695
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1249 / 1800 correct (69.39)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 939/1000:
# Iteration 0, loss = 0.6845
# cpu
# Got 197 / 300 correct (65.67)
#
# cpu
# Got 1244 / 1800 correct (69.11)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 940/1000:
# Iteration 0, loss = 0.7003
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1268 / 1800 correct (70.44)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 941/1000:
# Iteration 0, loss = 0.7167
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1258 / 1800 correct (69.89)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 942/1000:
# Iteration 0, loss = 0.7504
# cpu
# Got 193 / 300 correct (64.33)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 943/1000:
# Iteration 0, loss = 0.7323
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1248 / 1800 correct (69.33)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 944/1000:
# Iteration 0, loss = 0.6959
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1246 / 1800 correct (69.22)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 945/1000:
# Iteration 0, loss = 0.7207
# cpu
# Got 197 / 300 correct (65.67)
#
# cpu
# Got 1282 / 1800 correct (71.22)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 946/1000:
# Iteration 0, loss = 0.7088
# cpu
# Got 198 / 300 correct (66.00)
#
# cpu
# Got 1236 / 1800 correct (68.67)
# cpu
# Got 195 / 300 correct (65.00)
#
# Epoch 947/1000:
# Iteration 0, loss = 0.7239
# cpu
# Got 197 / 300 correct (65.67)
# cpu
# Got 1255 / 1800 correct (69.72)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 948/1000:
# Iteration 0, loss = 0.6656
# cpu
# Got 201 / 300 correct (67.00)
#
# cpu
# Got 1238 / 1800 correct (68.78)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 949/1000:
# Iteration 0, loss = 0.6878
# cpu
# Got 193 / 300 correct (64.33)
#
# cpu
# Got 1240 / 1800 correct (68.89)
# cpu
# Got 206 / 300 correct (68.67)
#
# Epoch 950/1000:
# Iteration 0, loss = 0.6391
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1262 / 1800 correct (70.11)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 951/1000:
# Iteration 0, loss = 0.6796
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1262 / 1800 correct (70.11)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 952/1000:
# Iteration 0, loss = 0.7009
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1257 / 1800 correct (69.83)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 953/1000:
# Iteration 0, loss = 0.6857
# cpu
# Got 208 / 300 correct (69.33)
#
# cpu
# Got 1260 / 1800 correct (70.00)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 954/1000:
# Iteration 0, loss = 0.6635
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1268 / 1800 correct (70.44)
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 955/1000:
# Iteration 0, loss = 0.6916
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1269 / 1800 correct (70.50)
# cpu
# Got 203 / 300 correct (67.67)
#
# Epoch 956/1000:
# Iteration 0, loss = 0.6881
# cpu
# Got 201 / 300 correct (67.00)
#
# cpu
# Got 1266 / 1800 correct (70.33)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 957/1000:
# Iteration 0, loss = 0.6750
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 958/1000:
# Iteration 0, loss = 0.6310
# cpu
# Got 195 / 300 correct (65.00)
#
# cpu
# Got 1268 / 1800 correct (70.44)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 959/1000:
# Iteration 0, loss = 0.7077
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 960/1000:
# Iteration 0, loss = 0.6787
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1257 / 1800 correct (69.83)
# cpu
# Got 193 / 300 correct (64.33)
#
# Epoch 961/1000:
# Iteration 0, loss = 0.6622
# cpu
# Got 188 / 300 correct (62.67)
#
# cpu
# Got 1276 / 1800 correct (70.89)
# cpu
# Got 213 / 300 correct (71.00)
#
# Epoch 962/1000:
# Iteration 0, loss = 0.6600
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1254 / 1800 correct (69.67)
# cpu
# Got 206 / 300 correct (68.67)
#
# Epoch 963/1000:
# Iteration 0, loss = 0.6650
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1254 / 1800 correct (69.67)
# cpu
# Got 191 / 300 correct (63.67)
#
# Epoch 964/1000:
# Iteration 0, loss = 0.6739
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1255 / 1800 correct (69.72)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 965/1000:
# Iteration 0, loss = 0.6571
# cpu
# Got 194 / 300 correct (64.67)
#
# cpu
# Got 1245 / 1800 correct (69.17)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 966/1000:
# Iteration 0, loss = 0.7122
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1261 / 1800 correct (70.06)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 967/1000:
# Iteration 0, loss = 0.6498
# cpu
# Got 209 / 300 correct (69.67)
#
# cpu
# Got 1243 / 1800 correct (69.06)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 968/1000:
# Iteration 0, loss = 0.6866
# cpu
# Got 205 / 300 correct (68.33)
#
# cpu
# Got 1247 / 1800 correct (69.28)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 969/1000:
# Iteration 0, loss = 0.6872
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1238 / 1800 correct (68.78)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 970/1000:
# Iteration 0, loss = 0.7017
# cpu
# Got 198 / 300 correct (66.00)
#
# cpu
# Got 1265 / 1800 correct (70.28)
# cpu
# Got 193 / 300 correct (64.33)
#
# Epoch 971/1000:
# Iteration 0, loss = 0.6599
# cpu
# Got 195 / 300 correct (65.00)
#
# cpu
# Got 1243 / 1800 correct (69.06)
# cpu
# Got 207 / 300 correct (69.00)
#
# Epoch 972/1000:
# Iteration 0, loss = 0.7094
# cpu
# Got 195 / 300 correct (65.00)
#
# cpu
# Got 1248 / 1800 correct (69.33)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 973/1000:
# Iteration 0, loss = 0.6540
# cpu
# Got 188 / 300 correct (62.67)
#
# cpu
# Got 1250 / 1800 correct (69.44)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 974/1000:
# Iteration 0, loss = 0.7040
# cpu
# Got 205 / 300 correct (68.33)
#
# cpu
# Got 1233 / 1800 correct (68.50)
# cpu
# Got 202 / 300 correct (67.33)
#
# Epoch 975/1000:
# Iteration 0, loss = 0.6813
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1258 / 1800 correct (69.89)
# cpu
# Got 197 / 300 correct (65.67)
#
# Epoch 976/1000:
# Iteration 0, loss = 0.6877
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1228 / 1800 correct (68.22)
# cpu
# Got 187 / 300 correct (62.33)
#
# Epoch 977/1000:
# Iteration 0, loss = 0.6471
# cpu
# Got 202 / 300 correct (67.33)
#
# cpu
# Got 1265 / 1800 correct (70.28)
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 978/1000:
# Iteration 0, loss = 0.6818
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1237 / 1800 correct (68.72)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 979/1000:
# Iteration 0, loss = 0.7036
# cpu
# Got 198 / 300 correct (66.00)
#
# cpu
# Got 1240 / 1800 correct (68.89)
# cpu
# Got 191 / 300 correct (63.67)
#
# Epoch 980/1000:
# Iteration 0, loss = 0.7235
# cpu
# Got 207 / 300 correct (69.00)
#
# cpu
# Got 1239 / 1800 correct (68.83)
# cpu
# Got 199 / 300 correct (66.33)
#
# Epoch 981/1000:
# Iteration 0, loss = 0.6528
# cpu
# Got 197 / 300 correct (65.67)
#
# cpu
# Got 1244 / 1800 correct (69.11)
# cpu
# Got 189 / 300 correct (63.00)
#
# Epoch 982/1000:
# Iteration 0, loss = 0.6786
# cpu
# Got 181 / 300 correct (60.33)
#
# cpu
# Got 1275 / 1800 correct (70.83)
# cpu
# Got 194 / 300 correct (64.67)
#
# Epoch 983/1000:
# Iteration 0, loss = 0.6832
# cpu
# Got 205 / 300 correct (68.33)
#
# cpu
# Got 1260 / 1800 correct (70.00)
# cpu
# Got 205 / 300 correct (68.33)
#
# Epoch 984/1000:
# Iteration 0, loss = 0.6777
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1257 / 1800 correct (69.83)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 985/1000:
# Iteration 0, loss = 0.6785
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 986/1000:
# Iteration 0, loss = 0.6686
# cpu
# Got 191 / 300 correct (63.67)
#
# cpu
# Got 1241 / 1800 correct (68.94)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 987/1000:
# Iteration 0, loss = 0.7283
# cpu
# Got 189 / 300 correct (63.00)
#
# cpu
# Got 1230 / 1800 correct (68.33)
# cpu
# Got 191 / 300 correct (63.67)
#
# Epoch 988/1000:
# Iteration 0, loss = 0.6750
# cpu
# Got 199 / 300 correct (66.33)
#
# cpu
# Got 1258 / 1800 correct (69.89)
# cpu
# Got 193 / 300 correct (64.33)
#
# Epoch 989/1000:
# Iteration 0, loss = 0.6962
# cpu
# Got 200 / 300 correct (66.67)
#
# cpu
# Got 1262 / 1800 correct (70.11)
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 990/1000:
# Iteration 0, loss = 0.6802
# cpu
# Got 186 / 300 correct (62.00)
#
# cpu
# Got 1249 / 1800 correct (69.39)
# cpu
# Got 200 / 300 correct (66.67)
#
# Epoch 991/1000:
# Iteration 0, loss = 0.6626
# cpu
# Got 193 / 300 correct (64.33)
#
# cpu
# Got 1267 / 1800 correct (70.39)
# cpu
# Got 185 / 300 correct (61.67)
#
# Epoch 992/1000:
# Iteration 0, loss = 0.7121
# cpu
# Got 207 / 300 correct (69.00)
#
# cpu
# Got 1220 / 1800 correct (67.78)
# cpu
# Got 192 / 300 correct (64.00)
#
# Epoch 993/1000:
# Iteration 0, loss = 0.6683
# cpu
# Got 203 / 300 correct (67.67)
#
# cpu
# Got 1267 / 1800 correct (70.39)
# cpu
# Got 204 / 300 correct (68.00)
#
# Epoch 994/1000:
# Iteration 0, loss = 0.6689
# cpu
# Got 212 / 300 correct (70.67)
#
# cpu
# Got 1252 / 1800 correct (69.56)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 995/1000:
# Iteration 0, loss = 0.7034
# cpu
# Got 196 / 300 correct (65.33)
#
# cpu
# Got 1250 / 1800 correct (69.44)
# cpu
# Got 201 / 300 correct (67.00)
#
# Epoch 996/1000:
# Iteration 0, loss = 0.6783
# cpu
# Got 210 / 300 correct (70.00)
#
# cpu
# Got 1248 / 1800 correct (69.33)
# cpu
# Got 196 / 300 correct (65.33)
#
# Epoch 997/1000:
# Iteration 0, loss = 0.6907
# cpu
# Got 197 / 300 correct (65.67)
#
# cpu
# Got 1259 / 1800 correct (69.94)
# cpu
# Got 204 / 300 correct (68.00)
#
# Epoch 998/1000:
# Iteration 0, loss = 0.6725
# cpu
# Got 206 / 300 correct (68.67)
#
# cpu
# Got 1255 / 1800 correct (69.72)
# cpu
# Got 198 / 300 correct (66.00)
#
# Epoch 999/1000:
# Iteration 0, loss = 0.6860
# cpu
# Got 213 / 300 correct (71.00)
#
# cpu
# Got 1247 / 1800 correct (69.28)
# cpu
# Got 192 / 300 correct (64.00)
#
# Epoch 1000/1000:
# Iteration 0, loss = 0.6718
# cpu
# Got 193 / 300 correct (64.33)
#
# cpu
# Got 1273 / 1800 correct (70.72)
# cpu
# Got 197 / 300 correct (65.67)

# %%
trainingMetrics(history)

# %%
check_accuracy(loader_val,fc)
# Out:
# cpu
# Got 195 / 300 correct (65.00)

# %%
type(1e4)
# Out:
# float
